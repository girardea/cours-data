# %% [markdown]
# # Import des modules nécessaires

# %%
    # Pour manipuler efficacement des tables de données dans Python
    import pandas as pd

    # Pour faire des requêtes GET et POST
    import requests
    
    # Pour gérer les date
    import datetime as dt

# %%
print(pd.__version__)
# Out:
# 0.23.0

# %%
print(requests.__version__)
# Out:
# 2.18.4

# %% [markdown]
# # Requêtage d'une API REST

# %% [markdown]
# Pour lancer une requête GET, c'est ultra-simple : on utilise `requests.get(url)`.
#
# Si vous voulez glisser des paramètres avec la requête, utilisez l'argument optionnel `params`, qui accepte un simple dictionnaire.

# %%
r = requests.get("https://data.angers.fr/api/records/1.0/search/",
                 params={
                     'dataset': 'horaires-theoriques-et-arrets-du-reseau-irigo-gtfs',
                     'rows': 10
                 })

# %%
g = requests.get("https://data.angers.fr/api/records/1.0/search/",
                 params={
                     'dataset': 'bus-tram-position-tr',
                     'rows': 200
                 })

# %% [markdown]
# Regardons la nature de ce qui nous est renvoyé.

# %%
type(g)
# Out:
# requests.models.Response

# %% [markdown]
# C'est un objet de la classe `Response`. Si vous voulez connaitre toutes les méthodes attachées, faites `help(r)`

# %%
help(g)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, state)
#  |
#  |  close(self)
#  |      Releases the connection back to the pool. Once this method has been
#  |      called the underlying ``raw`` object must not be accessed again.
#  |
#  |      *Note: Should not normally need to be called explicitly.*
#  |
#  |  iter_content(self, chunk_size=1, decode_unicode=False)
#  |      Iterates over the response data.  When stream=True is set on the
#  |      request, this avoids reading the content at once into memory for
#  |      large responses.  The chunk size is the number of bytes it should
#  |      read into memory.  This is not necessarily the length of each item
#  |      returned as decoding can take place.
#  |
#  |      chunk_size must be of type int or None. A value of None will
#  |      function differently depending on the value of `stream`.
#  |      stream=True will read data as it arrives in whatever size the
#  |      chunks are received. If stream=False, data is returned as
#  |      a single chunk.
#  |
#  |      If decode_unicode is True, content will be decoded using the best
#  |      available encoding based on the response.
#  |
#  |  iter_lines(self, chunk_size=512, decode_unicode=None, delimiter=None)
#  |      Iterates over the response data, one line at a time.  When
#  |      stream=True is set on the request, this avoids reading the
#  |      content at once into memory for large responses.
#  |
#  |      .. note:: This method is not reentrant safe.
#  |
#  |  json(self, **kwargs)
#  |      Returns the json-encoded content of a response, if any.
#  |
#  |      :param \*\*kwargs: Optional arguments that ``json.loads`` takes.
#  |      :raises ValueError: If the response body does not contain valid json.
#  |
#  |  raise_for_status(self)
#  |      Raises stored :class:`HTTPError`, if one occurred.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  apparent_encoding
#  |      The apparent encoding, provided by the chardet library.
#  |
#  |  content
#  |      Content of the response, in bytes.
#  |
#  |  is_permanent_redirect
#  |      True if this Response one of the permanent versions of redirect.
#  |
#  |  is_redirect
#  |      True if this Response is a well-formed HTTP redirect that could have
#  |      been processed automatically (by :meth:`Session.resolve_redirects`).
#  |
#  |  links
#  |      Returns the parsed header links of the response, if any.
#  |
#  |  next
#  |      Returns a PreparedRequest for the next request in a redirect chain, if there is one.
#  |
#  |  ok
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  text
#  |      Content of the response, in unicode.
#  |
#  |      If Response.encoding is None, encoding will be guessed using
#  |      ``chardet``.
#  |
#  |      The encoding of the response content is determined based solely on HTTP
#  |      headers, following RFC 2616 to the letter. If you can take advantage of
#  |      non-HTTP knowledge to make a better guess at the encoding, you should
#  |      set ``r.encoding`` appropriately before accessing this property.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __attrs__ = ['_content', 'status_code', 'headers', 'url', 'history', '...

# %% [markdown]
# Pour tester que tout a bien fonctionnné, on va vérifié le statut.

# %%
g.raise_for_status()

# %% [markdown]
# Si ça dit rien c'est que c'est bon :) Dans le doute, regardons le statut...

# %%
g.status_code
# Out:
# 200

# %% [markdown]
# Statut 200 = succès !!

# %% [markdown]
# Pour récupérer le contenu de la réponse, vous pouvez utiliser `r.text`.
#
# Il y a aussi un décodeur JSON, si on sait que la réponse est dans ce format. Du coup, il parse le JSON et rend un dictionnaire !

# %%
g.json()
# Out:
# {'nhits': 106,
#  'parameters': {'dataset': ['bus-tram-position-tr'],
#   'timezone': 'UTC',
#   'rows': 200,
#   'format': 'json'},
#  'records': [{'datasetid': 'bus-tram-position-tr',
#    'recordid': '14c506f09a99d91c098950a3fe823121db098640',
#    'fields': {'etat': 'HLPS',
#     'type': 'OmniArtE6',
#     'ecart': 0,
#     'novh': '681',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268721408,
#     'cap': 95,
#     'nomarret': 'SORTIE BUS CTB',
#     'idvh': 268436137,
#     'iddesserte': 268721409,
#     'mnemoligne': '04',
#     'y': 2281381,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'SDCTB',
#     'idarret': 671973,
#     'harret': '2018-06-19T06:53:55+00:00',
#     'x': 381077,
#     'sv': '0423',
#     'coordonnees': [47.4956, -0.56967987],
#     'idligne': 268435460,
#     'numarret': 17220},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56967987, 47.4956]},
#    'record_timestamp': '2018-06-19T06:57:17+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd2707eca39de09f79bcef7be9101e0af08c1a754',
#    'fields': {'etat': 'HLPS',
#     'type': 'OmniSTDE6',
#     'ecart': 0,
#     'novh': '803',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268720384,
#     'cap': 185,
#     'nomarret': 'SORTIE DEPOT ST BART',
#     'idvh': 268436259,
#     'iddesserte': 268720385,
#     'mnemoligne': '04',
#     'y': 2279028,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'DEPOT SD',
#     'idarret': 671375,
#     'harret': '2018-06-19T07:09:46+00:00',
#     'x': 386788,
#     'sv': '0412',
#     'coordonnees': [47.476323, -0.49280852],
#     'idligne': 268435460,
#     'numarret': 6562},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49280852, 47.476323]},
#    'record_timestamp': '2018-06-19T07:16:13+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'e9e06aaa63b6f1909e235bab88e3c0c22401af53',
#    'fields': {'etat': 'HLPS',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '443',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268875520,
#     'cap': 5,
#     'nomarret': 'SORTIE DEPOT ST BART',
#     'idvh': 268435899,
#     'iddesserte': 268875521,
#     'mnemoligne': '06',
#     'y': 2278894,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'DEPOT SD',
#     'idarret': 671375,
#     'harret': '2018-06-19T07:26:00+00:00',
#     'x': 386789,
#     'sv': '0621',
#     'coordonnees': [47.475119, -0.49273127],
#     'idligne': 268435462,
#     'numarret': 6562},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49273127, 47.475119]},
#    'record_timestamp': '2018-06-19T07:31:18+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a0a5b38fdf8b9abdd0ac05e7bf1854b76737021b',
#    'fields': {'etat': 'HLPS',
#     'type': 'OMNIART',
#     'ecart': 0,
#     'novh': '664',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268525312,
#     'cap': 95,
#     'nomarret': 'SORTIE BUS CTB',
#     'idvh': 268436120,
#     'iddesserte': 268525313,
#     'mnemoligne': '01',
#     'y': 2281389,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'SDCTB',
#     'idarret': 671973,
#     'harret': '2018-06-19T07:45:09+00:00',
#     'x': 381107,
#     'sv': '0104',
#     'coordonnees': [47.495681, -0.56928591],
#     'idligne': 268435457,
#     'numarret': 17220},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56928591, 47.495681]},
#    'record_timestamp': '2018-06-19T07:57:53+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '330bfa9dc100be890f1ad6d996ec766cdfae6765',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '449',
#     'dest': 'MOULIN MARCILLE PAR TRELA',
#     'idparcours': 269266944,
#     'cap': 90,
#     'nomarret': 'ST AUBIN LA SALLE',
#     'idvh': 268435905,
#     'iddesserte': 269266945,
#     'mnemoligne': '12',
#     'y': 2280507,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'BARONNER',
#     'idarret': 671157,
#     'harret': '2018-06-19T09:00:00+00:00',
#     'x': 386016,
#     'sv': '1210',
#     'coordonnees': [47.489367, -0.50375319],
#     'idligne': 268435468,
#     'numarret': 2861},
#    'geometry': {'type': 'Point', 'coordinates': [-0.50375319, 47.489367]},
#    'record_timestamp': '2018-06-19T08:53:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c1face88ffc04e903b88bc015a11c7192cc278ca',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 11450,
#     'novh': '423',
#     'dest': 'SPECIAL PISCINE',
#     'idparcours': 272342272,
#     'cap': 206,
#     'nomarret': 'PISCINE MONPLAISIR',
#     'idvh': 268435879,
#     'iddesserte': 272342273,
#     'mnemoligne': '535',
#     'y': 2280239,
#     'nomligne': 'Piscine MONPLAISIR',
#     'mnemoarret': 'P-MONPL',
#     'idarret': 672636,
#     'harret': '2018-06-19T08:54:51+00:00',
#     'x': 384690,
#     'sv': '53513',
#     'coordonnees': [47.486526, -0.52120883],
#     'idligne': 268435515,
#     'numarret': 804722},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52120883, 47.486526]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c22f1921661fede0c6f6635c9e3bddf9f5d46476',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 30,
#     'novh': '453',
#     'dest': 'MOULIN MARCILLE PAR TRELA',
#     'idparcours': 269266944,
#     'cap': 299,
#     'nomarret': 'JOFFRE',
#     'idvh': 268435909,
#     'iddesserte': 269266963,
#     'mnemoligne': '12',
#     'y': 2278368,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'JOFFRE',
#     'idarret': 671593,
#     'harret': '2018-06-19T08:56:22+00:00',
#     'x': 383160,
#     'sv': '1208',
#     'coordonnees': [47.469206, -0.54058905],
#     'idligne': 268435468,
#     'numarret': 25570},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54058905, 47.469206]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a627776c208afbfbfe4fcb5838046358a0b64ab9',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 31,
#     'novh': '454',
#     'dest': 'MOULIN MARCILLE',
#     'idparcours': 269004288,
#     'cap': 107,
#     'nomarret': 'CENTRE COMMERCIAL',
#     'idvh': 268435910,
#     'iddesserte': 269004322,
#     'mnemoligne': '08',
#     'y': 2274840,
#     'nomligne': 'PONTS CE <>  AQUAVITA H. RECULEE',
#     'mnemoarret': 'CCOMME-E',
#     'idarret': 671263,
#     'harret': '2018-06-19T08:54:51+00:00',
#     'x': 384063,
#     'sv': '0803',
#     'coordonnees': [47.43779, -0.5269133],
#     'idligne': 268435464,
#     'numarret': 10530},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5269133, 47.43779]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '11f4c1b37f06116e5b390b43b8e54697d256c67d',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 310,
#     'novh': '457',
#     'dest': 'CIRCULAIRE SENS B',
#     'idparcours': 268807680,
#     'cap': 276,
#     'nomarret': 'GILLIER',
#     'idvh': 268435913,
#     'iddesserte': 268807729,
#     'mnemoligne': '05',
#     'y': 2278965,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'GILLIER',
#     'idarret': 671507,
#     'harret': '2018-06-19T08:54:57+00:00',
#     'x': 384366,
#     'sv': '0521',
#     'coordonnees': [47.474968, -0.52488989],
#     'idligne': 268435461,
#     'numarret': 4265},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52488989, 47.474968]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '8761725445b2f9ae6b68bcdf6c2d59173db8f9cf',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 17,
#     'novh': '538',
#     'dest': 'TRELAZE ST LEZIN',
#     'idparcours': 269131264,
#     'cap': 300,
#     'nomarret': 'VAUGAREAU',
#     'idvh': 268435994,
#     'iddesserte': 269131267,
#     'mnemoligne': '10',
#     'y': 2279926,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'VAUGA6',
#     'idarret': 672042,
#     'harret': '2018-06-19T08:55:02+00:00',
#     'x': 384130,
#     'sv': '1009',
#     'coordonnees': [47.483529, -0.52848353],
#     'idligne': 268435466,
#     'numarret': 7338},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52848353, 47.483529]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a1b0c279c5f0d4879ca2c32b0ea558e39a40bec6',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 151,
#     'novh': '601',
#     'dest': 'BELLE BEILLE',
#     'idparcours': 268545536,
#     'cap': 284,
#     'nomarret': 'MONPROFIT',
#     'idvh': 268436057,
#     'iddesserte': 268545563,
#     'mnemoligne': '01',
#     'y': 2279086,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'MONPRO-E',
#     'idarret': 671756,
#     'harret': '2018-06-19T08:56:29+00:00',
#     'x': 381573,
#     'sv': '0121',
#     'coordonnees': [47.475135, -0.56197817],
#     'idligne': 268435457,
#     'numarret': 29694},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56197817, 47.475135]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '09f8443253a4eefd0208aae651dc2f15bdf2f09f',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 111,
#     'novh': '603',
#     'dest': 'MONPLAISIR',
#     'idparcours': 268513024,
#     'cap': 81,
#     'nomarret': 'MONPROFIT',
#     'idvh': 268436059,
#     'iddesserte': 268513036,
#     'mnemoligne': '01',
#     'y': 2279005,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'MONPROF.',
#     'idarret': 671757,
#     'harret': '2018-06-19T08:54:45+00:00',
#     'x': 381217,
#     'sv': '0102',
#     'coordonnees': [47.474289, -0.56665826],
#     'idligne': 268435457,
#     'numarret': 29382},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56665826, 47.474289]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'ca5f9f90466b1fe721348057a739de323c1f62b0',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 11,
#     'novh': '616',
#     'dest': 'ST BARTHELEMY',
#     'idparcours': 268706560,
#     'cap': 27,
#     'nomarret': 'CEZANNE',
#     'idvh': 268436072,
#     'iddesserte': 268706621,
#     'mnemoligne': '04',
#     'y': 2278234,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'CEZAN-E',
#     'idarret': 671269,
#     'harret': '2018-06-19T08:55:02+00:00',
#     'x': 386792,
#     'sv': '0425',
#     'coordonnees': [47.469187, -0.49237633],
#     'idligne': 268435460,
#     'numarret': 16647},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49237633, 47.469187]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd256116331bdd077cabb56b796160ec1f9b3e536',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 350,
#     'novh': '622',
#     'dest': 'MONPLAISIR',
#     'idparcours': 268513024,
#     'cap': 17,
#     'nomarret': 'VAUGAREAU',
#     'idvh': 268436078,
#     'iddesserte': 268513059,
#     'mnemoligne': '01',
#     'y': 2279787,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'VAUGAR-E',
#     'idarret': 672044,
#     'harret': '2018-06-19T08:54:51+00:00',
#     'x': 384252,
#     'sv': '0105',
#     'coordonnees': [47.48232, -0.5267986],
#     'idligne': 268435457,
#     'numarret': 1236},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5267986, 47.48232]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '58d6606ab15a377baf27fad8857c7941efc6b8d8',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 715,
#     'novh': '623',
#     'dest': 'AVRILLE SALETTE',
#     'idparcours': 268641024,
#     'cap': 339,
#     'nomarret': 'PATINOIRE',
#     'idvh': 268436079,
#     'iddesserte': 268641055,
#     'mnemoligne': '03',
#     'y': 2277882,
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'mnemoarret': 'PATNOIRE',
#     'idarret': 671816,
#     'harret': '2018-06-19T08:56:38+00:00',
#     'x': 382525,
#     'sv': '0306',
#     'coordonnees': [47.464628, -0.54877023],
#     'idligne': 268435459,
#     'numarret': 31383},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54877023, 47.464628]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'dffc3b25e4e34ecd2cef8eff3568305edd7045f1',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 58,
#     'novh': '651',
#     'dest': 'ST BARTHELEMY',
#     'idparcours': 268706560,
#     'cap': 324,
#     'nomarret': 'PINSONS',
#     'idvh': 268436107,
#     'iddesserte': 268706563,
#     'mnemoligne': '04',
#     'y': 2278843,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'PINSONS',
#     'idarret': 671845,
#     'harret': '2018-06-19T08:55:22+00:00',
#     'x': 376544,
#     'sv': '0406',
#     'coordonnees': [47.471264, -0.62852822],
#     'idligne': 268435460,
#     'numarret': 23478},
#    'geometry': {'type': 'Point', 'coordinates': [-0.62852822, 47.471264]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '397a1a8465f0a320704c8e49423d5602f81800da',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 429,
#     'novh': '654',
#     'dest': 'ST SYLVAIN',
#     'idparcours': 268578560,
#     'cap': 45,
#     'nomarret': 'LORRAINE MAISONBLEUE',
#     'idvh': 268436110,
#     'iddesserte': 268578595,
#     'mnemoligne': '02',
#     'y': 2278376,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'LOR-FO-A',
#     'idarret': 671680,
#     'harret': '2018-06-19T08:55:28+00:00',
#     'x': 382498,
#     'sv': '0209',
#     'coordonnees': [47.469059, -0.54936872],
#     'idligne': 268435458,
#     'numarret': 3039},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54936872, 47.469059]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '9d9442de2731053444e1871f103d3f6d8681bd25',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': -7,
#     'novh': '670',
#     'dest': 'ST BARTHELEMY',
#     'idparcours': 268707072,
#     'cap': 186,
#     'nomarret': 'LA BARRE',
#     'idvh': 268436126,
#     'iddesserte': 268707093,
#     'mnemoligne': '04',
#     'y': 2279136,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'LABARRE',
#     'idarret': 671607,
#     'harret': '2018-06-19T08:56:19+00:00',
#     'x': 378730,
#     'sv': '0405',
#     'coordonnees': [47.474636, -0.59969437],
#     'idligne': 268435460,
#     'numarret': 26186},
#    'geometry': {'type': 'Point', 'coordinates': [-0.59969437, 47.474636]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '29857e6a1d70228cebf7abe4877f19094f4a5587',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniArtE6',
#     'ecart': 38,
#     'novh': '683',
#     'dest': 'BANCHAIS',
#     'idparcours': 268579072,
#     'cap': 281,
#     'nomarret': 'TRELAZE',
#     'idvh': 268436139,
#     'iddesserte': 268579074,
#     'mnemoligne': '02',
#     'y': 2277176,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'TRELAZE',
#     'idarret': 672020,
#     'harret': '2018-06-19T08:55:00+00:00',
#     'x': 387990,
#     'sv': '0206',
#     'coordonnees': [47.460064, -0.47599233],
#     'idligne': 268435458,
#     'numarret': 25775},
#    'geometry': {'type': 'Point', 'coordinates': [-0.47599233, 47.460064]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c654b6be045e5ffa2ce381caefccce8eb35b7d5c',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniArtE6',
#     'ecart': 335,
#     'novh': '689',
#     'dest': 'ST BARTHELEMY',
#     'idparcours': 268707072,
#     'cap': 105,
#     'nomarret': 'MAISON DES ARTS',
#     'idvh': 268436145,
#     'iddesserte': 268707111,
#     'mnemoligne': '04',
#     'y': 2278657,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'BELFON-E',
#     'idarret': 671177,
#     'harret': '2018-06-19T08:55:34+00:00',
#     'x': 383266,
#     'sv': '0402',
#     'coordonnees': [47.471839, -0.53932413],
#     'idligne': 268435460,
#     'numarret': 32395},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53932413, 47.471839]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'eccdff00c372435527fda3fdf2c58cdb4f76720b',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 158,
#     'novh': '814',
#     'dest': 'BOUCHEMAINE CENTRE',
#     'idparcours': 268873728,
#     'cap': 275,
#     'nomarret': 'MARIUS BRIANT',
#     'idvh': 268436270,
#     'iddesserte': 268873752,
#     'mnemoligne': '06',
#     'y': 2278970,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'MBRIAN-E',
#     'idarret': 672772,
#     'harret': '2018-06-19T08:55:58+00:00',
#     'x': 380607,
#     'sv': '0622',
#     'coordonnees': [47.473771, -0.57472818],
#     'idligne': 268435462,
#     'numarret': 380053},
#    'geometry': {'type': 'Point', 'coordinates': [-0.57472818, 47.473771]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'b95e98363405c9aa34a2927c7b4b1694df5d455d',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 101,
#     'novh': '1005',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 147,
#     'nomarret': 'RALLIEMENT',
#     'idvh': 268436461,
#     'iddesserte': 269451537,
#     'mnemoligne': 'A',
#     'y': 2278765,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1RALL',
#     'idarret': 671059,
#     'harret': '2018-06-19T08:55:41+00:00',
#     'x': 382240,
#     'sv': 'A13',
#     'coordonnees': [47.472471, -0.55297858],
#     'idligne': 268435471,
#     'numarret': 24847},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55297858, 47.472471]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6649fd4dfef1b561ba530e1bc102b820b6dbe42c',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 40,
#     'novh': '1014',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 215,
#     'nomarret': 'CAPUCINS',
#     'idvh': 268436470,
#     'iddesserte': 269451532,
#     'mnemoligne': 'A',
#     'y': 2280660,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1CAPU',
#     'idarret': 671046,
#     'harret': '2018-06-19T08:55:49+00:00',
#     'x': 382344,
#     'sv': 'A04',
#     'coordonnees': [47.489539, -0.5525239],
#     'idligne': 268435471,
#     'numarret': 29904},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5525239, 47.489539]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'ed7cfc069de9bd032567e715cfa8a3d1f43778f3',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 249,
#     'novh': '1016',
#     'dest': 'AVRILLE ARDENNE',
#     'idparcours': 269419008,
#     'cap': 25,
#     'nomarret': 'CHU - HOPITAL',
#     'idvh': 268436472,
#     'iddesserte': 269419022,
#     'mnemoligne': 'A',
#     'y': 2279778,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2HOPA',
#     'idarret': 671076,
#     'harret': '2018-06-19T08:54:51+00:00',
#     'x': 382213,
#     'sv': 'A11',
#     'coordonnees': [47.481567, -0.55383073],
#     'idligne': 268435471,
#     'numarret': 13445},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55383073, 47.481567]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '463ca9a4e1dce86959ef7fbe0f8262176858a5ba',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '456',
#     'dest': 'MONTREUIL JUIGNE',
#     'idparcours': 268905216,
#     'cap': 227,
#     'nomarret': 'CHU - MATERNITE',
#     'idvh': 268435912,
#     'iddesserte': 268905217,
#     'mnemoligne': '07',
#     'y': 2279680,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'HOPA8-C',
#     'idarret': 671540,
#     'harret': '2018-06-19T09:02:00+00:00',
#     'x': 382118,
#     'sv': '0723',
#     'coordonnees': [47.480655, -0.55504254],
#     'idligne': 268435463,
#     'numarret': 27358},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55504254, 47.480655]},
#    'record_timestamp': '2018-06-19T08:45:54+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '410c26a654609b0c4d49d5270b56aa4d95ce1d46',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '433',
#     'dest': 'SAINTE GEMMES',
#     'idparcours': 269198848,
#     'cap': 56,
#     'nomarret': "L'HOIRIE",
#     'idvh': 268435889,
#     'iddesserte': 269198849,
#     'mnemoligne': '11',
#     'y': 2278354,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'LHOIRI11',
#     'idarret': 671667,
#     'harret': '2018-06-19T08:57:00+00:00',
#     'x': 377296,
#     'sv': '1103',
#     'coordonnees': [47.467123, -0.61831542],
#     'idligne': 268435467,
#     'numarret': 32088},
#    'geometry': {'type': 'Point', 'coordinates': [-0.61831542, 47.467123]},
#    'record_timestamp': '2018-06-19T08:50:17+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '561a880c6d029bc6de267ab847dda10902ec5bb7',
#    'fields': {'etat': 'TDEP',
#     'type': 'CITADIS',
#     'ecart': 0,
#     'novh': '1010',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269452544,
#     'cap': 139,
#     'nomarret': 'AVRILLE - ARDENNE',
#     'idvh': 268436466,
#     'iddesserte': 269452545,
#     'mnemoligne': 'A',
#     'y': 2283216,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2AARD',
#     'idarret': 671064,
#     'harret': '2018-06-19T08:59:30+00:00',
#     'x': 379175,
#     'sv': 'A06',
#     'coordonnees': [47.511458, -0.59581421],
#     'idligne': 268435471,
#     'numarret': 22259},
#    'geometry': {'type': 'Point', 'coordinates': [-0.59581421, 47.511458]},
#    'record_timestamp': '2018-06-19T08:51:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '0a12e603e02f5e994a88075550171c456e379e8b',
#    'fields': {'etat': 'TDEP',
#     'type': 'GX 327',
#     'ecart': 0,
#     'novh': '540',
#     'dest': 'CIRCULAIRE SENS B',
#     'idparcours': 268807680,
#     'cap': 185,
#     'nomarret': 'AQUA VITA',
#     'idvh': 268435996,
#     'iddesserte': 268807681,
#     'mnemoligne': '05',
#     'y': 2281098,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'AQVI-D5B',
#     'idarret': 672581,
#     'harret': '2018-06-19T09:01:00+00:00',
#     'x': 381387,
#     'sv': '0501',
#     'coordonnees': [47.493159, -0.56542969],
#     'idligne': 268435461,
#     'numarret': 96211},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56542969, 47.493159]},
#    'record_timestamp': '2018-06-19T08:50:34+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a5f2364fa47f3c3f2feb3aad849ce7129fda01b0',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 144,
#     'novh': '435',
#     'dest': 'SCHWEITZER',
#     'idparcours': 269097728,
#     'cap': 314,
#     'nomarret': 'SAUMUROISE',
#     'idvh': 268435891,
#     'iddesserte': 269097747,
#     'mnemoligne': '10',
#     'y': 2276804,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'MILLOT.',
#     'idarret': 671741,
#     'harret': '2018-06-19T08:56:02+00:00',
#     'x': 383934,
#     'sv': '1004',
#     'coordonnees': [47.455402, -0.52957189],
#     'idligne': 268435466,
#     'numarret': 4218},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52957189, 47.455402]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '4bf1180af40564915f9ac781c42e35e9b9ddc970',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '448',
#     'dest': 'SPECIAL PISCINE',
#     'idparcours': 272209920,
#     'cap': 118,
#     'nomarret': 'PISCINE ROSERAIE',
#     'idvh': 268435904,
#     'iddesserte': 272209921,
#     'mnemoligne': '533',
#     'y': 2275623,
#     'nomligne': 'Piscine ROSERAIE',
#     'mnemoarret': 'P-ROSER',
#     'idarret': 672637,
#     'harret': '2018-06-19T08:54:51+00:00',
#     'x': 381316,
#     'sv': '53314',
#     'coordonnees': [47.443922, -0.56369014],
#     'idligne': 268435513,
#     'numarret': 720289},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56369014, 47.443922]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '820424ed13c77fcca5c018cd39cb0c8715893e08',
#    'fields': {'etat': 'DEVP',
#     'type': 'OMNICITY',
#     'ecart': -5,
#     'novh': '461',
#     'dest': 'AQUAVITA VERNEAU',
#     'idparcours': 268969728,
#     'cap': 213,
#     'nomarret': 'GARES BREMONT',
#     'idvh': 268435917,
#     'iddesserte': 268969751,
#     'mnemoligne': '08',
#     'y': 2278043,
#     'nomligne': 'PONTS CE <>  AQUAVITA H. RECULEE',
#     'mnemoarret': 'BREMON-E',
#     'idarret': 671225,
#     'harret': '2018-06-19T08:55:11+00:00',
#     'x': 382054,
#     'sv': '0805',
#     'coordonnees': [47.465919, -0.55509204],
#     'idligne': 268435464,
#     'numarret': 25430},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55509204, 47.465919]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd0336bf87cfa1a8ebcbc46581cdcb22d4e9aaff9',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 230,
#     'novh': '463',
#     'dest': 'ST AUBIN LA SALLE',
#     'idparcours': 269233408,
#     'cap': 20,
#     'nomarret': 'BAUDRAIRIE',
#     'idvh': 268435919,
#     'iddesserte': 269233410,
#     'mnemoligne': '12',
#     'y': 2274408,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'BAUDRAI',
#     'idarret': 671163,
#     'harret': '2018-06-19T08:56:06+00:00',
#     'x': 386099,
#     'sv': '1202',
#     'coordonnees': [47.43457, -0.49973174],
#     'idligne': 268435468,
#     'numarret': 19950},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49973174, 47.43457]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'cd82d6207c107d5d4584b4a56062daefea35048d',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 37,
#     'novh': '523',
#     'dest': 'CHU - HOPITAL',
#     'idparcours': 268939776,
#     'cap': 134,
#     'nomarret': 'ARDENNE',
#     'idvh': 268435979,
#     'iddesserte': 268939802,
#     'mnemoligne': '07',
#     'y': 2283866,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'AARD-7C',
#     'idarret': 671092,
#     'harret': '2018-06-19T08:56:37+00:00',
#     'x': 378517,
#     'sv': '0724',
#     'coordonnees': [47.517079, -0.60486659],
#     'idligne': 268435463,
#     'numarret': 562},
#    'geometry': {'type': 'Point', 'coordinates': [-0.60486659, 47.517079]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '5327f3cc268302a81b5dc181c51c0b928a071e0a',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 147,
#     'novh': '526',
#     'dest': 'MONTREUIL JUIGNE',
#     'idparcours': 268905216,
#     'cap': 314,
#     'nomarret': 'AUCHAN',
#     'idvh': 268435982,
#     'iddesserte': 268905235,
#     'mnemoligne': '07',
#     'y': 2283993,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'INTAVR-E',
#     'idarret': 671561,
#     'harret': '2018-06-19T08:54:50+00:00',
#     'x': 378388,
#     'sv': '0721',
#     'coordonnees': [47.518177, -0.60664131],
#     'idligne': 268435463,
#     'numarret': 6846},
#    'geometry': {'type': 'Point', 'coordinates': [-0.60664131, 47.518177]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'bd67a0bd59245e77a5c03b656518702e5376bc42',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 243,
#     'novh': '533',
#     'dest': 'CIRCULAIRE SENS A',
#     'idparcours': 268774144,
#     'cap': 72,
#     'nomarret': 'GARE SEMARD',
#     'idvh': 268435989,
#     'iddesserte': 268774192,
#     'mnemoligne': '05',
#     'y': 2277924,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'SEMARD',
#     'idarret': 671977,
#     'harret': '2018-06-19T08:54:48+00:00',
#     'x': 381691,
#     'sv': '0526',
#     'coordonnees': [47.46473, -0.55984564],
#     'idligne': 268435461,
#     'numarret': 27110},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55984564, 47.46473]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '609d77ff21f896937788b45d7b65f06220ef926a',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': -19,
#     'novh': '660',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611584,
#     'cap': 150,
#     'nomarret': 'CHOUTEAU',
#     'idvh': 268436116,
#     'iddesserte': 268611614,
#     'mnemoligne': '02',
#     'y': 2275821,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'CHOUTE-E',
#     'idarret': 671302,
#     'harret': '2018-06-19T08:55:32+00:00',
#     'x': 386130,
#     'sv': '0218',
#     'coordonnees': [47.447282, -0.49999708],
#     'idligne': 268435458,
#     'numarret': 22740},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49999708, 47.447282]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd3b33e48da329c0170c82621ed03538fa0d4c83d',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 143,
#     'novh': '809',
#     'dest': 'ST AUBIN LA SALLE',
#     'idparcours': 269233408,
#     'cap': 20,
#     'nomarret': 'PLACE LORRAINE',
#     'idvh': 268436265,
#     'iddesserte': 269233429,
#     'mnemoligne': '12',
#     'y': 2278368,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'HMAI',
#     'idarret': 671539,
#     'harret': '2018-06-19T08:55:42+00:00',
#     'x': 382846,
#     'sv': '1203',
#     'coordonnees': [47.469102, -0.54475158],
#     'idligne': 268435468,
#     'numarret': 11449},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54475158, 47.469102]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '1f2028b7e74b31c7314f4ab98fa191316dfae8d3',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': -112,
#     'novh': '822',
#     'dest': "LAC DE MAINE - L'HOIRIE",
#     'idparcours': 269166848,
#     'cap': 216,
#     'nomarret': 'GRAND MAINE',
#     'idvh': 268436278,
#     'iddesserte': 269166872,
#     'mnemoligne': '11',
#     'y': 2278313,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'GDMAIN-E',
#     'idarret': 671490,
#     'harret': '2018-06-19T08:54:49+00:00',
#     'x': 379173,
#     'sv': '1104',
#     'coordonnees': [47.467387, -0.59341426],
#     'idligne': 268435467,
#     'numarret': 15461},
#    'geometry': {'type': 'Point', 'coordinates': [-0.59341426, 47.467387]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '48bce3dfd575d9ee4003715c272c32cdccbfb365',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 149,
#     'novh': '1002',
#     'dest': 'AVRILLE ARDENNE',
#     'idparcours': 269419008,
#     'cap': 44,
#     'nomarret': 'FOCHMAISONBLEUEv2',
#     'idvh': 268436458,
#     'iddesserte': 269419017,
#     'mnemoligne': 'A',
#     'y': 2278380,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2FMBL',
#     'idarret': 671074,
#     'harret': '2018-06-19T08:54:50+00:00',
#     'x': 382489,
#     'sv': 'A09',
#     'coordonnees': [47.469092, -0.54948998],
#     'idligne': 268435471,
#     'numarret': 3788},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54948998, 47.469092]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd5b4b40f7c787ec86cd8f76e52d0a706e159b4bc',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 204,
#     'novh': '1004',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 177,
#     'nomarret': 'STRASBOURG',
#     'idvh': 268436460,
#     'iddesserte': 269451542,
#     'mnemoligne': 'A',
#     'y': 2277133,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1STRA',
#     'idarret': 671062,
#     'harret': '2018-06-19T08:55:24+00:00',
#     'x': 382084,
#     'sv': 'A02',
#     'coordonnees': [47.45775, -0.55425041],
#     'idligne': 268435471,
#     'numarret': 7319},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55425041, 47.45775]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '0c8dd8c5a708e0664d44a12784aefcf971125e97',
#    'fields': {'etat': 'HLPS',
#     'type': 'GX 327',
#     'ecart': 0,
#     'novh': '522',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 269148928,
#     'cap': 5,
#     'nomarret': 'SORTIE DEPOT ST BART',
#     'idvh': 268435978,
#     'iddesserte': 269148929,
#     'mnemoligne': '10',
#     'y': 2279046,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'DEPOT SD',
#     'idarret': 671375,
#     'harret': '2018-06-19T09:40:00+00:00',
#     'x': 386777,
#     'sv': '1002',
#     'coordonnees': [47.476481, -0.49296296],
#     'idligne': 268435466,
#     'numarret': 6562},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49296296, 47.476481]},
#    'record_timestamp': '2018-06-19T08:30:17+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '25d7cc7cf7b2468813876206d33006beb4ecefa5',
#    'fields': {'etat': 'TDEP',
#     'type': 'MAN City',
#     'ecart': 0,
#     'novh': '602',
#     'dest': 'BELLE BEILLE',
#     'idparcours': 268545536,
#     'cap': 287,
#     'nomarret': 'MONPLAISIR',
#     'idvh': 268436058,
#     'iddesserte': 268545537,
#     'mnemoligne': '01',
#     'y': 2280768,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'MONPLAIS',
#     'idarret': 671754,
#     'harret': '2018-06-19T08:56:00+00:00',
#     'x': 384172,
#     'sv': '0123',
#     'coordonnees': [47.491111, -0.52833384],
#     'idligne': 268435457,
#     'numarret': 4795},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52833384, 47.491111]},
#    'record_timestamp': '2018-06-19T08:51:15+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'f5a196e2c8dcbffe36742d6840765f591ee91e68',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 428,
#     'novh': '439',
#     'dest': 'TRELAZE ST LEZIN',
#     'idparcours': 269131264,
#     'cap': 71,
#     'nomarret': 'BUISSON',
#     'idvh': 268435895,
#     'iddesserte': 269131302,
#     'mnemoligne': '10',
#     'y': 2275147,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'BUISSO-E',
#     'idarret': 671232,
#     'harret': '2018-06-19T08:55:01+00:00',
#     'x': 387181,
#     'sv': '1010',
#     'coordonnees': [47.441564, -0.48574894],
#     'idligne': 268435466,
#     'numarret': 5587},
#    'geometry': {'type': 'Point', 'coordinates': [-0.48574894, 47.441564]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a1247a963a151e63fd05ad19fde1c5fcd369fd98',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 218,
#     'novh': '441',
#     'dest': 'ESPACE ANJOU',
#     'idparcours': 269062656,
#     'cap': 123,
#     'nomarret': 'MICHELET',
#     'idvh': 268435897,
#     'iddesserte': 269062678,
#     'mnemoligne': '09',
#     'y': 2277684,
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'mnemoarret': 'MICHEL-E',
#     'idarret': 671736,
#     'harret': '2018-06-19T08:55:37+00:00',
#     'x': 382852,
#     'sv': '0905',
#     'coordonnees': [47.462956, -0.54433947],
#     'idligne': 268435465,
#     'numarret': 5053},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54433947, 47.462956]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '22e54152c416fda5b3de7baf13381b018d92a6c0',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 23,
#     'novh': '532',
#     'dest': 'CIRCULAIRE SENS A',
#     'idparcours': 268774144,
#     'cap': 186,
#     'nomarret': 'THULEAU',
#     'idvh': 268435988,
#     'iddesserte': 268774157,
#     'mnemoligne': '05',
#     'y': 2279399,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'THULEAU',
#     'idarret': 672019,
#     'harret': '2018-06-19T08:55:11+00:00',
#     'x': 384129,
#     'sv': '0524',
#     'coordonnees': [47.478792, -0.52824191],
#     'idligne': 268435461,
#     'numarret': 17278},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52824191, 47.478792]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '1fcdc2e6526189c6064cfc71a846fa3ba03a94e4',
#    'fields': {'etat': 'HLPR',
#     'type': 'GX 327',
#     'ecart': 0,
#     'novh': '534',
#     'dest': 'ST BARTHELEMY',
#     'idparcours': 268707072,
#     'cap': 213,
#     'nomarret': 'ST BARTH COLLEGE',
#     'idvh': 268435990,
#     'iddesserte': 268707133,
#     'mnemoligne': '04',
#     'y': 2278174,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'SBARTHEL',
#     'idarret': 671963,
#     'harret': '2018-06-18T22:00:00+00:00',
#     'x': 385062,
#     'sv': '0427',
#     'coordonnees': [47.468086, -0.51528148],
#     'idligne': 268435460,
#     'numarret': 11134},
#    'geometry': {'type': 'Point', 'coordinates': [-0.51528148, 47.468086]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '183566835d3ff296e8ae815ad799eed75504ecbc',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': -118,
#     'novh': '543',
#     'dest': 'CIRCULAIRE SENS B',
#     'idparcours': 268807680,
#     'cap': 167,
#     'nomarret': 'PONT NOIR',
#     'idvh': 268435999,
#     'iddesserte': 268807697,
#     'mnemoligne': '05',
#     'y': 2278029,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'PONTNO-E',
#     'idarret': 671870,
#     'harret': '2018-06-19T08:56:00+00:00',
#     'x': 381723,
#     'sv': '0523',
#     'coordonnees': [47.465684, -0.55947279],
#     'idligne': 268435461,
#     'numarret': 4391},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55947279, 47.465684]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '30a353abe809221867cccbb106a130f8d25528ed',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 133,
#     'novh': '605',
#     'dest': 'AVRILLE ADEZIERE',
#     'idparcours': 268641536,
#     'cap': 343,
#     'nomarret': 'CENTRE COMMERCIAL',
#     'idvh': 268436061,
#     'iddesserte': 268641557,
#     'mnemoligne': '03',
#     'y': 2274515,
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'mnemoarret': 'CCOMMERC',
#     'idarret': 671264,
#     'harret': '2018-06-19T08:55:45+00:00',
#     'x': 384061,
#     'sv': '0322',
#     'coordonnees': [47.434868, -0.52678282],
#     'idligne': 268435459,
#     'numarret': 3146},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52678282, 47.434868]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'ef9ed2ba47ef35f349a711625a77488a3c741382',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 144,
#     'novh': '609',
#     'dest': 'BANCHAIS',
#     'idparcours': 268579072,
#     'cap': 314,
#     'nomarret': 'MADELEINE',
#     'idvh': 268436065,
#     'iddesserte': 268579099,
#     'mnemoligne': '02',
#     'y': 2277061,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'MADELEIN',
#     'idarret': 671697,
#     'harret': '2018-06-19T08:55:32+00:00',
#     'x': 383669,
#     'sv': '0211',
#     'coordonnees': [47.457625, -0.53320841],
#     'idligne': 268435458,
#     'numarret': 20411},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53320841, 47.457625]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '2fce171a2943ed93bdc50cb037542940828810f5',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': -102,
#     'novh': '610',
#     'dest': 'BEAUCOUZE  HAUTE ROCHE',
#     'idparcours': 268741632,
#     'cap': 290,
#     'nomarret': 'MAISON DE TECHNOPOLE',
#     'idvh': 268436066,
#     'iddesserte': 268741676,
#     'mnemoligne': '04',
#     'y': 2279594,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'BBMAT',
#     'idarret': 672763,
#     'harret': '2018-06-19T08:54:57+00:00',
#     'x': 378269,
#     'sv': '0422',
#     'coordonnees': [47.478597, -0.60603354],
#     'idligne': 268435460,
#     'numarret': 11748},
#    'geometry': {'type': 'Point', 'coordinates': [-0.60603354, 47.478597]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '1620d79e322a0e1e7267de6a3246c6d2e8d0a531',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 215,
#     'novh': '619',
#     'dest': 'BELLE BEILLE',
#     'idparcours': 268545536,
#     'cap': 178,
#     'nomarret': 'VAUGAREAU',
#     'idvh': 268436075,
#     'iddesserte': 268545542,
#     'mnemoligne': '01',
#     'y': 2279921,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'VAUGAREA',
#     'idarret': 672045,
#     'harret': '2018-06-19T08:55:14+00:00',
#     'x': 384258,
#     'sv': '0106',
#     'coordonnees': [47.483526, -0.52678381],
#     'idligne': 268435457,
#     'numarret': 31184},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52678381, 47.483526]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '894cde35a5be2a3613d9cbfdd813c7f2ecba2a69',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 41,
#     'novh': '656',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611584,
#     'cap': 259,
#     'nomarret': 'MUSSET',
#     'idvh': 268436112,
#     'iddesserte': 268611594,
#     'mnemoligne': '02',
#     'y': 2278866,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'MUSSET',
#     'idarret': 671788,
#     'harret': '2018-06-19T08:54:57+00:00',
#     'x': 383349,
#     'sv': '0204',
#     'coordonnees': [47.473744, -0.5383252],
#     'idligne': 268435458,
#     'numarret': 21453},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5383252, 47.473744]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '36b62334a7ff50c31051c6a0597240632d0ea15e',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 411,
#     'novh': '665',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611072,
#     'cap': 223,
#     'nomarret': 'FOCH HARAS',
#     'idvh': 268436121,
#     'iddesserte': 268611101,
#     'mnemoligne': '02',
#     'y': 2278235,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'HARAS-E',
#     'idarret': 671529,
#     'harret': '2018-06-19T08:55:18+00:00',
#     'x': 382333,
#     'sv': '0214',
#     'coordonnees': [47.467738, -0.5514873],
#     'idligne': 268435458,
#     'numarret': 3412},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5514873, 47.467738]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '31b621d7a932256f3844f32c315f3a643ef826dd',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 20,
#     'novh': '675',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611072,
#     'cap': 235,
#     'nomarret': 'PARC DES EXPOSITIONS',
#     'idvh': 268436131,
#     'iddesserte': 268611084,
#     'mnemoligne': '02',
#     'y': 2282050,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'PARCEXPO',
#     'idarret': 671809,
#     'harret': '2018-06-19T08:56:19+00:00',
#     'x': 387821,
#     'sv': '0216',
#     'coordonnees': [47.503822, -0.48054939],
#     'idligne': 268435458,
#     'numarret': 12773},
#    'geometry': {'type': 'Point', 'coordinates': [-0.48054939, 47.503822]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c733fa262074908e8a48a5db2ed96f0bd883293c',
#    'fields': {'etat': 'LIGN',
#     'type': 'AGORA123456789ABCDEFART',
#     'ecart': 234,
#     'novh': '701',
#     'dest': 'AVRILLE ADEZIERE',
#     'idparcours': 268641536,
#     'cap': 87,
#     'nomarret': 'LA BUISSAIE',
#     'idvh': 268436157,
#     'iddesserte': 268641538,
#     'mnemoligne': '03',
#     'y': 2270226,
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'mnemoarret': 'LABUISSA',
#     'idarret': 671611,
#     'harret': '2018-06-19T08:55:16+00:00',
#     'x': 381794,
#     'sv': '0301',
#     'coordonnees': [47.395567, -0.5547242],
#     'idligne': 268435459,
#     'numarret': 24161},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5547242, 47.395567]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'f48d83ae1fff87a101699f34fc3c268b8c3a139d',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 55,
#     'novh': '801',
#     'dest': 'EVENTARD par MONPLAISIR',
#     'idparcours': 269029376,
#     'cap': 188,
#     'nomarret': 'JEAN BOUIN',
#     'idvh': 268436257,
#     'iddesserte': 269029380,
#     'mnemoligne': '09',
#     'y': 2277198,
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'mnemoarret': 'JEBOUIN',
#     'idarret': 671582,
#     'harret': '2018-06-19T08:54:49+00:00',
#     'x': 383694,
#     'sv': '0906',
#     'coordonnees': [47.458864, -0.5329434],
#     'idligne': 268435465,
#     'numarret': 43885},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5329434, 47.458864]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '2b95f4212d5984812194c435ddf6d73e1896d6d1',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 11,
#     'novh': '802',
#     'dest': 'BOUCHEMAINE CHANTOURTEAU',
#     'idparcours': 268874240,
#     'cap': 216,
#     'nomarret': 'FOCH MAISON BLEUE',
#     'idvh': 268436258,
#     'iddesserte': 268874255,
#     'mnemoligne': '06',
#     'y': 2278438,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'FO-LOR-R',
#     'idarret': 671447,
#     'harret': '2018-06-19T08:55:11+00:00',
#     'x': 382540,
#     'sv': '0605',
#     'coordonnees': [47.469631, -0.54884214],
#     'idligne': 268435462,
#     'numarret': 170},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54884214, 47.469631]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'b96414f9cbe6797203811e2b9a4578f44c15f1d7',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 0,
#     'novh': '815',
#     'dest': 'CIRCULAIRE SENS B',
#     'idparcours': 268807680,
#     'cap': 348,
#     'nomarret': 'ARBORETUM',
#     'idvh': 268436271,
#     'iddesserte': 268807715,
#     'mnemoligne': '05',
#     'y': 2276174,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'ARBORETU',
#     'idarret': 671121,
#     'harret': '2018-06-19T08:54:49+00:00',
#     'x': 382800,
#     'sv': '0503',
#     'coordonnees': [47.449366, -0.54429462],
#     'idligne': 268435461,
#     'numarret': 32544},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54429462, 47.449366]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6f5b7c2626ab8d00785f9b5b0750ae9b211b3048',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': -1,
#     'novh': '823',
#     'dest': 'ZI EST',
#     'idparcours': 268840704,
#     'cap': 30,
#     'nomarret': 'GROUPE COMMERCIAL',
#     'idvh': 268436279,
#     'iddesserte': 268840721,
#     'mnemoligne': '06',
#     'y': 2275888,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'GRCPRUNI',
#     'idarret': 671519,
#     'harret': '2018-06-19T08:55:02+00:00',
#     'x': 378062,
#     'sv': '0601',
#     'coordonnees': [47.445216, -0.60693662],
#     'idligne': 268435462,
#     'numarret': 24782},
#    'geometry': {'type': 'Point', 'coordinates': [-0.60693662, 47.445216]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'f08398155e95e20b46fcba30878938d505f69be8',
#    'fields': {'etat': 'TARR',
#     'type': 'OmniSTDE6',
#     'ecart': 0,
#     'novh': '819',
#     'dest': 'BOUCHEMAINE CENTRE',
#     'idparcours': 268873728,
#     'cap': 164,
#     'nomarret': 'BOUCHEMAINE',
#     'idvh': 268436275,
#     'iddesserte': 268873778,
#     'mnemoligne': '06',
#     'y': 2273283,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'BOUCHE-E',
#     'idarret': 671213,
#     'harret': '2018-06-19T08:45:56+00:00',
#     'x': 377695,
#     'sv': '0607',
#     'coordonnees': [47.421677, -0.6105043],
#     'idligne': 268435462,
#     'numarret': 10804},
#    'geometry': {'type': 'Point', 'coordinates': [-0.6105043, 47.421677]},
#    'record_timestamp': '2018-06-19T08:46:17+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'bf0b6b6adfbde05aea4a9073e9a7c6eed437279d',
#    'fields': {'etat': 'TDEP',
#     'type': 'OmniSTDE6',
#     'ecart': 0,
#     'novh': '818',
#     'dest': 'BOUCHEMAINE CENTRE',
#     'idparcours': 268873728,
#     'cap': 262,
#     'nomarret': 'ZI. EST',
#     'idvh': 268436274,
#     'iddesserte': 268873729,
#     'mnemoligne': '06',
#     'y': 2278874,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'ZIEST',
# ...
#     'sv': '1204',
#     'coordonnees': [47.450489, -0.50466615],
#     'idligne': 268435468,
#     'numarret': 9180},
#    'geometry': {'type': 'Point', 'coordinates': [-0.50466615, 47.450489]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '7aa657468c72427e5d25dd577ff24717dfbbfea4',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 125,
#     'novh': '813',
#     'dest': 'ZI EST',
#     'idparcours': 268840192,
#     'cap': 92,
#     'nomarret': 'SAINT JACQUES',
#     'idvh': 268436269,
#     'iddesserte': 268840220,
#     'mnemoligne': '06',
#     'y': 2278980,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'SAJACQUE',
#     'idarret': 671959,
#     'harret': '2018-06-19T08:55:52+00:00',
#     'x': 380505,
#     'sv': '0604',
#     'coordonnees': [47.473827, -0.57608535],
#     'idligne': 268435462,
#     'numarret': 17939},
#    'geometry': {'type': 'Point', 'coordinates': [-0.57608535, 47.473827]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '161cd571ad2dc70fadfb2d47376533bad80809ca',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSDTE6',
#     'ecart': -117,
#     'novh': '821',
#     'dest': 'BOUCHEMAINE CHANTOURTEAU',
#     'idparcours': 268874240,
#     'cap': 210,
#     'nomarret': 'VAL DE MAINE',
#     'idvh': 268436277,
#     'iddesserte': 268874282,
#     'mnemoligne': '06',
#     'y': 2275883,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'VALDEMAI',
#     'idarret': 672029,
#     'harret': '2018-06-19T08:55:43+00:00',
#     'x': 378059,
#     'sv': '0609',
#     'coordonnees': [47.44517, -0.60697389],
#     'idligne': 268435462,
#     'numarret': 31960},
#    'geometry': {'type': 'Point', 'coordinates': [-0.60697389, 47.44517]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '1f0724e843448d3e4454ec7bf0f4ec5a1570ca5f',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 21,
#     'novh': '1001',
#     'dest': 'AVRILLE ARDENNE',
#     'idparcours': 269419008,
#     'cap': 38,
#     'nomarret': 'BAMAKO',
#     'idvh': 268436457,
#     'iddesserte': 269419012,
#     'mnemoligne': 'A',
#     'y': 2276515,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2BAMA',
#     'idarret': 671067,
#     'harret': '2018-06-19T08:54:51+00:00',
#     'x': 381902,
#     'sv': 'A01',
#     'coordonnees': [47.452134, -0.55636088],
#     'idligne': 268435471,
#     'numarret': 30251},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55636088, 47.452134]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '230c927c9a060c0b8e5dfc9fcdd4198820236236',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 148,
#     'novh': '1003',
#     'dest': 'AVRILLE ARDENNE',
#     'idparcours': 269419008,
#     'cap': 334,
#     'nomarret': 'PLATEAU MAYENNE',
#     'idvh': 268436459,
#     'iddesserte': 269419029,
#     'mnemoligne': 'A',
#     'y': 2281444,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2PMAY',
#     'idarret': 671084,
#     'harret': '2018-06-19T08:55:51+00:00',
#     'x': 380286,
#     'sv': 'A08',
#     'coordonnees': [47.495902, -0.5802018],
#     'idligne': 268435471,
#     'numarret': 4961},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5802018, 47.495902]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a25ad9020687e6782c8f7e7739c903a92c32c886',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 36,
#     'novh': '1012',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 154,
#     'nomarret': 'BOIS DU ROY',
#     'idvh': 268436468,
#     'iddesserte': 269451525,
#     'mnemoligne': 'A',
#     'y': 2282216,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1BROY',
#     'idarret': 671045,
#     'harret': '2018-06-19T08:55:56+00:00',
#     'x': 379905,
#     'sv': 'A05',
#     'coordonnees': [47.502714, -0.5856359],
#     'idligne': 268435471,
#     'numarret': 32629},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5856359, 47.502714]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6bc00b133c0eed3ca8506f4da939cd3aa85f0040',
#    'fields': {'etat': 'TDEP',
#     'type': 'OmniSTDE6',
#     'ecart': 0,
#     'novh': '820',
#     'dest': "LAC DE MAINE - L'HOIRIE",
#     'idparcours': 269164800,
#     'cap': 260,
#     'nomarret': 'ROCHE MORNA',
#     'idvh': 268436276,
#     'iddesserte': 269164801,
#     'mnemoligne': '11',
#     'y': 2273041,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'ROMORNA',
#     'idarret': 671938,
#     'harret': '2018-06-19T08:55:00+00:00',
#     'x': 379881,
#     'sv': '1102',
#     'coordonnees': [47.420235, -0.58143286],
#     'idligne': 268435467,
#     'numarret': 32360},
#    'geometry': {'type': 'Point', 'coordinates': [-0.58143286, 47.420235]},
#    'record_timestamp': '2018-06-19T08:52:37+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd110e1c9e41eb28cc65d5fb9906627c0ca61e895',
#    'fields': {'etat': 'TDEP',
#     'type': 'GX 327',
#     'ecart': 0,
#     'novh': '530',
#     'dest': 'CIRCULAIRE SENS A',
#     'idparcours': 268774144,
#     'cap': 180,
#     'nomarret': 'AQUA VITA',
#     'idvh': 268435986,
#     'iddesserte': 268774145,
#     'mnemoligne': '05',
#     'y': 2281090,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'AQUA-D5A',
#     'idarret': 672579,
#     'harret': '2018-06-19T09:01:00+00:00',
#     'x': 381387,
#     'sv': '0502',
#     'coordonnees': [47.493087, -0.56542577],
#     'idligne': 268435461,
#     'numarret': 55947},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56542577, 47.493087]},
#    'record_timestamp': '2018-06-19T08:49:12+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '480c257c4a57c1a8d6db8aec5735b24d657699a8',
#    'fields': {'etat': 'TDEP',
#     'type': 'CITADIS',
#     'ecart': 0,
#     'novh': '1009',
#     'dest': 'AVRILLE ARDENNE',
#     'idparcours': 269419008,
#     'cap': 44,
#     'nomarret': 'ANGERS - ROSERAIE',
#     'idvh': 268436465,
#     'iddesserte': 269419009,
#     'mnemoligne': 'A',
#     'y': 2275597,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2ANRO',
#     'idarret': 671066,
#     'harret': '2018-06-19T08:58:30+00:00',
#     'x': 382049,
#     'sv': 'A03',
#     'coordonnees': [47.443931, -0.55396511],
#     'idligne': 268435471,
#     'numarret': 32091},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55396511, 47.443931]},
#    'record_timestamp': '2018-06-19T08:54:16+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '056dfb2f15e4ef1d3945b94183f2519279d3b11d',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 59,
#     'novh': '436',
#     'dest': 'SCHWEITZER',
#     'idparcours': 269098240,
#     'cap': 26,
#     'nomarret': 'CARNOT Supprimé',
#     'idvh': 268435892,
#     'iddesserte': 269098276,
#     'mnemoligne': '10',
#     'y': 2278831,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'CARNOT-E',
#     'idarret': 671253,
#     'harret': '2018-06-19T08:57:09+00:00',
#     'x': 382799,
#     'sv': '1008',
#     'coordonnees': [47.473249, -0.54559986],
#     'idligne': 268435466,
#     'numarret': 8689},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54559986, 47.473249]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '2c7d2ad67790f429eaf5ad4ca04ddd350f0335bb',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 24,
#     'novh': '452',
#     'dest': 'HAUTE DE RECULEE',
#     'idparcours': 268972288,
#     'cap': 86,
#     'nomarret': 'GEORGE SAND',
#     'idvh': 268435908,
#     'iddesserte': 268972296,
#     'mnemoligne': '08',
#     'y': 2274353,
#     'nomligne': 'PONTS CE <>  AQUAVITA H. RECULEE',
#     'mnemoarret': 'GGESSAND',
#     'idarret': 671504,
#     'harret': '2018-06-19T08:54:53+00:00',
#     'x': 384555,
#     'sv': '0821',
#     'coordonnees': [47.433573, -0.5201602],
#     'idligne': 268435464,
#     'numarret': 18970},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5201602, 47.433573]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'abb9c3fdc7e92b38615dfa2359b4ff247c92c750',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': -119,
#     'novh': '536',
#     'dest': 'SORGES',
#     'idparcours': 269130752,
#     'cap': 132,
#     'nomarret': 'MORELLERIE',
#     'idvh': 268435992,
#     'iddesserte': 269130772,
#     'mnemoligne': '10',
#     'y': 2276781,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'MORELL-E',
#     'idarret': 671779,
#     'harret': '2018-06-19T08:55:37+00:00',
#     'x': 382544,
#     'sv': '1006',
#     'coordonnees': [47.454737, -0.54798241],
#     'idligne': 268435466,
#     'numarret': 16834},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54798241, 47.454737]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'e5812a9ccb0bd902d9a22e36d4fe05cd190e17cd',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 137,
#     'novh': '541',
#     'dest': 'SAINTE GEMMES',
#     'idparcours': 269198848,
#     'cap': 42,
#     'nomarret': 'POISSONNERIE',
#     'idvh': 268435997,
#     'iddesserte': 269198863,
#     'mnemoligne': '11',
#     'y': 2278183,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'POISSONN',
#     'idarret': 671863,
#     'harret': '2018-06-19T08:56:38+00:00',
#     'x': 381156,
#     'sv': '1122',
#     'coordonnees': [47.46688, -0.56706411],
#     'idligne': 268435467,
#     'numarret': 29689},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56706411, 47.46688]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '970584f6ee3dc808db238005d8da0cac59de5961',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': -33,
#     'novh': '611',
#     'dest': 'MONPLAISIR',
#     'idparcours': 268513024,
#     'cap': 80,
#     'nomarret': 'FOCH HARAS',
#     'idvh': 268436067,
#     'iddesserte': 268513046,
#     'mnemoligne': '01',
#     'y': 2277961,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'HARAS',
#     'idarret': 671528,
#     'harret': '2018-06-19T08:56:09+00:00',
#     'x': 382009,
#     'sv': '0126',
#     'coordonnees': [47.465167, -0.55564852],
#     'idligne': 268435457,
#     'numarret': 20835},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55564852, 47.465167]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a777f1ace4019b5f775a24a70db74c8a946649ce',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 47,
#     'novh': '618',
#     'dest': "BEAUCOUZE L'ATOLL",
#     'idparcours': 268739072,
#     'cap': 263,
#     'nomarret': 'GARES PAPIN',
#     'idvh': 268436074,
#     'iddesserte': 268739101,
#     'mnemoligne': '04',
#     'y': 2277966,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'GAREPA-E',
#     'idarret': 671475,
#     'harret': '2018-06-19T08:54:47+00:00',
#     'x': 381874,
#     'sv': '0410',
#     'coordonnees': [47.465168, -0.55744044],
#     'idligne': 268435460,
#     'numarret': 715},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55744044, 47.465168]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c19095510a59102cdeb093f2b3798b1ca4c5e4a0',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': -32,
#     'novh': '653',
#     'dest': 'MURS ERIGNE',
#     'idparcours': 268674560,
#     'cap': 39,
#     'nomarret': 'LEVESQUE',
#     'idvh': 268436109,
#     'iddesserte': 268674615,
#     'mnemoligne': '03',
#     'y': 2270822,
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'mnemoarret': 'LEVESQ-E',
#     'idarret': 671664,
#     'harret': '2018-06-19T08:55:48+00:00',
#     'x': 383712,
#     'sv': '0328',
#     'coordonnees': [47.401557, -0.52962107],
#     'idligne': 268435459,
#     'numarret': 29876},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52962107, 47.401557]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '3dcde40073a7428c513a255b9f510d94917b4c08',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 8,
#     'novh': '669',
#     'dest': 'BANCHAIS',
#     'idparcours': 268579072,
#     'cap': 260,
#     'nomarret': 'BANCHAIS',
#     'idvh': 268436125,
#     'iddesserte': 268579120,
#     'mnemoligne': '02',
#     'y': 2280129,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'BANCSTMA',
#     'idarret': 671154,
#     'harret': '2018-06-19T08:55:08+00:00',
#     'x': 385403,
#     'sv': '0201',
#     'coordonnees': [47.48577, -0.51170084],
#     'idligne': 268435458,
#     'numarret': 20610},
#    'geometry': {'type': 'Point', 'coordinates': [-0.51170084, 47.48577]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'bdf823031297320af34641d34d5b600511bb478e',
#    'fields': {'etat': 'DEVP',
#     'type': 'OMNIART',
#     'ecart': 3,
#     'novh': '673',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611072,
#     'cap': 139,
#     'nomarret': 'QUANTINIERE',
#     'idvh': 268436129,
#     'iddesserte': 268611128,
#     'mnemoligne': '02',
#     'y': 2276185,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'QUANTI-E',
#     'idarret': 672665,
#     'harret': '2018-06-19T08:54:35+00:00',
#     'x': 388159,
#     'sv': '0208',
#     'coordonnees': [47.45121, -0.4732824],
#     'idligne': 268435458,
#     'numarret': 83420},
#    'geometry': {'type': 'Point', 'coordinates': [-0.4732824, 47.45121]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '5927b0379c66aab1b64ccc75e4dcb8e69a9fe431',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniArtE6',
#     'ecart': 8,
#     'novh': '678',
#     'dest': "BEAUCOUZE L'ATOLL",
#     'idparcours': 268739072,
#     'cap': 152,
#     'nomarret': "L'ATOLL - BEAUCOUZE",
#     'idvh': 268436134,
#     'iddesserte': 268739132,
#     'mnemoligne': '04',
#     'y': 2280493,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'ATOLLBEA',
#     'idarret': 672520,
#     'harret': '2018-06-19T08:55:08+00:00',
#     'x': 376634,
#     'sv': '0408',
#     'coordonnees': [47.486125, -0.62816077],
#     'idligne': 268435460,
#     'numarret': 20041},
#    'geometry': {'type': 'Point', 'coordinates': [-0.62816077, 47.486125]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '3ad238cd9a5428b65f240fab9f26c0ecd34e4c3b',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniArtE6',
#     'ecart': -235,
#     'novh': '686',
#     'dest': 'BELLE BEILLE',
#     'idparcours': 268545536,
#     'cap': 291,
#     'nomarret': 'I U T',
#     'idvh': 268436142,
#     'iddesserte': 268545573,
#     'mnemoligne': '01',
#     'y': 2279771,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'I U T -E',
#     'idarret': 671554,
#     'harret': '2018-06-19T08:54:55+00:00',
#     'x': 378553,
#     'sv': '0128',
#     'coordonnees': [47.480284, -0.60235594],
#     'idligne': 268435457,
#     'numarret': 31087},
#    'geometry': {'type': 'Point', 'coordinates': [-0.60235594, 47.480284]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6898f9644086f005a620ca7f8541875967116336',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 122,
#     'novh': '816',
#     'dest': 'ESPACE ANJOU',
#     'idparcours': 269062656,
#     'cap': 206,
#     'nomarret': 'FACULTE ST SERGE',
#     'idvh': 268436272,
#     'iddesserte': 269062669,
#     'mnemoligne': '09',
#     'y': 2280143,
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'mnemoarret': 'FACUL-SS',
#     'idarret': 671434,
#     'harret': '2018-06-19T08:56:55+00:00',
#     'x': 382663,
#     'sv': '0904',
#     'coordonnees': [47.484997, -0.54804167],
#     'idligne': 268435465,
#     'numarret': 7400},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54804167, 47.484997]},
#    'record_timestamp': '2018-06-19T08:54:56+00:00'}]}

# %% [markdown]
# # Remplissage de DataFrame

# %% [markdown]
# On peut construire une `DataFrame` directement à partir d'un "dictionnaires de colonnes".

# %%
df = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [3, 4, 1]
})

df
# Out:
#    a  b
# 0  1  3
# 1  2  4
# 2  3  1

# %% [markdown]
# Par exemple, listons les arrêts, leur id, leur nom et leurs coordonnées GPS.

# %%
dd = g.json()['records']

# %%
dd[0]
# Out:
# {'datasetid': 'bus-tram-position-tr',
#  'recordid': '14c506f09a99d91c098950a3fe823121db098640',
#  'fields': {'etat': 'HLPS',
#   'type': 'OmniArtE6',
#   'ecart': 0,
#   'novh': '681',
#   'dest': 'PAS EN SERVICE',
#   'idparcours': 268721408,
#   'cap': 95,
#   'nomarret': 'SORTIE BUS CTB',
#   'idvh': 268436137,
#   'iddesserte': 268721409,
#   'mnemoligne': '04',
#   'y': 2281381,
#   'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#   'mnemoarret': 'SDCTB',
#   'idarret': 671973,
#   'harret': '2018-06-19T06:53:55+00:00',
#   'x': 381077,
#   'sv': '0423',
#   'coordonnees': [47.4956, -0.56967987],
#   'idligne': 268435460,
#   'numarret': 17220},
#  'geometry': {'type': 'Point', 'coordinates': [-0.56967987, 47.4956]},
#  'record_timestamp': '2018-06-19T06:57:17+00:00'}

# %%
#Arret
id_arret = [elem['fields']['idarret'] for elem in dd]
nom_arret = [elem['fields']['nomarret'] for elem in dd]
mne_arret = [elem['fields']['mnemoarret'] for elem in dd]

arret = pd.DataFrame({
    'id_arret': id_arret,
    'nom_arret': nom_arret,
    'mne_arret': mne_arret
})

arret.info()

arret.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 3 columns):
# id_arret     106 non-null int64
# nom_arret    106 non-null object
# mne_arret    106 non-null object
# dtypes: int64(1), object(2)
# memory usage: 2.6+ KB
#     id_arret          nom_arret mne_arret
# 94    671253    CARNOT Supprimé  CARNOT-E
# 20    672772      MARIUS BRIANT  MBRIAN-E
# 21    671059         RALLIEMENT     1RALL
# 12    671269            CEZANNE   CEZAN-E
# 88    671067             BAMAKO     2BAMA
# 7     671263  CENTRE COMMERCIAL  CCOMME-E
# 34    671977        GARE SEMARD    SEMARD
# 55    671582         JEAN BOUIN   JEBOUIN
# 48    671697          MADELEINE  MADELEIN
# 27    672581          AQUA VITA  AQVI-D5B

# %%
#Bus
id_vh = [elem['fields']['idvh'] for elem in dd]
type_vh = [elem['fields']['type'] for elem in dd]
etat_vh = [elem['fields']['etat'] for elem in dd]

bus = pd.DataFrame({
    'id_vh': id_vh,
    'type_vh': type_vh,
    'etat_vh': etat_vh
})

bus.info()

bus.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 3 columns):
# id_vh      106 non-null int64
# type_vh    106 non-null object
# etat_vh    106 non-null object
# dtypes: int64(1), object(2)
# memory usage: 2.6+ KB
#         id_vh    type_vh etat_vh
# 26  268436466    CITADIS    TDEP
# 55  268436257  OmniSTDE6    LIGN
# 67  268435900   OMNICITY    LIGN
# 3   268436120    OMNIART    HLPS
# 14  268436079   MAN City    LIGN
# 69  268435911   OMNICITY    DEVP
# 81  268436123    OMNIART    LIGN
# 64  268436077   MAN City    TDEP
# 21  268436461    CITADIS    LIGN
# 16  268436110    OMNIART    LIGN

# %%
#Ligne
id_ligne = [elem['fields']['idligne'] for elem in dd]
nom_ligne = [elem['fields']['nomligne'] for elem in dd]
mne_ligne = [elem['fields']['mnemoligne'] for elem in dd]

ligne = pd.DataFrame({
    'id_ligne': id_arret,
    'nom_ligne': nom_ligne,
    'mne_ligne': mne_ligne
})

ligne.info()

ligne
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 3 columns):
# id_ligne     106 non-null int64
# nom_ligne    106 non-null object
# mne_ligne    106 non-null object
# dtypes: int64(1), object(2)
# memory usage: 2.6+ KB
#      id_ligne                         nom_ligne mne_ligne
# 0      671973        BEAUCOUZE <> ST BARTHELEMY        04
# 1      671375        BEAUCOUZE <> ST BARTHELEMY        04
# 2      671375           BOUCHEMAINE <> Z I  EST        06
# 3      671973        BELLE BEILLE <> MONPLAISIR        01
# 4      671157   M-MARCILLE <> ST AUBIN LA SALLE        12
# 5      672636                Piscine MONPLAISIR       535
# 6      671593   M-MARCILLE <> ST AUBIN LA SALLE        12
# 7      671263  PONTS CE <>  AQUAVITA H. RECULEE        08
# 8      671507    CIRCULAIRE VERNEAU GARE EUROPE        05
# 9      672042     ST LEZIN SORGES <> SCHWEITZER        10
# 10     671756        BELLE BEILLE <> MONPLAISIR        01
# 11     671757        BELLE BEILLE <> MONPLAISIR        01
# 12     671269        BEAUCOUZE <> ST BARTHELEMY        04
# 13     672044        BELLE BEILLE <> MONPLAISIR        01
# 14     671816   MURS ERIGNE <> ADEZIERE SALETTE        03
# 15     671845        BEAUCOUZE <> ST BARTHELEMY        04
# 16     671680     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 17     671607        BEAUCOUZE <> ST BARTHELEMY        04
# 18     672020     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 19     671177        BEAUCOUZE <> ST BARTHELEMY        04
# 20     672772           BOUCHEMAINE <> Z I  EST        06
# 21     671059               ARDENNE <> ROSERAIE         A
# 22     671046               ARDENNE <> ROSERAIE         A
# 23     671076               ARDENNE <> ROSERAIE         A
# 24     671540       HOPITAL <> MONTREUIL JUIGNE        07
# 25     671667  LAC MAINE <> STE GEMMES CL ANJOU        11
# 26     671064               ARDENNE <> ROSERAIE         A
# 27     672581    CIRCULAIRE VERNEAU GARE EUROPE        05
# 28     671741     ST LEZIN SORGES <> SCHWEITZER        10
# 29     672637                  Piscine ROSERAIE       533
# ..        ...                               ...       ...
# 76     671711     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 77     671099   MURS ERIGNE <> ADEZIERE SALETTE        03
# 78     671476        BEAUCOUZE <> ST BARTHELEMY        04
# 79     671160     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 80     672053        BEAUCOUZE <> ST BARTHELEMY        04
# 81     671328   MURS ERIGNE <> ADEZIERE SALETTE        03
# 82     671792        BELLE BEILLE <> MONPLAISIR        01
# 83     672022   MURS ERIGNE <> ADEZIERE SALETTE        03
# 84     671149   MURS ERIGNE <> ADEZIERE SALETTE        03
# 85     671915   M-MARCILLE <> ST AUBIN LA SALLE        12
# 86     671959           BOUCHEMAINE <> Z I  EST        06
# 87     672029           BOUCHEMAINE <> Z I  EST        06
# 88     671067               ARDENNE <> ROSERAIE         A
# 89     671084               ARDENNE <> ROSERAIE         A
# 90     671045               ARDENNE <> ROSERAIE         A
# 91     671938  LAC MAINE <> STE GEMMES CL ANJOU        11
# 92     672579    CIRCULAIRE VERNEAU GARE EUROPE        05
# 93     671066               ARDENNE <> ROSERAIE         A
# 94     671253     ST LEZIN SORGES <> SCHWEITZER        10
# 95     671504  PONTS CE <>  AQUAVITA H. RECULEE        08
# 96     671779     ST LEZIN SORGES <> SCHWEITZER        10
# 97     671863  LAC MAINE <> STE GEMMES CL ANJOU        11
# 98     671528        BELLE BEILLE <> MONPLAISIR        01
# 99     671475        BEAUCOUZE <> ST BARTHELEMY        04
# 100    671664   MURS ERIGNE <> ADEZIERE SALETTE        03
# 101    671154     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 102    672665     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 103    672520        BEAUCOUZE <> ST BARTHELEMY        04
# 104    671554        BELLE BEILLE <> MONPLAISIR        01
# 105    671434          ESPACE ANJOU <> EVENTARD        09
#
# [106 rows x 3 columns]

# %%
#Trajet
id_bus = [elem['fields']['idvh'] for elem in dd]
id_ligne = [elem['fields']['idligne'] for elem in dd]
latitude = [elem['fields']['coordonnees'][0] for elem in dd]
longitude = [elem['fields']['coordonnees'][1] for elem in dd]

trajet = pd.DataFrame({
    'id_bus': id_bus,
    'id_ligne': id_ligne,
    'latitude': latitude,
    'longitude': longitude
})

trajet.info()

trajet
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 4 columns):
# id_bus       106 non-null int64
# id_ligne     106 non-null int64
# latitude     106 non-null float64
# longitude    106 non-null float64
# dtypes: float64(2), int64(2)
# memory usage: 3.4 KB
#         id_bus   id_ligne   latitude  longitude
# 0    268436137  268435460  47.495600  -0.569680
# 1    268436259  268435460  47.476323  -0.492809
# 2    268435899  268435462  47.475119  -0.492731
# 3    268436120  268435457  47.495681  -0.569286
# 4    268435905  268435468  47.489367  -0.503753
# 5    268435879  268435515  47.486526  -0.521209
# 6    268435909  268435468  47.469206  -0.540589
# 7    268435910  268435464  47.437790  -0.526913
# 8    268435913  268435461  47.474968  -0.524890
# 9    268435994  268435466  47.483529  -0.528484
# 10   268436057  268435457  47.475135  -0.561978
# 11   268436059  268435457  47.474289  -0.566658
# 12   268436072  268435460  47.469187  -0.492376
# 13   268436078  268435457  47.482320  -0.526799
# 14   268436079  268435459  47.464628  -0.548770
# 15   268436107  268435460  47.471264  -0.628528
# 16   268436110  268435458  47.469059  -0.549369
# 17   268436126  268435460  47.474636  -0.599694
# 18   268436139  268435458  47.460064  -0.475992
# 19   268436145  268435460  47.471839  -0.539324
# 20   268436270  268435462  47.473771  -0.574728
# 21   268436461  268435471  47.472471  -0.552979
# 22   268436470  268435471  47.489539  -0.552524
# 23   268436472  268435471  47.481567  -0.553831
# 24   268435912  268435463  47.480655  -0.555043
# 25   268435889  268435467  47.467123  -0.618315
# 26   268436466  268435471  47.511458  -0.595814
# 27   268435996  268435461  47.493159  -0.565430
# 28   268435891  268435466  47.455402  -0.529572
# 29   268435904  268435513  47.443922  -0.563690
# ..         ...        ...        ...        ...
# 76   268436108  268435458  47.444240  -0.490402
# 77   268436111  268435459  47.453230  -0.541266
# 78   268436114  268435460  47.464962  -0.557376
# 79   268436115  268435458  47.515426  -0.474521
# 80   268436118  268435460  47.471095  -0.486478
# 81   268436123  268435459  47.484807  -0.585463
# 82   268436141  268435457  47.480696  -0.594266
# 83   268436160  268435459  47.476229  -0.566127
# 84   268436162  268435459  47.505437  -0.595443
# 85   268436267  268435468  47.450489  -0.504666
# 86   268436269  268435462  47.473827  -0.576085
# 87   268436277  268435462  47.445170  -0.606974
# 88   268436457  268435471  47.452134  -0.556361
# 89   268436459  268435471  47.495902  -0.580202
# 90   268436468  268435471  47.502714  -0.585636
# 91   268436276  268435467  47.420235  -0.581433
# 92   268435986  268435461  47.493087  -0.565426
# 93   268436465  268435471  47.443931  -0.553965
# 94   268435892  268435466  47.473249  -0.545600
# 95   268435908  268435464  47.433573  -0.520160
# 96   268435992  268435466  47.454737  -0.547982
# 97   268435997  268435467  47.466880  -0.567064
# 98   268436067  268435457  47.465167  -0.555649
# 99   268436074  268435460  47.465168  -0.557440
# 100  268436109  268435459  47.401557  -0.529621
# 101  268436125  268435458  47.485770  -0.511701
# 102  268436129  268435458  47.451210  -0.473282
# 103  268436134  268435460  47.486125  -0.628161
# 104  268436142  268435457  47.480284  -0.602356
# 105  268436272  268435465  47.484997  -0.548042
#
# [106 rows x 4 columns]

# %%
#Etape
id_arret = [elem['fields']['idarret'] for elem in dd]
harret = [elem['fields']['harret'] for elem in dd]
record_timestamp = [elem['record_timestamp'] for elem in dd]
ecart = [elem['fields']['ecart'] for elem in dd]

def transfo(row):
    return record_timestamp + dt.timedelta(seconds=ecart)

heure_estime = df.apply(transfo, axis='columns')

etape = pd.DataFrame({
    'id_arret': id_arret,
    'heure_theorique': harret,
    'heure_estime': heure_estime,
    'ecart': ecart
})

etape.info()

etape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-7168337e6fbf> in <module>()
#       8     return record_timestamp + dt.timedelta(seconds=ecart)
#       9
# ---> 10 heure_estime = df.apply(transfo, axis='columns')
#      11
#      12 etape = pd.DataFrame({
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# D:\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# D:\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# D:\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-19-7168337e6fbf> in transfo(row)
#       6
#       7 def transfo(row):
# ----> 8     return record_timestamp + dt.timedelta(seconds=ecart)
#       9
#      10 heure_estime = df.apply(transfo, axis='columns')
#
# TypeError: ('unsupported type for timedelta seconds component: list', 'occurred at index 0')
