# %% [markdown]
# # Import des modules nécessaires

# %%
    # Pour manipuler efficacement des tables de données dans Python
    import pandas as pd

    # Pour faire des requêtes GET et POST
    import requests

# %%
print(pd.__version__)
# Out:
# 0.23.0

# %%
print(requests.__version__)
# Out:
# 2.18.4

# %% [markdown]
# # Requêtage d'une API REST

# %% [markdown]
# Pour lancer une requête GET, c'est ultra-simple : on utilise `requests.get(url)`.
#
# Si vous voulez glisser des paramètres avec la requête, utilisez l'argument optionnel `params`, qui accepte un simple dictionnaire.

# %%
r = requests.get("https://data.angers.fr/api/records/1.0/search/",
                 params={
                     'dataset': 'horaires-theoriques-et-arrets-du-reseau-irigo-gtfs',
                     'rows': 10
                 })

# %%
g = requests.get("https://data.angers.fr/api/records/1.0/search/",
                 params={
                     'dataset': 'bus-tram-position-tr',
                     'rows': 200
                 })

# %% [markdown]
# Regardons la nature de ce qui nous est renvoyé.

# %%
type(g)
# Out:
# requests.models.Response

# %% [markdown]
# C'est un objet de la classe `Response`. Si vous voulez connaitre toutes les méthodes attachées, faites `help(r)`

# %%
help(g)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, state)
#  |
#  |  close(self)
#  |      Releases the connection back to the pool. Once this method has been
#  |      called the underlying ``raw`` object must not be accessed again.
#  |
#  |      *Note: Should not normally need to be called explicitly.*
#  |
#  |  iter_content(self, chunk_size=1, decode_unicode=False)
#  |      Iterates over the response data.  When stream=True is set on the
#  |      request, this avoids reading the content at once into memory for
#  |      large responses.  The chunk size is the number of bytes it should
#  |      read into memory.  This is not necessarily the length of each item
#  |      returned as decoding can take place.
#  |
#  |      chunk_size must be of type int or None. A value of None will
#  |      function differently depending on the value of `stream`.
#  |      stream=True will read data as it arrives in whatever size the
#  |      chunks are received. If stream=False, data is returned as
#  |      a single chunk.
#  |
#  |      If decode_unicode is True, content will be decoded using the best
#  |      available encoding based on the response.
#  |
#  |  iter_lines(self, chunk_size=512, decode_unicode=None, delimiter=None)
#  |      Iterates over the response data, one line at a time.  When
#  |      stream=True is set on the request, this avoids reading the
#  |      content at once into memory for large responses.
#  |
#  |      .. note:: This method is not reentrant safe.
#  |
#  |  json(self, **kwargs)
#  |      Returns the json-encoded content of a response, if any.
#  |
#  |      :param \*\*kwargs: Optional arguments that ``json.loads`` takes.
#  |      :raises ValueError: If the response body does not contain valid json.
#  |
#  |  raise_for_status(self)
#  |      Raises stored :class:`HTTPError`, if one occurred.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  apparent_encoding
#  |      The apparent encoding, provided by the chardet library.
#  |
#  |  content
#  |      Content of the response, in bytes.
#  |
#  |  is_permanent_redirect
#  |      True if this Response one of the permanent versions of redirect.
#  |
#  |  is_redirect
#  |      True if this Response is a well-formed HTTP redirect that could have
#  |      been processed automatically (by :meth:`Session.resolve_redirects`).
#  |
#  |  links
#  |      Returns the parsed header links of the response, if any.
#  |
#  |  next
#  |      Returns a PreparedRequest for the next request in a redirect chain, if there is one.
#  |
#  |  ok
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  text
#  |      Content of the response, in unicode.
#  |
#  |      If Response.encoding is None, encoding will be guessed using
#  |      ``chardet``.
#  |
#  |      The encoding of the response content is determined based solely on HTTP
#  |      headers, following RFC 2616 to the letter. If you can take advantage of
#  |      non-HTTP knowledge to make a better guess at the encoding, you should
#  |      set ``r.encoding`` appropriately before accessing this property.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __attrs__ = ['_content', 'status_code', 'headers', 'url', 'history', '...

# %% [markdown]
# Pour tester que tout a bien fonctionnné, on va vérifié le statut.

# %%
g.raise_for_status()

# %% [markdown]
# Si ça dit rien c'est que c'est bon :) Dans le doute, regardons le statut...

# %%
g.status_code
# Out:
# 200

# %% [markdown]
# Statut 200 = succès !!

# %% [markdown]
# Pour récupérer le contenu de la réponse, vous pouvez utiliser `r.text`.
#
# Il y a aussi un décodeur JSON, si on sait que la réponse est dans ce format. Du coup, il parse le JSON et rend un dictionnaire !

# %%
g.json()
# Out:
# {'nhits': 134,
#  'parameters': {'dataset': ['bus-tram-position-tr'],
#   'timezone': 'UTC',
#   'rows': 200,
#   'format': 'json'},
#  'records': [{'datasetid': 'bus-tram-position-tr',
#    'recordid': '7d38ad93bae9122ed8d759dbf052ddecb200ded5',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 427 Hyb',
#     'ecart': 338,
#     'novh': '201',
#     'dest': 'BEAUCOUZE  HAUTE ROCHE',
#     'idparcours': 268741632,
#     'cap': 6,
#     'nomarret': 'GAUBERT',
#     'idvh': 268435657,
#     'iddesserte': 268741673,
#     'mnemoligne': '04',
#     'y': 2278950,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'GAUBER-E',
#     'idarret': 669723,
#     'harret': '2018-06-18T13:59:43+00:00',
#     'x': 378709,
#     'sv': '0407',
#     'coordonnees': [47.472957, -0.59988059],
#     'idligne': 268435460,
#     'numarret': 12547},
#    'geometry': {'type': 'Point', 'coordinates': [-0.59988059, 47.472957]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '4e6a006e5d11d44958fc3937dbaa402118a90737',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 132,
#     'novh': '425',
#     'dest': 'TRELAZE ST LEZIN',
#     'idparcours': 269131264,
#     'cap': 76,
#     'nomarret': 'DE LATTRE',
#     'idvh': 268435881,
#     'iddesserte': 269131285,
#     'mnemoligne': '10',
#     'y': 2276503,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'DELATR-E',
#     'idarret': 669609,
#     'harret': '2018-06-18T13:58:32+00:00',
#     'x': 382983,
#     'sv': '1008',
#     'coordonnees': [47.452383, -0.54202936],
#     'idligne': 268435466,
#     'numarret': 25487},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54202936, 47.452383]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '1fd516059c0bf544c7241ec3ee006cfe9b15987e',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 331,
#     'novh': '428',
#     'dest': 'CHU - HOPITAL',
#     'idparcours': 268939776,
#     'cap': 197,
#     'nomarret': 'CAMPING DE JUIGNE',
#     'idvh': 268435884,
#     'iddesserte': 268939779,
#     'mnemoligne': '07',
#     'y': 2286311,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'CAMPJUIG',
#     'idarret': 669481,
#     'harret': '2018-06-18T13:58:48+00:00',
#     'x': 377742,
#     'sv': '0722',
#     'coordonnees': [47.538794, -0.61636888],
#     'idligne': 268435463,
#     'numarret': 7458},
#    'geometry': {'type': 'Point', 'coordinates': [-0.61636888, 47.538794]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'e9e06aaa63b6f1909e235bab88e3c0c22401af53',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 42,
#     'novh': '443',
#     'dest': 'CHU - HOPITAL',
#     'idparcours': 268939776,
#     'cap': 136,
#     'nomarret': 'ARDENNE',
#     'idvh': 268435899,
#     'iddesserte': 268939802,
#     'mnemoligne': '07',
#     'y': 2283265,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'AARD-7C',
#     'idarret': 669332,
#     'harret': '2018-06-18T13:58:42+00:00',
#     'x': 379118,
#     'sv': '0724',
#     'coordonnees': [47.511879, -0.59659469],
#     'idligne': 268435463,
#     'numarret': 562},
#    'geometry': {'type': 'Point', 'coordinates': [-0.59659469, 47.511879]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '330bfa9dc100be890f1ad6d996ec766cdfae6765',
#    'fields': {'etat': 'HLPS',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '449',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 269138432,
#     'cap': 185,
#     'nomarret': 'SORTIE DEPOT ST BART',
#     'idvh': 268435905,
#     'iddesserte': 269138433,
#     'mnemoligne': '10',
#     'y': 2278886,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'DEPOT SD',
#     'idarret': 669615,
#     'harret': '2018-06-18T13:59:00+00:00',
#     'x': 386765,
#     'sv': '1005',
#     'coordonnees': [47.475039, -0.49304564],
#     'idligne': 268435466,
#     'numarret': 6562},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49304564, 47.475039]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '9f2b9f6c3301d14871638a9d10a3070be4f10283',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': -10,
#     'novh': '531',
#     'dest': 'VERNUSSON PAR TRELAZE',
#     'idparcours': 269266432,
#     'cap': 118,
#     'nomarret': 'PLACE LORRAINE',
#     'idvh': 268435987,
#     'iddesserte': 269266452,
#     'mnemoligne': '12',
#     'y': 2278504,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'LOHUIT',
#     'idarret': 669917,
#     'harret': '2018-06-18T13:58:49+00:00',
#     'x': 382665,
#     'sv': '1204',
#     'coordonnees': [47.470265, -0.54721719],
#     'idligne': 268435468,
#     'numarret': 5526},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54721719, 47.470265]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '8761725445b2f9ae6b68bcdf6c2d59173db8f9cf',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 307,
#     'novh': '538',
#     'dest': 'CIRCULAIRE SENS B',
#     'idparcours': 268807680,
#     'cap': 17,
#     'nomarret': 'CAMELIA',
#     'idvh': 268435994,
#     'iddesserte': 268807727,
#     'mnemoligne': '05',
#     'y': 2278433,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'CAMELIAS',
#     'idarret': 669475,
#     'harret': '2018-06-18T13:59:06+00:00',
#     'x': 384775,
#     'sv': '0501',
#     'coordonnees': [47.47032, -0.51921089],
#     'idligne': 268435461,
#     'numarret': 11696},
#    'geometry': {'type': 'Point', 'coordinates': [-0.51921089, 47.47032]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a1b0c279c5f0d4879ca2c32b0ea558e39a40bec6',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 0,
#     'novh': '601',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268721408,
#     'cap': 237,
#     'nomarret': 'SORTIE BUS CTB',
#     'idvh': 268436057,
#     'iddesserte': 268721409,
#     'mnemoligne': '04',
#     'y': 2281465,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'SDCTB',
#     'idarret': 670213,
#     'harret': '2018-06-18T13:58:28+00:00',
#     'x': 381194,
#     'sv': '0423',
#     'coordonnees': [47.496393, -0.56816931],
#     'idligne': 268435460,
#     'numarret': 17220},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56816931, 47.496393]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '09f8443253a4eefd0208aae651dc2f15bdf2f09f',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 154,
#     'novh': '603',
#     'dest': 'MONPLAISIR',
#     'idparcours': 268513024,
#     'cap': 169,
#     'nomarret': 'BOISRAME',
#     'idvh': 268436059,
#     'iddesserte': 268513031,
#     'mnemoligne': '01',
#     'y': 2279494,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'BOISRAME',
#     'idarret': 669447,
#     'harret': '2018-06-18T13:59:17+00:00',
#     'x': 379870,
#     'sv': '0105',
#     'coordonnees': [47.478236, -0.58475724],
#     'idligne': 268435457,
#     'numarret': 22086},
#    'geometry': {'type': 'Point', 'coordinates': [-0.58475724, 47.478236]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '5cceb21a4ff8d451ef96003be77334a0392b4518',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': -10,
#     'novh': '608',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611072,
#     'cap': 118,
#     'nomarret': 'VAL DE LOIRE',
#     'idvh': 268436064,
#     'iddesserte': 268611111,
#     'mnemoligne': '02',
#     'y': 2276196,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'VDLOIR-E',
#     'idarret': 670290,
#     'harret': '2018-06-18T13:59:00+00:00',
#     'x': 384846,
#     'sv': '0214',
#     'coordonnees': [47.450235, -0.51719218],
#     'idligne': 268435458,
#     'numarret': 32158},
#    'geometry': {'type': 'Point', 'coordinates': [-0.51719218, 47.450235]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '97f6ce6f0689c56277361a552ab05a4d51c5bc50',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 301,
#     'novh': '614',
#     'dest': 'ST BARTHELEMY',
#     'idparcours': 268706560,
#     'cap': 47,
#     'nomarret': 'FOCH HARAS',
#     'idvh': 268436070,
#     'iddesserte': 268706596,
#     'mnemoligne': '04',
#     'y': 2278167,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'HARAS',
#     'idarret': 669768,
#     'harret': '2018-06-18T13:58:32+00:00',
#     'x': 382293,
#     'sv': '0409',
#     'coordonnees': [47.467113, -0.55198439],
#     'idligne': 268435460,
#     'numarret': 20835},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55198439, 47.467113]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'ca5f9f90466b1fe721348057a739de323c1f62b0',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 34,
#     'novh': '616',
#     'dest': 'BELLE BEILLE',
#     'idparcours': 268545536,
#     'cap': 148,
#     'nomarret': 'ALLONNEAU',
#     'idvh': 268436072,
#     'iddesserte': 268545541,
#     'mnemoligne': '01',
#     'y': 2280362,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'ALLONNEA',
#     'idarret': 669343,
#     'harret': '2018-06-18T13:59:30+00:00',
#     'x': 384237,
#     'sv': '0128',
#     'coordonnees': [47.487483, -0.52727549],
#     'idligne': 268435457,
#     'numarret': 16562},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52727549, 47.487483]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd256116331bdd077cabb56b796160ec1f9b3e536',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 255,
#     'novh': '622',
#     'dest': 'MONPLAISIR',
#     'idparcours': 268513024,
#     'cap': 189,
#     'nomarret': 'GARES BREMONT',
#     'idvh': 268436078,
#     'iddesserte': 268513043,
#     'mnemoligne': '01',
#     'y': 2278073,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'GBREM-E',
#     'idarret': 669729,
#     'harret': '2018-06-18T13:58:54+00:00',
#     'x': 381732,
#     'sv': '0106',
#     'coordonnees': [47.466082, -0.559375],
#     'idligne': 268435457,
#     'numarret': 25296},
#    'geometry': {'type': 'Point', 'coordinates': [-0.559375, 47.466082]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '58d6606ab15a377baf27fad8857c7941efc6b8d8',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 730,
#     'novh': '623',
#     'dest': 'AVRILLE SALETTE',
#     'idparcours': 268641024,
#     'cap': 53,
#     'nomarret': 'CHAMP DES MARTYRS',
#     'idvh': 268436079,
#     'iddesserte': 268641073,
#     'mnemoligne': '03',
#     'y': 2280717,
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'mnemoarret': 'CHMART-E',
#     'idarret': 669540,
#     'harret': '2018-06-18T13:58:43+00:00',
#     'x': 379966,
#     'sv': '0306',
#     'coordonnees': [47.489261, -0.58408739],
#     'idligne': 268435459,
#     'numarret': 2510},
#    'geometry': {'type': 'Point', 'coordinates': [-0.58408739, 47.489261]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'dffc3b25e4e34ecd2cef8eff3568305edd7045f1',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 20,
#     'novh': '651',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611072,
#     'cap': 227,
#     'nomarret': 'ROUTE DE PARIS',
#     'idvh': 268436107,
#     'iddesserte': 268611086,
#     'mnemoligne': '02',
#     'y': 2280850,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'RTEPARIS',
#     'idarret': 670190,
#     'harret': '2018-06-18T13:59:38+00:00',
#     'x': 386128,
#     'sv': '0216',
#     'coordonnees': [47.492487, -0.50243229],
#     'idligne': 268435458,
#     'numarret': 17574},
#    'geometry': {'type': 'Point', 'coordinates': [-0.50243229, 47.492487]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '397a1a8465f0a320704c8e49423d5602f81800da',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 238,
#     'novh': '654',
#     'dest': 'ST SYLVAIN',
#     'idparcours': 268578560,
#     'cap': 301,
#     'nomarret': 'BOURGONNIER',
#     'idvh': 268436110,
#     'iddesserte': 268578589,
#     'mnemoligne': '02',
#     'y': 2277375,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'BOUGONNI',
#     'idarret': 669456,
#     'harret': '2018-06-18T13:59:27+00:00',
#     'x': 383320,
#     'sv': '0218',
#     'coordonnees': [47.460333, -0.53798624],
#     'idligne': 268435458,
#     'numarret': 27073},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53798624, 47.460333]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '9d9442de2731053444e1871f103d3f6d8681bd25',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 140,
#     'novh': '670',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268612096,
#     'cap': 233,
#     'nomarret': 'LUTIN',
#     'idvh': 268436126,
#     'iddesserte': 268612108,
#     'mnemoligne': '02',
#     'y': 2279147,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'LUTIN',
#     'idarret': 669928,
#     'harret': '2018-06-18T13:59:06+00:00',
#     'x': 383757,
#     'sv': '0215',
#     'coordonnees': [47.476404, -0.53305217],
#     'idligne': 268435458,
#     'numarret': 32534},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53305217, 47.476404]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '29857e6a1d70228cebf7abe4877f19094f4a5587',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniArtE6',
#     'ecart': 405,
#     'novh': '683',
#     'dest': 'ST BARTHELEMY',
#     'idparcours': 268707072,
#     'cap': 101,
#     'nomarret': 'CHENE VERT',
#     'idvh': 268436139,
#     'iddesserte': 268707116,
#     'mnemoligne': '04',
#     'y': 2278443,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'CHVERT-E',
#     'idarret': 669545,
#     'harret': '2018-06-18T13:58:32+00:00',
#     'x': 384968,
#     'sv': '0402',
#     'coordonnees': [47.470473, -0.51665712],
#     'idligne': 268435460,
#     'numarret': 24160},
#    'geometry': {'type': 'Point', 'coordinates': [-0.51665712, 47.470473]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd07052825f8badccd4f05dbbc6b88b0b62e69b92',
#    'fields': {'etat': 'HLPS',
#     'type': 'AGORA123456789ABCDEFART',
#     'ecart': 2314,
#     'novh': '702',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268655360,
#     'cap': 241,
#     'nomarret': 'SORTIE DEPOT ST BART',
#     'idvh': 268436158,
#     'iddesserte': 268655361,
#     'mnemoligne': '03',
#     'y': 2270270,
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'mnemoarret': 'DEPOT SD',
#     'idarret': 669615,
#     'harret': '2018-06-18T13:58:14+00:00',
#     'x': 381928,
#     'sv': '0307',
#     'coordonnees': [47.396007, -0.55297172],
#     'idligne': 268435459,
#     'numarret': 6562},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55297172, 47.396007]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd2707eca39de09f79bcef7be9101e0af08c1a754',
#    'fields': {'etat': 'TDEP',
#     'type': 'OmniSTDE6',
#     'ecart': 0,
#     'novh': '803',
#     'dest': "CLINIQUE DE L'ANJOU",
#     'idparcours': 269198336,
#     'cap': 56,
#     'nomarret': "L'HOIRIE",
#     'idvh': 268436259,
#     'iddesserte': 269198337,
#     'mnemoligne': '11',
#     'y': 2278354,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'LHOIRI11',
#     'idarret': 669907,
#     'harret': '2018-06-18T14:04:00+00:00',
#     'x': 377296,
#     'sv': '1103',
#     'coordonnees': [47.467123, -0.61831542],
#     'idligne': 268435467,
#     'numarret': 32088},
#    'geometry': {'type': 'Point', 'coordinates': [-0.61831542, 47.467123]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'adfe21ef157d323c7568362828aba5315bfea5c7',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 327,
#     'novh': '817',
#     'dest': 'ZI EST',
#     'idparcours': 268840192,
#     'cap': 106,
#     'nomarret': 'LAREVELLIERE',
#     'idvh': 268436273,
#     'iddesserte': 268840234,
#     'mnemoligne': '06',
#     'y': 2278586,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'LAMART-E',
#     'idarret': 669864,
#     'harret': '2018-06-18T13:59:05+00:00',
#     'x': 383692,
#     'sv': '0604',
#     'coordonnees': [47.47134, -0.53364216],
#     'idligne': 268435462,
#     'numarret': 2631},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53364216, 47.47134]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'b95e98363405c9aa34a2927c7b4b1694df5d455d',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 133,
#     'novh': '1005',
#     'dest': 'AVRILLE ARDENNE',
#     'idparcours': 269419008,
#     'cap': 45,
#     'nomarret': 'FOCH HARAS',
#     'idvh': 268436461,
#     'iddesserte': 269419016,
#     'mnemoligne': 'A',
#     'y': 2278147,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2HARA',
#     'idarret': 669315,
#     'harret': '2018-06-18T13:58:33+00:00',
#     'x': 382259,
#     'sv': 'A10',
#     'coordonnees': [47.466922, -0.55242534],
#     'idligne': 268435471,
#     'numarret': 14426},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55242534, 47.466922]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6649fd4dfef1b561ba530e1bc102b820b6dbe42c',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': -3,
#     'novh': '1014',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269452544,
#     'cap': 220,
#     'nomarret': 'BAMAKO',
#     'idvh': 268436470,
#     'iddesserte': 269452567,
#     'mnemoligne': 'A',
#     'y': 2276537,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1BAMA',
#     'idarret': 669281,
#     'harret': '2018-06-18T13:58:36+00:00',
#     'x': 381920,
#     'sv': 'A04',
#     'coordonnees': [47.452338, -0.55613308],
#     'idligne': 268435471,
#     'numarret': 24604},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55613308, 47.452338]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'ed7cfc069de9bd032567e715cfa8a3d1f43778f3',
#    'fields': {'etat': 'TARR',
#     'type': 'CITADIS',
#     'ecart': 0,
#     'novh': '1016',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 84,
#     'nomarret': 'ANGERS - ROSERAIE',
#     'idvh': 268436472,
#     'iddesserte': 269451546,
#     'mnemoligne': 'A',
#     'y': 2275600,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2ANRO',
#     'idarret': 669306,
#     'harret': '2018-06-18T13:58:28+00:00',
#     'x': 382048,
#     'sv': 'A13',
#     'coordonnees': [47.443958, -0.55397982],
#     'idligne': 268435471,
#     'numarret': 32091},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55397982, 47.443958]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c69372bacb0214e0bd77b75ba8d31ac3d10aeb9c',
#    'fields': {'etat': 'HLPS',
#     'type': 'Low Entry',
#     'ecart': 1323,
#     'novh': '9402',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 270293760,
#     'cap': 56,
#     'nomarret': 'DEPOT VOISIN',
#     'idvh': 268444858,
#     'iddesserte': 270293761,
#     'mnemoligne': '13',
#     'y': 2277892,
#     'nomligne': 'EXPRESS MONTREUIL <> GARES',
#     'mnemoarret': 'DEP VOIS',
#     'idarret': 671023,
#     'harret': '2018-06-18T13:58:23+00:00',
#     'x': 381563,
#     'sv': '1336',
#     'coordonnees': [47.464399, -0.56152667],
#     'idligne': 268435484,
#     'numarret': 790167},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56152667, 47.464399]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c654b6be045e5ffa2ce381caefccce8eb35b7d5c',
#    'fields': {'etat': 'TDEP',
#     'type': 'OmniArtE6',
#     'ecart': 0,
#     'novh': '689',
#     'dest': 'ST BARTHELEMY',
#     'idparcours': 268707072,
#     'cap': 95,
#     'nomarret': "L'ATOLL - BEAUCOUZE",
#     'idvh': 268436145,
#     'iddesserte': 268707073,
#     'mnemoligne': '04',
#     'y': 2280270,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'ATOLLBEA',
#     'idarret': 670760,
#     'harret': '2018-06-18T14:06:00+00:00',
#     'x': 376758,
#     'sv': '0408',
#     'coordonnees': [47.484163, -0.62640495],
#     'idligne': 268435460,
#     'numarret': 20041},
#    'geometry': {'type': 'Point', 'coordinates': [-0.62640495, 47.484163]},
#    'record_timestamp': '2018-06-18T13:57:13+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c1bfb3bc9be4759834bc733e32fa04ac77d5234e',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '462',
#     'dest': 'VERNUSSON PAR TRELAZE',
#     'idparcours': 269266432,
#     'cap': 90,
#     'nomarret': 'ST AUBIN LA SALLE',
#     'idvh': 268435918,
#     'iddesserte': 269266433,
#     'mnemoligne': '12',
#     'y': 2280507,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'BARONNER',
#     'idarret': 669397,
#     'harret': '2018-06-18T14:06:00+00:00',
#     'x': 386016,
#     'sv': '1208',
#     'coordonnees': [47.489367, -0.50375319],
#     'idligne': 268435468,
#     'numarret': 2861},
#    'geometry': {'type': 'Point', 'coordinates': [-0.50375319, 47.489367]},
#    'record_timestamp': '2018-06-18T13:54:36+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '14c506f09a99d91c098950a3fe823121db098640',
#    'fields': {'etat': 'HLPS',
#     'type': 'OmniArtE6',
#     'ecart': 0,
#     'novh': '681',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268720896,
#     'cap': 95,
#     'nomarret': 'SORTIE BUS CTB',
#     'idvh': 268436137,
#     'iddesserte': 268720897,
#     'mnemoligne': '04',
#     'y': 2281373,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'SDCTB',
#     'idarret': 670213,
#     'harret': '2018-06-18T14:07:00+00:00',
#     'x': 381070,
#     'sv': '0424',
#     'coordonnees': [47.495525, -0.56976879],
#     'idligne': 268435460,
#     'numarret': 17220},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56976879, 47.495525]},
#    'record_timestamp': '2018-06-18T12:57:19+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a0a5b38fdf8b9abdd0ac05e7bf1854b76737021b',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNIART',
#     'ecart': 0,
#     'novh': '664',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611584,
#     'cap': 279,
#     'nomarret': 'BANCHAIS',
#     'idvh': 268436120,
#     'iddesserte': 268611585,
#     'mnemoligne': '02',
#     'y': 2280145,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'BANCSTMA',
#     'idarret': 669394,
#     'harret': '2018-06-18T14:07:00+00:00',
#     'x': 385347,
#     'sv': '0206',
#     'coordonnees': [47.485896, -0.51245114],
#     'idligne': 268435458,
#     'numarret': 20610},
#    'geometry': {'type': 'Point', 'coordinates': [-0.51245114, 47.485896]},
#    'record_timestamp': '2018-06-18T13:45:59+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '463ca9a4e1dce86959ef7fbe0f8262176858a5ba',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '456',
#     'dest': 'MONTREUIL JUIGNE',
#     'idparcours': 268905216,
#     'cap': 227,
#     'nomarret': 'CHU - MATERNITE',
#     'idvh': 268435912,
#     'iddesserte': 268905217,
#     'mnemoligne': '07',
#     'y': 2279680,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'HOPA8-C',
#     'idarret': 669780,
#     'harret': '2018-06-18T14:08:00+00:00',
#     'x': 382118,
#     'sv': '0723',
#     'coordonnees': [47.480655, -0.55504254],
#     'idligne': 268435463,
#     'numarret': 27358},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55504254, 47.480655]},
#    'record_timestamp': '2018-06-18T13:55:58+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '609d77ff21f896937788b45d7b65f06220ef926a',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNIART',
#     'ecart': 0,
#     'novh': '660',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611072,
#     'cap': 61,
#     'nomarret': 'ST SYLVAIN',
#     'idvh': 268436116,
#     'iddesserte': 268611073,
#     'mnemoligne': '02',
#     'y': 2283022,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'STSYLVAI',
#     'idarret': 670250,
#     'harret': '2018-06-18T14:01:00+00:00',
#     'x': 388599,
#     'sv': '0207',
#     'coordonnees': [47.512809, -0.47068963],
#     'idligne': 268435458,
#     'numarret': 32055},
#    'geometry': {'type': 'Point', 'coordinates': [-0.47068963, 47.512809]},
#    'record_timestamp': '2018-06-18T13:55:58+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '4bf1180af40564915f9ac781c42e35e9b9ddc970',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '448',
#     'dest': 'ESPACE ANJOU',
#     'idparcours': 269062912,
#     'cap': 135,
#     'nomarret': 'ZI ECOUFLANT',
#     'idvh': 268435904,
#     'iddesserte': 269062913,
#     'mnemoligne': '09',
#     'y': 2281373,
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'mnemoarret': 'ZIECOUFL',
#     'idarret': 670322,
#     'harret': '2018-06-18T14:02:01+00:00',
#     'x': 385202,
#     'sv': '0914',
#     'coordonnees': [47.496887, -0.51496515],
#     'idligne': 268435465,
#     'numarret': 8779},
#    'geometry': {'type': 'Point', 'coordinates': [-0.51496515, 47.496887]},
#    'record_timestamp': '2018-06-18T13:57:13+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6e16bdd53966c9d74ae0a6d501d431e4ff2b46dd',
#    'fields': {'etat': 'TDEP',
#     'type': 'GX 427 Hyb',
#     'ecart': 24,
#     'novh': '202',
#     'dest': 'MONPLAISIR',
#     'idparcours': 268513024,
#     'cap': 281,
#     'nomarret': 'MAISON DE TECHNOPOLE',
#     'idvh': 268435658,
#     'iddesserte': 268513025,
#     'mnemoligne': '01',
#     'y': 2279599,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'MATECHNO',
#     'idarret': 669963,
#     'harret': '2018-06-18T13:58:24+00:00',
#     'x': 378283,
#     'sv': '0101',
#     'coordonnees': [47.478647, -0.6058504],
#     'idligne': 268435457,
#     'numarret': 29466},
#    'geometry': {'type': 'Point', 'coordinates': [-0.6058504, 47.478647]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '5d3bae20031171731d3c2e03ddc087a18f780878',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 103,
#     'novh': '422',
#     'dest': 'CIRCULAIRE SENS B',
#     'idparcours': 268807680,
#     'cap': 195,
#     'nomarret': 'GARENNE',
#     'idvh': 268435878,
#     'iddesserte': 268807689,
#     'mnemoligne': '05',
#     'y': 2279561,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'PARCGARE',
#     'idarret': 670051,
#     'harret': '2018-06-18T13:58:59+00:00',
#     'x': 380510,
#     'sv': '0503',
#     'coordonnees': [47.479051, -0.57630472],
#     'idligne': 268435461,
#     'numarret': 1681},
#    'geometry': {'type': 'Point', 'coordinates': [-0.57630472, 47.479051]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '9e27c22a0f3035afdda1694da39f58334337f32f',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 56,
#     'novh': '424',
#     'dest': 'MURS ERIGNE',
#     'idparcours': 268674048,
#     'cap': 122,
#     'nomarret': 'ANDRE LEROY',
#     'idvh': 268435880,
#     'iddesserte': 268674077,
#     'mnemoligne': '03',
#     'y': 2278140,
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'mnemoarret': 'ANLERO-E',
#     'idarret': 669348,
#     'harret': '2018-06-18T14:00:55+00:00',
#     'x': 382134,
#     'sv': '0305',
#     'coordonnees': [47.466818, -0.55407891],
#     'idligne': 268435459,
#     'numarret': 14800},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55407891, 47.466818]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '410c26a654609b0c4d49d5270b56aa4d95ce1d46',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': -43,
#     'novh': '433',
#     'dest': "LAC DE MAINE - L'HOIRIE",
#     'idparcours': 269166848,
#     'cap': 331,
#     'nomarret': 'POIREL',
#     'idvh': 268435889,
#     'iddesserte': 269166864,
#     'mnemoligne': '11',
#     'y': 2277489,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'POIREL',
#     'idarret': 670100,
#     'harret': '2018-06-18T13:59:02+00:00',
#     'x': 381555,
#     'sv': '1104',
#     'coordonnees': [47.460774, -0.56143562],
#     'idligne': 268435467,
#     'numarret': 14957},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56143562, 47.460774]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '095bf38bd7af700ac4021f314595f3cbfdd4587a',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 1359,
#     'novh': '434',
#     'dest': 'SCHWEITZER',
#     'idparcours': 269097728,
#     'cap': 134,
#     'nomarret': 'GENTRIC',
#     'idvh': 268435890,
#     'iddesserte': 269097730,
#     'mnemoligne': '10',
#     'y': 2276053,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'GENTRIC',
#     'idarret': 669741,
#     'harret': '2018-06-18T13:58:49+00:00',
#     'x': 387190,
#     'sv': '1001',
#     'coordonnees': [47.449711, -0.48606108],
#     'idligne': 268435466,
#     'numarret': 45617},
#    'geometry': {'type': 'Point', 'coordinates': [-0.48606108, 47.449711]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a5f2364fa47f3c3f2feb3aad849ce7129fda01b0',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 759,
#     'novh': '435',
#     'dest': 'SCHWEITZER',
#     'idparcours': 269098240,
#     'cap': 63,
#     'nomarret': 'CHALOUERE',
#     'idvh': 268435891,
#     'iddesserte': 269098279,
#     'mnemoligne': '10',
#     'y': 2279529,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'CHALOU-E',
#     'idarret': 669519,
#     'harret': '2018-06-18T13:59:41+00:00',
#     'x': 383141,
#     'sv': '1010',
#     'coordonnees': [47.479636, -0.54140486],
#     'idligne': 268435466,
#     'numarret': 16972},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54140486, 47.479636]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'cd82d6207c107d5d4584b4a56062daefea35048d',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 221,
#     'novh': '523',
#     'dest': 'BOUCHEMAINE PAR HARENCHER',
#     'idparcours': 268873216,
#     'cap': 184,
#     'nomarret': 'PETIT ANJOU',
#     'idvh': 268435979,
#     'iddesserte': 268873261,
#     'mnemoligne': '06',
#     'y': 2276222,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'P-ANJOU',
#     'idarret': 670748,
#     'harret': '2018-06-18T13:59:26+00:00',
#     'x': 377397,
#     'sv': '0622',
#     'coordonnees': [47.447994, -0.61591428],
#     'idligne': 268435462,
#     'numarret': 24330},
#    'geometry': {'type': 'Point', 'coordinates': [-0.61591428, 47.447994]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '5327f3cc268302a81b5dc181c51c0b928a071e0a',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 56,
#     'novh': '526',
#     'dest': 'CIRCULAIRE SENS B',
#     'idparcours': 268807680,
#     'cap': 225,
#     'nomarret': 'CENTRE DE TRI',
#     'idvh': 268435982,
#     'iddesserte': 268807702,
#     'mnemoligne': '05',
#     'y': 2276814,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'CTRETR-E',
#     'idarret': 670755,
#     'harret': '2018-06-18T13:59:31+00:00',
#     'x': 381079,
#     'sv': '0521',
#     'coordonnees': [47.454549, -0.56741386],
#     'idligne': 268435461,
#     'numarret': 6456},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56741386, 47.454549]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'bd67a0bd59245e77a5c03b656518702e5376bc42',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 15,
#     'novh': '533',
#     'dest': 'CIRCULAIRE SENS B',
#     'idparcours': 268807680,
#     'cap': 67,
#     'nomarret': 'HAUT PRESSOIR',
#     'idvh': 268435989,
#     'iddesserte': 268807718,
#     'mnemoligne': '05',
#     'y': 2276586,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'HAUTPR-E',
#     'idarret': 669772,
#     'harret': '2018-06-18T13:58:31+00:00',
#     'x': 383286,
#     'sv': '0525',
#     'coordonnees': [47.453229, -0.53805415],
#     'idligne': 268435461,
#     'numarret': 52},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53805415, 47.453229]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '78853a2af8a78a2aa42b5257bdfa5136efca6aba',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 1100,
#     'novh': '539',
#     'dest': 'CIRCULAIRE SENS A',
#     'idparcours': 268774144,
#     'cap': 314,
#     'nomarret': 'INTERMARCHE MILLOT',
#     'idvh': 268435995,
#     'iddesserte': 268774169,
#     'mnemoligne': '05',
#     'y': 2277027,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'INTERMIL',
#     'idarret': 669803,
#     'harret': '2018-06-18T13:59:47+00:00',
#     'x': 383705,
#     'sv': '0526',
#     'coordonnees': [47.457331, -0.53271482],
#     'idligne': 268435461,
#     'numarret': 3434},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53271482, 47.457331]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '0a12e603e02f5e994a88075550171c456e379e8b',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 518,
#     'novh': '540',
#     'dest': 'CIRCULAIRE SENS A',
#     'idparcours': 268774144,
#     'cap': 9,
#     'nomarret': 'GARES BREMONT',
#     'idvh': 268435996,
#     'iddesserte': 268774193,
#     'mnemoligne': '05',
#     'y': 2278073,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'BREMON-E',
#     'idarret': 669465,
#     'harret': '2018-06-18T14:00:36+00:00',
#     'x': 381732,
#     'sv': '0502',
#     'coordonnees': [47.466082, -0.559375],
#     'idligne': 268435461,
#     'numarret': 25430},
#    'geometry': {'type': 'Point', 'coordinates': [-0.559375, 47.466082]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'b83fc3362b1b931dc37cb04dd6df8739eda9266c',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniArtE6',
#     'ecart': 458,
#     'novh': '679',
#     'dest': 'MURS ERIGNE',
#     'idparcours': 268674560,
#     'cap': 122,
#     'nomarret': 'CLINIQUE ST DIDIER',
#     'idvh': 268436135,
#     'iddesserte': 268674576,
#     'mnemoligne': '03',
#     'y': 2280403,
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'mnemoarret': 'CLINIQUE',
#     'idarret': 669569,
#     'harret': '2018-06-18T13:58:58+00:00',
#     'x': 379652,
#     'sv': '0323',
#     'coordonnees': [47.486333, -0.58809635],
#     'idligne': 268435459,
#     'numarret': 26512},
#    'geometry': {'type': 'Point', 'coordinates': [-0.58809635, 47.486333]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd3b33e48da329c0170c82621ed03538fa0d4c83d',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 30,
#     'novh': '809',
#     'dest': 'BOUCHEMAINE CHANTOURTEAU',
#     'idparcours': 268874240,
#     'cap': 123,
#     'nomarret': 'PERUSSAIE',
#     'idvh': 268436265,
#     'iddesserte': 268874275,
#     'mnemoligne': '06',
#     'y': 2278122,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'PERUSS-E',
#     'idarret': 670071,
#     'harret': '2018-06-18T13:58:31+00:00',
#     'x': 379007,
#     'sv': '0602',
#     'coordonnees': [47.465614, -0.5955202],
#     'idligne': 268435462,
#     'numarret': 4185},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5955202, 47.465614]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '1f2028b7e74b31c7314f4ab98fa191316dfae8d3',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 121,
#     'novh': '822',
#     'dest': 'MOULIN MARCILLE PAR TRELA',
#     'idparcours': 269266944,
#     'cap': 216,
#     'nomarret': 'CHATELAIN',
#     'idvh': 268436278,
#     'iddesserte': 269266950,
#     'mnemoligne': '12',
#     'y': 2280022,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'CHATELAI',
#     'idarret': 669529,
#     'harret': '2018-06-18T13:59:07+00:00',
#     'x': 385335,
#     'sv': '1205',
#     'coordonnees': [47.484786, -0.5125511],
#     'idligne': 268435468,
#     'numarret': 23220},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5125511, 47.484786]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd5b4b40f7c787ec86cd8f76e52d0a706e159b4bc',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 113,
#     'novh': '1004',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 149,
#     'nomarret': 'RALLIEMENT',
#     'idvh': 268436460,
#     'iddesserte': 269451537,
#     'mnemoligne': 'A',
#     'y': 2278608,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1RALL',
#     'idarret': 669299,
#     'harret': '2018-06-18T14:00:12+00:00',
#     'x': 382340,
#     'sv': 'A05',
#     'coordonnees': [47.471093, -0.55157632],
#     'idligne': 268435471,
#     'numarret': 24847},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55157632, 47.471093]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '561a880c6d029bc6de267ab847dda10902ec5bb7',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': -1,
#     'novh': '1010',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 171,
#     'nomarret': 'CHU - HOPITAL',
#     'idvh': 268436466,
#     'iddesserte': 269451533,
#     'mnemoligne': 'A',
#     'y': 2279964,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1HOPA',
#     'idarret': 669290,
#     'harret': '2018-06-18T13:59:09+00:00',
#     'x': 382237,
#     'sv': 'A06',
#     'coordonnees': [47.483247, -0.55360325],
#     'idligne': 268435471,
#     'numarret': 24731},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55360325, 47.483247]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'f5d83fb84acf66fbe7a5d9e742b97e7ddfd40cd4',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 22,
#     'novh': '1017',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 67,
#     'nomarret': 'TERRA BOTANICA',
#     'idvh': 268436473,
#     'iddesserte': 269451527,
#     'mnemoligne': 'A',
#     'y': 2281171,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1BOTA',
#     'idarret': 669284,
#     'harret': '2018-06-18T13:59:02+00:00',
#     'x': 380584,
#     'sv': 'A08',
#     'coordonnees': [47.493548, -0.57611518],
#     'idligne': 268435471,
#     'numarret': 24128},
#    'geometry': {'type': 'Point', 'coordinates': [-0.57611518, 47.493548]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '0c8dd8c5a708e0664d44a12784aefcf971125e97',
#    'fields': {'etat': 'TDEP',
#     'type': 'GX 327',
#     'ecart': 0,
#     'novh': '522',
#     'dest': 'ST AUBIN LA SALLE',
#     'idparcours': 269233408,
#     'cap': 33,
#     'nomarret': 'MOULIN MARCILLE',
#     'idvh': 268435978,
#     'iddesserte': 269233409,
#     'mnemoligne': '12',
#     'y': 2274330,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'MOULINMA',
#     'idarret': 670024,
#     'harret': '2018-06-18T14:02:00+00:00',
#     'x': 386027,
#     'sv': '1203',
#     'coordonnees': [47.433846, -0.50064828],
#     'idligne': 268435468,
#     'numarret': 32614},
#    'geometry': {'type': 'Point', 'coordinates': [-0.50064828, 47.433846]},
#    'record_timestamp': '2018-06-18T13:48:53+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '4ee146c3e76bb2fcd5b578dd048105e30eaeacba',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '458',
#     'dest': 'ST SYLVAIN',
#     'idparcours': 268578560,
#     'cap': 315,
#     'nomarret': 'TRELAZE',
#     'idvh': 268435914,
#     'iddesserte': 268578561,
#     'mnemoligne': '02',
#     'y': 2277163,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'TRELA AR',
#     'idarret': 670742,
#     'harret': '2018-06-18T13:59:00+00:00',
#     'x': 388011,
#     'sv': '0208',
#     'coordonnees': [47.459953, -0.47570781],
#     'idligne': 268435458,
#     'numarret': 29269},
#    'geometry': {'type': 'Point', 'coordinates': [-0.47570781, 47.459953]},
#    'record_timestamp': '2018-06-18T13:52:34+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '8c5c08abc25ceba7789df1bbd064a405391fa2df',
#    'fields': {'etat': 'TARR',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '432',
#     'dest': 'MONTREUIL JUIGNE',
#     'idparcours': 268905216,
#     'cap': 16,
#     'nomarret': 'BENE',
#     'idvh': 268435888,
#     'iddesserte': 268905259,
#     'mnemoligne': '07',
#     'y': 2286541,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'BENE-E',
#     'idarret': 669426,
#     'harret': '2018-06-18T13:50:42+00:00',
#     'x': 378272,
#     'sv': '0725',
#     'coordonnees': [47.541041, -0.60944848],
#     'idligne': 268435463,
#     'numarret': 27645},
#    'geometry': {'type': 'Point', 'coordinates': [-0.60944848, 47.541041]},
#    'record_timestamp': '2018-06-18T13:57:37+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '1620d79e322a0e1e7267de6a3246c6d2e8d0a531',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 0,
#     'novh': '619',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268525312,
#     'cap': 354,
#     'nomarret': 'SORTIE BUS CTB',
#     'idvh': 268436075,
#     'iddesserte': 268525313,
#     'mnemoligne': '01',
#     'y': 2281447,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'SDCTB',
#     'idarret': 670213,
#     'harret': '2018-06-18T14:02:00+00:00',
#     'x': 381224,
#     'sv': '0104',
#     'coordonnees': [47.496242, -0.56776259],
#     'idligne': 268435457,
#     'numarret': 17220},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56776259, 47.496242]},
#    'record_timestamp': '2018-06-18T13:58:18+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a6a2342aee1908680a1e3f0f9c6c10861fa59067',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 125,
#     'novh': '437',
#     'dest': 'MONTREUIL JUIGNE',
#     'idparcours': 268905216,
#     'cap': 39,
#     'nomarret': 'ALLEMAGNE',
#     'idvh': 268435893,
#     'iddesserte': 268905240,
#     'mnemoligne': '07',
#     'y': 2284993,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'ALLEMA-E',
#     'idarret': 669340,
#     'harret': '2018-06-18T13:58:48+00:00',
#     'x': 378819,
#     'sv': '0721',
#     'coordonnees': [47.527311, -0.60141897],
#     'idligne': 268435463,
#     'numarret': 9078},
#    'geometry': {'type': 'Point', 'coordinates': [-0.60141897, 47.527311]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'f5a196e2c8dcbffe36742d6840765f591ee91e68',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 45,
#     'novh': '439',
#     'dest': "LAC DE MAINE - L'HOIRIE",
#     'idparcours': 269164800,
#     'cap': 230,
#     'nomarret': 'GRAND MAINE',
#     'idvh': 268435895,
#     'iddesserte': 269164830,
#     'mnemoligne': '11',
#     'y': 2278705,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'GDMAIN-E',
#     'idarret': 669730,
#     'harret': '2018-06-18T14:02:46+00:00',
#     'x': 381765,
#     'sv': '1115',
#     'coordonnees': [47.471774, -0.55924643],
#     'idligne': 268435467,
#     'numarret': 15461},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55924643, 47.471774]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a1247a963a151e63fd05ad19fde1c5fcd369fd98',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '441',
#     'dest': 'EVENTARD par MONPLAISIR',
#     'idparcours': 269029376,
#     'cap': 11,
#     'nomarret': 'ESPACE ANJOU',
#     'idvh': 268435897,
#     'iddesserte': 269029377,
#     'mnemoligne': '09',
#     'y': 2278212,
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'mnemoarret': 'ESPACEAN',
#     'idarret': 669663,
#     'harret': '2018-06-18T14:00:00+00:00',
#     'x': 384248,
#     'sv': '0904',
#     'coordonnees': [47.468161, -0.52609049],
#     'idligne': 268435465,
#     'numarret': 18251},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52609049, 47.468161]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'ccd68a007a9a31df7129ef070f4a48574bf42c8e',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': -505,
#     'novh': '445',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 269179392,
#     'cap': 151,
#     'nomarret': "CLINIQUE DE L'ANJOU",
#     'idvh': 268435901,
#     'iddesserte': 269179394,
#     'mnemoligne': '11',
#     'y': 2276267,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'CLINANJO',
#     'idarret': 669567,
#     'harret': '2018-06-18T14:04:54+00:00',
#     'x': 383163,
#     'sv': '1106',
#     'coordonnees': [47.450321, -0.53952942],
#     'idligne': 268435467,
#     'numarret': 21645},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53952942, 47.450321]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '62d6271609d212ea251a79589403116a781d6c44',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX317',
#     'ecart': 312,
#     'novh': '512',
#     'dest': 'SCHWEITZER',
#     'idparcours': 269097728,
#     'cap': 119,
#     'nomarret': 'FOCH HARAS',
#     'idvh': 268435968,
#     'iddesserte': 269097761,
#     'mnemoligne': '10',
#     'y': 2278175,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'HARAS',
#     'idarret': 669768,
#     'harret': '2018-06-18T14:01:09+00:00',
#     'x': 382080,
#     'sv': '1006',
#     'coordonnees': [47.467115, -0.5548118],
#     'idligne': 268435466,
#     'numarret': 20835},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5548118, 47.467115]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '655a8ab3e31840f33567ac92f0cec89627ee1f06',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX317',
#     'ecart': 104,
#     'novh': '513',
#     'dest': 'EVENTARD par MONPLAISIR',
#     'idparcours': 269029376,
#     'cap': 110,
#     'nomarret': 'HOTELLERIE',
#     'idvh': 268435969,
#     'iddesserte': 269029401,
#     'mnemoligne': '09',
#     'y': 2280601,
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'mnemoarret': 'HOTELL-E',
#     'idarret': 669785,
#     'harret': '2018-06-18T13:58:53+00:00',
#     'x': 384713,
#     'sv': '0906',
#     'coordonnees': [47.489788, -0.52107848],
#     'idligne': 268435465,
#     'numarret': 31454},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52107848, 47.489788]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd467dc7e7a1d17297a1285fd4ce40eb531a1882b',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX317',
#     'ecart': 18,
#     'novh': '518',
#     'dest': 'ESPACE ANJOU',
#     'idparcours': 269062656,
#     'cap': 225,
#     'nomarret': 'FOCH HARAS',
#     'idvh': 268435974,
#     'iddesserte': 269062676,
#     'mnemoligne': '09',
#     'y': 2278183,
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'mnemoarret': 'HARAS-E',
#     'idarret': 669769,
#     'harret': '2018-06-18T13:58:28+00:00',
#     'x': 382283,
#     'sv': '0907',
#     'coordonnees': [47.467254, -0.55212475],
#     'idligne': 268435465,
#     'numarret': 3412},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55212475, 47.467254]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '22e54152c416fda5b3de7baf13381b018d92a6c0',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': -18,
#     'novh': '532',
#     'dest': 'CIRCULAIRE SENS A',
#     'idparcours': 268774144,
#     'cap': 137,
#     'nomarret': 'CARREFOUR',
#     'idvh': 268435988,
#     'iddesserte': 268774150,
#     'mnemoligne': '05',
#     'y': 2280714,
# ...
#     'idligne': 268435486,
#     'numarret': 2767},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52318727, 47.481581]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6bc00b133c0eed3ca8506f4da939cd3aa85f0040',
#    'fields': {'etat': 'TDEP',
#     'type': 'OmniSTDE6',
#     'ecart': 0,
#     'novh': '820',
#     'dest': 'ZI EST',
#     'idparcours': 268840704,
#     'cap': 282,
#     'nomarret': 'CHANTOURTEAU',
#     'idvh': 268436276,
#     'iddesserte': 268840705,
#     'mnemoligne': '06',
#     'y': 2271575,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'CHANTOUR',
#     'idarret': 669523,
#     'harret': '2018-06-18T14:05:00+00:00',
#     'x': 376662,
#     'sv': '0609',
#     'coordonnees': [47.405975, -0.62333307],
#     'idligne': 268435462,
#     'numarret': 20438},
#    'geometry': {'type': 'Point', 'coordinates': [-0.62333307, 47.405975]},
#    'record_timestamp': '2018-06-18T13:56:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '2c7d2ad67790f429eaf5ad4ca04ddd350f0335bb',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '452',
#     'dest': 'HAUTE DE RECULEE',
#     'idparcours': 268972288,
#     'cap': 11,
#     'nomarret': 'MAIRIE PONTS DE CE',
#     'idvh': 268435908,
#     'iddesserte': 268972289,
#     'mnemoligne': '08',
#     'y': 2273441,
#     'nomligne': 'PONTS CE <>  AQUAVITA H. RECULEE',
#     'mnemoarret': 'MAPTSCE',
#     'idarret': 669953,
#     'harret': '2018-06-18T14:02:00+00:00',
#     'x': 384268,
#     'sv': '0821',
#     'coordonnees': [47.425281, -0.52352237],
#     'idligne': 268435464,
#     'numarret': 9963},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52352237, 47.425281]},
#    'record_timestamp': '2018-06-18T13:52:34+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '01572d7f2a5a2906c67626ed862611c55e81151f',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': -1053,
#     'novh': '440',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 269050624,
#     'cap': 225,
#     'nomarret': 'ESPACE ANJOU',
#     'idvh': 268435896,
#     'iddesserte': 269050626,
#     'mnemoligne': '09',
#     'y': 2278457,
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'mnemoarret': 'ESPACEAN',
#     'idarret': 669663,
#     'harret': '2018-06-18T14:02:07+00:00',
#     'x': 385344,
#     'sv': '0902',
#     'coordonnees': [47.470721, -0.51167921],
#     'idligne': 268435465,
#     'numarret': 18251},
#    'geometry': {'type': 'Point', 'coordinates': [-0.51167921, 47.470721]},
#    'record_timestamp': '2018-06-18T13:58:18+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '5927b0379c66aab1b64ccc75e4dcb8e69a9fe431',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniArtE6',
#     'ecart': 143,
#     'novh': '678',
#     'dest': 'ST SYLVAIN',
#     'idparcours': 268578560,
#     'cap': 274,
#     'nomarret': 'EGLISE DE TRELAZE',
#     'idvh': 268436134,
#     'iddesserte': 268578568,
#     'mnemoligne': '02',
#     'y': 2275532,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'EGLTRELA',
#     'idarret': 669653,
#     'harret': '2018-06-18T13:57:59+00:00',
#     'x': 388732,
#     'sv': '0202',
#     'coordonnees': [47.445524, -0.46538001],
#     'idligne': 268435458,
#     'numarret': 208},
#    'geometry': {'type': 'Point', 'coordinates': [-0.46538001, 47.445524]},
#    'record_timestamp': '2018-06-18T13:58:18+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '480c257c4a57c1a8d6db8aec5735b24d657699a8',
#    'fields': {'etat': 'HLPS',
#     'type': 'CITADIS',
#     'ecart': 809,
#     'novh': '1009',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 269442304,
#     'cap': 241,
#     'nomarret': 'SORTIE TRAM CTT',
#     'idvh': 268436465,
#     'iddesserte': 269442305,
#     'mnemoligne': 'A',
#     'y': 2281302,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': 'SDPTRAM',
#     'idarret': 670214,
#     'harret': '2018-06-18T13:58:09+00:00',
#     'x': 381068,
#     'sv': 'A12',
#     'coordonnees': [47.494886, -0.56976047],
#     'idligne': 268435471,
#     'numarret': 16020},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56976047, 47.494886]},
#    'record_timestamp': '2018-06-18T13:58:18+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '207ba990d9bc30c04e1356e7e5023f8be073d088',
#    'fields': {'etat': 'HLPS',
#     'type': 'RECREO',
#     'ecart': 0,
#     'novh': '7492',
#     'dest': 'BRIOLLAY',
#     'idparcours': 270469888,
#     'cap': 22,
#     'nomarret': 'GARES SNCF ESPLANADE',
#     'idvh': 268442948,
#     'iddesserte': 270469889,
#     'mnemoligne': '31',
#     'y': 2277957,
#     'nomligne': 'BRIOLLAY <> GARE',
#     'mnemoarret': 'GARESNCF',
#     'idarret': 670678,
#     'harret': '2018-06-18T14:30:00+00:00',
#     'x': 381270,
#     'sv': '3107',
#     'coordonnees': [47.464886, -0.56544226],
#     'idligne': 268435487,
#     'numarret': 18137},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56544226, 47.464886]},
#    'record_timestamp': '2018-06-18T13:58:18+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '90fa36f09cc7d440510ec33099b584ee2dfc41d7',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': -140,
#     'novh': '429',
#     'dest': 'MONTREUIL JUIGNE',
#     'idparcours': 268905216,
#     'cap': 333,
#     'nomarret': 'KENNEDY',
#     'idvh': 268435885,
#     'iddesserte': 268905226,
#     'mnemoligne': '07',
#     'y': 2280889,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'KENNED-E',
#     'idarret': 669842,
#     'harret': '2018-06-18T13:59:18+00:00',
#     'x': 380555,
#     'sv': '0726',
#     'coordonnees': [47.491003, -0.57636108],
#     'idligne': 268435463,
#     'numarret': 21066},
#    'geometry': {'type': 'Point', 'coordinates': [-0.57636108, 47.491003]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '056dfb2f15e4ef1d3945b94183f2519279d3b11d',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 323,
#     'novh': '436',
#     'dest': 'ESPACE ANJOU',
#     'idparcours': 269062656,
#     'cap': 286,
#     'nomarret': 'DOYENNE',
#     'idvh': 268435892,
#     'iddesserte': 269062665,
#     'mnemoligne': '09',
#     'y': 2280777,
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'mnemoarret': 'DOYENNE',
#     'idarret': 670855,
#     'harret': '2018-06-18T13:59:48+00:00',
#     'x': 384142,
#     'sv': '0903',
#     'coordonnees': [47.491183, -0.52873606],
#     'idligne': 268435465,
#     'numarret': 24995},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52873606, 47.491183]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd110e1c9e41eb28cc65d5fb9906627c0ca61e895',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 24,
#     'novh': '530',
#     'dest': 'ST AUBIN LA SALLE',
#     'idparcours': 269233408,
#     'cap': 309,
#     'nomarret': 'VILLAGE SANTE',
#     'idvh': 268435986,
#     'iddesserte': 269233419,
#     'mnemoligne': '12',
#     'y': 2276864,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'VILSANTE',
#     'idarret': 670307,
#     'harret': '2018-06-18T13:59:23+00:00',
#     'x': 385508,
#     'sv': '1207',
#     'coordonnees': [47.456455, -0.50874003],
#     'idligne': 268435468,
#     'numarret': 17408},
#    'geometry': {'type': 'Point', 'coordinates': [-0.50874003, 47.456455]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'abb9c3fdc7e92b38615dfa2359b4ff247c92c750',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 1127,
#     'novh': '536',
#     'dest': 'BEAUCOUZE  HAUTE ROCHE',
#     'idparcours': 268741632,
#     'cap': 118,
#     'nomarret': 'GEMMETRIE',
#     'idvh': 268435992,
#     'iddesserte': 268741645,
#     'mnemoligne': '04',
#     'y': 2277458,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'GEMMETR',
#     'idarret': 669737,
#     'harret': '2018-06-18T13:58:59+00:00',
#     'x': 386406,
#     'sv': '0427',
#     'coordonnees': [47.462087, -0.49712231],
#     'idligne': 268435460,
#     'numarret': 27273},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49712231, 47.462087]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'e5812a9ccb0bd902d9a22e36d4fe05cd190e17cd',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 2,
#     'novh': '541',
#     'dest': 'SAINTE GEMMES',
#     'idparcours': 269198848,
#     'cap': 33,
#     'nomarret': 'GRAND MAINE',
#     'idvh': 268435997,
#     'iddesserte': 269198862,
#     'mnemoligne': '11',
#     'y': 2278138,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'GDMAINE',
#     'idarret': 669731,
#     'harret': '2018-06-18T13:59:01+00:00',
#     'x': 379058,
#     'sv': '1122',
#     'coordonnees': [47.465775, -0.59485209],
#     'idligne': 268435467,
#     'numarret': 14612},
#    'geometry': {'type': 'Point', 'coordinates': [-0.59485209, 47.465775]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '970584f6ee3dc808db238005d8da0cac59de5961',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': -27,
#     'novh': '611',
#     'dest': 'BELLE BEILLE',
#     'idparcours': 268545536,
#     'cap': 339,
#     'nomarret': 'MARIUS BRIANT',
#     'idvh': 268436067,
#     'iddesserte': 268545565,
#     'mnemoligne': '01',
#     'y': 2278985,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'MBRIAN-E',
#     'idarret': 671012,
#     'harret': '2018-06-18T13:58:32+00:00',
#     'x': 380393,
#     'sv': '0126',
#     'coordonnees': [47.473835, -0.57757265],
#     'idligne': 268435457,
#     'numarret': 380053},
#    'geometry': {'type': 'Point', 'coordinates': [-0.57757265, 47.473835]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'fca68a46e97fe6b917c4be714f2f90824a694bd4',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 126,
#     'novh': '613',
#     'dest': 'BELLE BEILLE',
#     'idparcours': 268545536,
#     'cap': 243,
#     'nomarret': 'GARDOT',
#     'idvh': 268436069,
#     'iddesserte': 268545548,
#     'mnemoligne': '01',
#     'y': 2278246,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'GARDOT',
#     'idarret': 669711,
#     'harret': '2018-06-18T13:58:29+00:00',
#     'x': 383708,
#     'sv': '0103',
#     'coordonnees': [47.468289, -0.53326536],
#     'idligne': 268435457,
#     'numarret': 27530},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53326536, 47.468289]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a777f1ace4019b5f775a24a70db74c8a946649ce',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 248,
#     'novh': '618',
#     'dest': 'BEAUCOUZE  HAUTE ROCHE',
#     'idparcours': 268741632,
#     'cap': 267,
#     'nomarret': 'LAREVELLIERE',
#     'idvh': 268436074,
#     'iddesserte': 268741654,
#     'mnemoligne': '04',
#     'y': 2278558,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'LAMART',
#     'idarret': 670854,
#     'harret': '2018-06-18T13:58:36+00:00',
#     'x': 383851,
#     'sv': '0410',
#     'coordonnees': [47.471141, -0.53152073],
#     'idligne': 268435460,
#     'numarret': 79764},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53152073, 47.471141]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '37ba40bfbe41e79b0b5dd11a93bc0df89426ed0e',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 356,
#     'novh': '663',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611584,
#     'cap': 70,
#     'nomarret': 'ARENA LOIRE',
#     'idvh': 268436119,
#     'iddesserte': 268611620,
#     'mnemoligne': '02',
#     'y': 2275267,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'GRCARR-E',
#     'idarret': 669756,
#     'harret': '2018-06-18T13:59:06+00:00',
#     'x': 387535,
#     'sv': '0201',
#     'coordonnees': [47.442757, -0.48111547],
#     'idligne': 268435458,
#     'numarret': 7784},
#    'geometry': {'type': 'Point', 'coordinates': [-0.48111547, 47.442757]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '3dcde40073a7428c513a255b9f510d94917b4c08',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': -10,
#     'novh': '669',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611584,
#     'cap': 122,
#     'nomarret': 'BOURGONNIER',
#     'idvh': 268436125,
#     'iddesserte': 268611602,
#     'mnemoligne': '02',
#     'y': 2277646,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'BOUGO.-E',
#     'idarret': 669455,
#     'harret': '2018-06-18T13:59:07+00:00',
#     'x': 382911,
#     'sv': '0211',
#     'coordonnees': [47.462634, -0.54353895],
#     'idligne': 268435458,
#     'numarret': 10871},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54353895, 47.462634]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '3ad238cd9a5428b65f240fab9f26c0ecd34e4c3b',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniArtE6',
#     'ecart': 16,
#     'novh': '686',
#     'dest': "BEAUCOUZE L'ATOLL",
#     'idparcours': 268739072,
#     'cap': 301,
#     'nomarret': "CHATEAU D'ANGERS",
#     'idvh': 268436142,
#     'iddesserte': 268739103,
#     'mnemoligne': '04',
#     'y': 2278418,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'CHDARR-E',
#     'idarret': 669535,
#     'harret': '2018-06-18T13:58:31+00:00',
#     'x': 381691,
#     'sv': '0422',
#     'coordonnees': [47.46917, -0.56008713],
#     'idligne': 268435460,
#     'numarret': 31053},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56008713, 47.46917]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '83056f92cee02dac088d72a7a7abe3523929d5f0',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 257,
#     'novh': '812',
#     'dest': 'ZI EST',
#     'idparcours': 268840192,
#     'cap': 271,
#     'nomarret': 'LES DENIERS',
#     'idvh': 268436268,
#     'iddesserte': 268840209,
#     'mnemoligne': '06',
#     'y': 2278185,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'LEDENIER',
#     'idarret': 669886,
#     'harret': '2018-06-18T13:58:39+00:00',
#     'x': 378816,
#     'sv': '0607',
#     'coordonnees': [47.466116, -0.59808315],
#     'idligne': 268435462,
#     'numarret': 6046},
#    'geometry': {'type': 'Point', 'coordinates': [-0.59808315, 47.466116]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6898f9644086f005a620ca7f8541875967116336',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 100,
#     'novh': '816',
#     'dest': 'CHANTOURTEAU PAR HARENCHE',
#     'idparcours': 268872704,
#     'cap': 224,
#     'nomarret': 'COINTREAU',
#     'idvh': 268436272,
#     'iddesserte': 268872708,
#     'mnemoligne': '06',
#     'y': 2279057,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'COINTREA',
#     'idarret': 669579,
#     'harret': '2018-06-18T13:59:13+00:00',
#     'x': 385671,
#     'sv': '0603',
#     'coordonnees': [47.476221, -0.50763217],
#     'idligne': 268435462,
#     'numarret': 9457},
#    'geometry': {'type': 'Point', 'coordinates': [-0.50763217, 47.476221]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '693773c499fda2831e4b3ce841ee8cd52b85c5de',
#    'fields': {'etat': 'HL',
#     'type': 'MERCEDES',
#     'ecart': 128,
#     'novh': '8769',
#     'dest': 'ST LEGER LA COUDRE',
#     'idparcours': 270734592,
#     'cap': 275,
#     'nomarret': 'LA RENARDIERE',
#     'idvh': 268444225,
#     'iddesserte': 270734603,
#     'mnemoligne': '35',
#     'y': 2280881,
#     'nomligne': 'St LEGER St LAMBERT <> GARE',
#     'mnemoarret': 'RENAR-E',
#     'idarret': 670586,
#     'harret': '2018-06-18T13:59:29+00:00',
#     'x': 373336,
#     'sv': '3507',
#     'coordonnees': [47.488485, -0.67208897],
#     'idligne': 268435491,
#     'numarret': 19748},
#    'geometry': {'type': 'Point', 'coordinates': [-0.67208897, 47.488485]},
#    'record_timestamp': '2018-06-18T13:58:35+00:00'}]}

# %% [markdown]
# # Remplissage de DataFrame

# %% [markdown]
# On peut construire une `DataFrame` directement à partir d'un "dictionnaires de colonnes".

# %%
df = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [3, 4, 1]
})

df
# Out:
#    a  b
# 0  1  3
# 1  2  4
# 2  3  1

# %% [markdown]
# Par exemple, listons les arrêts, leur id, leur nom et leurs coordonnées GPS.

# %%
dd = g.json()['records']

# %%
dd[0]
# Out:
# {'datasetid': 'bus-tram-position-tr',
#  'recordid': '7d38ad93bae9122ed8d759dbf052ddecb200ded5',
#  'fields': {'etat': 'LIGN',
#   'type': 'GX 427 Hyb',
#   'ecart': 338,
#   'novh': '201',
#   'dest': 'BEAUCOUZE  HAUTE ROCHE',
#   'idparcours': 268741632,
#   'cap': 6,
#   'nomarret': 'GAUBERT',
#   'idvh': 268435657,
#   'iddesserte': 268741673,
#   'mnemoligne': '04',
#   'y': 2278950,
#   'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#   'mnemoarret': 'GAUBER-E',
#   'idarret': 669723,
#   'harret': '2018-06-18T13:59:43+00:00',
#   'x': 378709,
#   'sv': '0407',
#   'coordonnees': [47.472957, -0.59988059],
#   'idligne': 268435460,
#   'numarret': 12547},
#  'geometry': {'type': 'Point', 'coordinates': [-0.59988059, 47.472957]},
#  'record_timestamp': '2018-06-18T13:58:35+00:00'}

# %%
#Arret
id_arret = [elem['fields']['idarret'] for elem in dd]
nom_arret = [elem['fields']['nomarret'] for elem in dd]
mne_arret = [elem['fields']['mnemoarret'] for elem in dd]

arret = pd.DataFrame({
    'id_arret': id_arret,
    'nom_arret': nom_arret,
    'mne_arret': mne_arret
})

arret.info()

arret.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 3 columns):
# id_arret     134 non-null int64
# nom_arret    134 non-null object
# mne_arret    134 non-null object
# dtypes: int64(1), object(2)
# memory usage: 3.2+ KB
#      id_arret            nom_arret mne_arret
# 91     669474              CAMELIA  CAMELI-E
# 102    669626             DIONNEAU  DIONNE-E
# 26     669397    ST AUBIN LA SALLE  BARONNER
# 101    670094    PLACE DE L'EUROPE  PLDEUR-E
# 61     669458               BOURSE  BOURSE-E
# 83     670819            AQUA VITA  AQUA-D5A
# 56     669567  CLINIQUE DE L'ANJOU  CLINANJO
# 118    670214      SORTIE TRAM CTT   SDPTRAM
# 130    669535     CHATEAU D'ANGERS  CHDARR-E
# 115    669953   MAIRIE PONTS DE CE   MAPTSCE

# %%
#Bus
id_vh = [elem['fields']['idvh'] for elem in dd]
type_vh = [elem['fields']['type'] for elem in dd]
etat_vh = [elem['fields']['etat'] for elem in dd]

bus = pd.DataFrame({
    'id_vh': id_vh,
    'type_vh': type_vh,
    'etat_vh': etat_vh
})

bus.info()

bus.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 5 columns):
# id_vh        134 non-null int64
# type_vh      134 non-null object
# etat_vh      134 non-null object
# latitude     134 non-null float64
# longitude    134 non-null float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 5.3+ KB
#          id_vh    type_vh etat_vh   latitude  longitude
# 26   268435918   OMNICITY    TDEP  47.489367  -0.503753
# 62   268435991     GX 327    LIGN  47.487193  -0.552383
# 117  268436134  OmniArtE6    LIGN  47.445524  -0.465380
# 95   268436111    OMNIART    LIGN  47.400466  -0.543098
# 14   268436107    OMNIART    LIGN  47.492487  -0.502432
# 13   268436079   MAN City    LIGN  47.489261  -0.584087
# 85   268435887   OMNICITY    LIGN  47.470001  -0.618409
# 81   268436124    OMNIART    TDEP  47.472720  -0.485927
# 48   268436473    CITADIS    LIGN  47.493548  -0.576115
# 110  268436459    CITADIS    LIGN  47.508634  -0.591461

# %%
#Ligne
id_ligne = [elem['fields']['idligne'] for elem in dd]
nom_ligne = [elem['fields']['nomligne'] for elem in dd]
mne_ligne = [elem['fields']['mnemoligne'] for elem in dd]

ligne = pd.DataFrame({
    'id_ligne': id_arret,
    'nom_ligne': nom_ligne,
    'mne_ligne': mne_ligne
})

ligne.info()

ligne
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 3 columns):
# id_ligne     134 non-null int64
# nom_ligne    134 non-null object
# mne_ligne    134 non-null object
# dtypes: int64(1), object(2)
# memory usage: 3.2+ KB
#      id_ligne                         nom_ligne mne_ligne
# 0      669723        BEAUCOUZE <> ST BARTHELEMY        04
# 1      669609     ST LEZIN SORGES <> SCHWEITZER        10
# 2      669481       HOPITAL <> MONTREUIL JUIGNE        07
# 3      669332       HOPITAL <> MONTREUIL JUIGNE        07
# 4      669615     ST LEZIN SORGES <> SCHWEITZER        10
# 5      669917   M-MARCILLE <> ST AUBIN LA SALLE        12
# 6      669475    CIRCULAIRE VERNEAU GARE EUROPE        05
# 7      670213        BEAUCOUZE <> ST BARTHELEMY        04
# 8      669447        BELLE BEILLE <> MONPLAISIR        01
# 9      670290     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 10     669768        BEAUCOUZE <> ST BARTHELEMY        04
# 11     669343        BELLE BEILLE <> MONPLAISIR        01
# 12     669729        BELLE BEILLE <> MONPLAISIR        01
# 13     669540   MURS ERIGNE <> ADEZIERE SALETTE        03
# 14     670190     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 15     669456     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 16     669928     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 17     669545        BEAUCOUZE <> ST BARTHELEMY        04
# 18     669615   MURS ERIGNE <> ADEZIERE SALETTE        03
# 19     669907  LAC MAINE <> STE GEMMES CL ANJOU        11
# 20     669864           BOUCHEMAINE <> Z I  EST        06
# 21     669315               ARDENNE <> ROSERAIE         A
# 22     669281               ARDENNE <> ROSERAIE         A
# 23     669306               ARDENNE <> ROSERAIE         A
# 24     671023        EXPRESS MONTREUIL <> GARES        13
# 25     670760        BEAUCOUZE <> ST BARTHELEMY        04
# 26     669397   M-MARCILLE <> ST AUBIN LA SALLE        12
# 27     670213        BEAUCOUZE <> ST BARTHELEMY        04
# 28     669394     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 29     669780       HOPITAL <> MONTREUIL JUIGNE        07
# ..        ...                               ...       ...
# 104    669535  PONTS CE <>  AQUAVITA H. RECULEE        08
# 105    669998  PONTS CE <>  AQUAVITA H. RECULEE        08
# 106    669371  PONTS CE <>  AQUAVITA H. RECULEE        08
# 107    669687           BOUCHEMAINE <> Z I  EST        06
# 108    670198           BOUCHEMAINE <> Z I  EST        06
# 109    670117   M-MARCILLE <> ST AUBIN LA SALLE        12
# 110    669308               ARDENNE <> ROSERAIE         A
# 111    669309               ARDENNE <> ROSERAIE         A
# 112    670586     St CLEMENT St LAMBERT <> GARE        38
# 113    669530          SARRIGNE PLESSIS <> GARE        30
# 114    669523           BOUCHEMAINE <> Z I  EST        06
# 115    669953  PONTS CE <>  AQUAVITA H. RECULEE        08
# 116    669663          ESPACE ANJOU <> EVENTARD        09
# 117    669653     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 118    670214               ARDENNE <> ROSERAIE         A
# 119    670678                  BRIOLLAY <> GARE        31
# 120    669842       HOPITAL <> MONTREUIL JUIGNE        07
# 121    670855          ESPACE ANJOU <> EVENTARD        09
# 122    670307   M-MARCILLE <> ST AUBIN LA SALLE        12
# 123    669737        BEAUCOUZE <> ST BARTHELEMY        04
# 124    669731  LAC MAINE <> STE GEMMES CL ANJOU        11
# 125    671012        BELLE BEILLE <> MONPLAISIR        01
# 126    669711        BELLE BEILLE <> MONPLAISIR        01
# 127    670854        BEAUCOUZE <> ST BARTHELEMY        04
# 128    669756     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 129    669455     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 130    669535        BEAUCOUZE <> ST BARTHELEMY        04
# 131    669886           BOUCHEMAINE <> Z I  EST        06
# 132    669579           BOUCHEMAINE <> Z I  EST        06
# 133    670586       St LEGER St LAMBERT <> GARE        35
#
# [134 rows x 3 columns]

# %%
#Trajet
id_bus = [elem['fields']['idvh'] for elem in dd]
id_ligne = [elem['fields']['idligne'] for elem in dd]
latitude = [elem['fields']['coordonnees'][0] for elem in dd]
longitude = [elem['fields']['coordonnees'][1] for elem in dd]

trajet = pd.DataFrame({
    'id_bus': id_bus,
    'id_ligne': id_ligne,
    'latitude': latitude,
    'longitude': longitude
})

trajet.info()

trajet
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 4 columns):
# id_bus       134 non-null int64
# id_ligne     134 non-null int64
# latitude     134 non-null float64
# longitude    134 non-null float64
# dtypes: float64(2), int64(2)
# memory usage: 4.3 KB
#         id_bus   id_ligne   latitude  longitude
# 0    268435657  268435460  47.472957  -0.599881
# 1    268435881  268435466  47.452383  -0.542029
# 2    268435884  268435463  47.538794  -0.616369
# 3    268435899  268435463  47.511879  -0.596595
# 4    268435905  268435466  47.475039  -0.493046
# 5    268435987  268435468  47.470265  -0.547217
# 6    268435994  268435461  47.470320  -0.519211
# 7    268436057  268435460  47.496393  -0.568169
# 8    268436059  268435457  47.478236  -0.584757
# 9    268436064  268435458  47.450235  -0.517192
# 10   268436070  268435460  47.467113  -0.551984
# 11   268436072  268435457  47.487483  -0.527275
# 12   268436078  268435457  47.466082  -0.559375
# 13   268436079  268435459  47.489261  -0.584087
# 14   268436107  268435458  47.492487  -0.502432
# 15   268436110  268435458  47.460333  -0.537986
# 16   268436126  268435458  47.476404  -0.533052
# 17   268436139  268435460  47.470473  -0.516657
# 18   268436158  268435459  47.396007  -0.552972
# 19   268436259  268435467  47.467123  -0.618315
# 20   268436273  268435462  47.471340  -0.533642
# 21   268436461  268435471  47.466922  -0.552425
# 22   268436470  268435471  47.452338  -0.556133
# 23   268436472  268435471  47.443958  -0.553980
# 24   268444858  268435484  47.464399  -0.561527
# 25   268436145  268435460  47.484163  -0.626405
# 26   268435918  268435468  47.489367  -0.503753
# 27   268436137  268435460  47.495525  -0.569769
# 28   268436120  268435458  47.485896  -0.512451
# 29   268435912  268435463  47.480655  -0.555043
# ..         ...        ...        ...        ...
# 104  268436262  268435464  47.466807  -0.559215
# 105  268436267  268435464  47.474649  -0.567395
# 106  268436269  268435464  47.439092  -0.529915
# 107  268436274  268435462  47.469843  -0.548615
# 108  268436275  268435462  47.473671  -0.572638
# 109  268436277  268435468  47.430479  -0.542239
# 110  268436459  268435471  47.508634  -0.591461
# 111  268436468  268435471  47.479360  -0.549595
# 112  268442446  268435494  47.485254  -0.665134
# 113  268442533  268435486  47.481581  -0.523187
# 114  268436276  268435462  47.405975  -0.623333
# 115  268435908  268435464  47.425281  -0.523522
# 116  268435896  268435465  47.470721  -0.511679
# 117  268436134  268435458  47.445524  -0.465380
# 118  268436465  268435471  47.494886  -0.569760
# 119  268442948  268435487  47.464886  -0.565442
# 120  268435885  268435463  47.491003  -0.576361
# 121  268435892  268435465  47.491183  -0.528736
# 122  268435986  268435468  47.456455  -0.508740
# 123  268435992  268435460  47.462087  -0.497122
# 124  268435997  268435467  47.465775  -0.594852
# 125  268436067  268435457  47.473835  -0.577573
# 126  268436069  268435457  47.468289  -0.533265
# 127  268436074  268435460  47.471141  -0.531521
# 128  268436119  268435458  47.442757  -0.481115
# 129  268436125  268435458  47.462634  -0.543539
# 130  268436142  268435460  47.469170  -0.560087
# 131  268436268  268435462  47.466116  -0.598083
# 132  268436272  268435462  47.476221  -0.507632
# 133  268444225  268435491  47.488485  -0.672089
#
# [134 rows x 4 columns]

# %%
#Etape
id_arret = [elem['fields']['idarret'] for elem in dd]
harret = [elem['fields']['harret'] for elem in dd]
record_timestamp = [elem['record_timestamp'] for elem in dd]
ecart = [elem['fields']['ecart'] for elem in dd]

def transfo(row):
    return record_timestamp + dt.timedelta(seconds=ecart)

heure_estime = df.apply(transfo, axis='columns')

etape = pd.DataFrame({
    'id_arret': id_arret,
    'heure_theorique': harret,
    'heure_estime': heure_estime,
    'ecart': ecart
})

etape.info()

etape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-7168337e6fbf> in <module>()
#       8     return record_timestamp + dt.timedelta(seconds=ecart)
#       9
# ---> 10 heure_estime = df.apply(transfo, axis='columns')
#      11
#      12 etape = pd.DataFrame({
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# D:\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# D:\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# D:\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-29-7168337e6fbf> in transfo(row)
#       6
#       7 def transfo(row):
# ----> 8     return record_timestamp + dt.timedelta(seconds=ecart)
#       9
#      10 heure_estime = df.apply(transfo, axis='columns')
#
# NameError: ("name 'dt' is not defined", 'occurred at index 0')
