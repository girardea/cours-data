# %% [markdown]
# # Import des modules nécessaires

# %%
    # Pour manipuler efficacement des tables de données dans Python
    import pandas as pd

    # Pour faire des requêtes GET et POST
    import requests
    
    # Pour gérer les date
    import datetime as dt
    
    # sql
    from sqlalchemy import create_engine

# %%
print(pd.__version__)
# Out:
# 0.23.0

# %%
print(requests.__version__)
# Out:
# 2.18.4

# %% [markdown]
# # Requêtage d'une API REST

# %% [markdown]
# Pour lancer une requête GET, c'est ultra-simple : on utilise `requests.get(url)`.
#
# Si vous voulez glisser des paramètres avec la requête, utilisez l'argument optionnel `params`, qui accepte un simple dictionnaire.

# %%
r = requests.get("https://data.angers.fr/api/records/1.0/search/",
                 params={
                     'dataset': 'horaires-theoriques-et-arrets-du-reseau-irigo-gtfs',
                     'rows': 10
                 })

# %%
g = requests.get("https://data.angers.fr/api/records/1.0/search/",
                 params={
                     'dataset': 'bus-tram-position-tr',
                     'rows': 200
                 })

# %% [markdown]
# Regardons la nature de ce qui nous est renvoyé.

# %%
type(g)
# Out:
# requests.models.Response

# %% [markdown]
# C'est un objet de la classe `Response`. Si vous voulez connaitre toutes les méthodes attachées, faites `help(r)`

# %%
help(g)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, state)
#  |
#  |  close(self)
#  |      Releases the connection back to the pool. Once this method has been
#  |      called the underlying ``raw`` object must not be accessed again.
#  |
#  |      *Note: Should not normally need to be called explicitly.*
#  |
#  |  iter_content(self, chunk_size=1, decode_unicode=False)
#  |      Iterates over the response data.  When stream=True is set on the
#  |      request, this avoids reading the content at once into memory for
#  |      large responses.  The chunk size is the number of bytes it should
#  |      read into memory.  This is not necessarily the length of each item
#  |      returned as decoding can take place.
#  |
#  |      chunk_size must be of type int or None. A value of None will
#  |      function differently depending on the value of `stream`.
#  |      stream=True will read data as it arrives in whatever size the
#  |      chunks are received. If stream=False, data is returned as
#  |      a single chunk.
#  |
#  |      If decode_unicode is True, content will be decoded using the best
#  |      available encoding based on the response.
#  |
#  |  iter_lines(self, chunk_size=512, decode_unicode=None, delimiter=None)
#  |      Iterates over the response data, one line at a time.  When
#  |      stream=True is set on the request, this avoids reading the
#  |      content at once into memory for large responses.
#  |
#  |      .. note:: This method is not reentrant safe.
#  |
#  |  json(self, **kwargs)
#  |      Returns the json-encoded content of a response, if any.
#  |
#  |      :param \*\*kwargs: Optional arguments that ``json.loads`` takes.
#  |      :raises ValueError: If the response body does not contain valid json.
#  |
#  |  raise_for_status(self)
#  |      Raises stored :class:`HTTPError`, if one occurred.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  apparent_encoding
#  |      The apparent encoding, provided by the chardet library.
#  |
#  |  content
#  |      Content of the response, in bytes.
#  |
#  |  is_permanent_redirect
#  |      True if this Response one of the permanent versions of redirect.
#  |
#  |  is_redirect
#  |      True if this Response is a well-formed HTTP redirect that could have
#  |      been processed automatically (by :meth:`Session.resolve_redirects`).
#  |
#  |  links
#  |      Returns the parsed header links of the response, if any.
#  |
#  |  next
#  |      Returns a PreparedRequest for the next request in a redirect chain, if there is one.
#  |
#  |  ok
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  text
#  |      Content of the response, in unicode.
#  |
#  |      If Response.encoding is None, encoding will be guessed using
#  |      ``chardet``.
#  |
#  |      The encoding of the response content is determined based solely on HTTP
#  |      headers, following RFC 2616 to the letter. If you can take advantage of
#  |      non-HTTP knowledge to make a better guess at the encoding, you should
#  |      set ``r.encoding`` appropriately before accessing this property.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __attrs__ = ['_content', 'status_code', 'headers', 'url', 'history', '...

# %% [markdown]
# Pour tester que tout a bien fonctionnné, on va vérifié le statut.

# %%
g.raise_for_status()

# %% [markdown]
# Si ça dit rien c'est que c'est bon :) Dans le doute, regardons le statut...

# %%
g.status_code
# Out:
# 200

# %% [markdown]
# Statut 200 = succès !!

# %%
g.json()
# Out:
# {'nhits': 125,
#  'parameters': {'dataset': ['bus-tram-position-tr'],
#   'timezone': 'UTC',
#   'rows': 200,
#   'format': 'json'},
#  'records': [{'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd2707eca39de09f79bcef7be9101e0af08c1a754',
#    'fields': {'etat': 'HLPS',
#     'type': 'OmniSTDE6',
#     'ecart': 0,
#     'novh': '803',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268720384,
#     'cap': 185,
#     'nomarret': 'SORTIE DEPOT ST BART',
#     'idvh': 268436259,
#     'iddesserte': 268720385,
#     'mnemoligne': '04',
#     'y': 2279028,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'DEPOT SD',
#     'idarret': 671375,
#     'harret': '2018-06-19T07:09:46+00:00',
#     'x': 386788,
#     'sv': '0412',
#     'coordonnees': [47.476323, -0.49280852],
#     'idligne': 268435460,
#     'numarret': 6562},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49280852, 47.476323]},
#    'record_timestamp': '2018-06-19T07:16:13+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a0a5b38fdf8b9abdd0ac05e7bf1854b76737021b',
#    'fields': {'etat': 'HLPS',
#     'type': 'OMNIART',
#     'ecart': 0,
#     'novh': '664',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268525312,
#     'cap': 95,
#     'nomarret': 'SORTIE BUS CTB',
#     'idvh': 268436120,
#     'iddesserte': 268525313,
#     'mnemoligne': '01',
#     'y': 2281389,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'SDCTB',
#     'idarret': 671973,
#     'harret': '2018-06-19T07:45:09+00:00',
#     'x': 381107,
#     'sv': '0104',
#     'coordonnees': [47.495681, -0.56928591],
#     'idligne': 268435457,
#     'numarret': 17220},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56928591, 47.495681]},
#    'record_timestamp': '2018-06-19T07:57:53+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'e9e06aaa63b6f1909e235bab88e3c0c22401af53',
#    'fields': {'etat': 'HLPS',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '443',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268875520,
#     'cap': 5,
#     'nomarret': 'SORTIE DEPOT ST BART',
#     'idvh': 268435899,
#     'iddesserte': 268875521,
#     'mnemoligne': '06',
#     'y': 2278894,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'DEPOT SD',
#     'idarret': 671375,
#     'harret': '2018-06-19T07:26:00+00:00',
#     'x': 386789,
#     'sv': '0621',
#     'coordonnees': [47.475119, -0.49273127],
#     'idligne': 268435462,
#     'numarret': 6562},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49273127, 47.475119]},
#    'record_timestamp': '2018-06-19T07:31:18+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd07052825f8badccd4f05dbbc6b88b0b62e69b92',
#    'fields': {'etat': 'TDEP',
#     'type': 'AGORA123456789ABCDEFART',
#     'ecart': 0,
#     'novh': '702',
#     'dest': 'BEAUCOUZE  HAUTE ROCHE',
#     'idparcours': 268741632,
#     'cap': 118,
#     'nomarret': 'ST BARTH COLLEGE',
#     'idvh': 268436158,
#     'iddesserte': 268741633,
#     'mnemoligne': '04',
#     'y': 2278645,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'SBARTHEL',
#     'idarret': 671963,
#     'harret': '2018-06-19T10:38:00+00:00',
#     'x': 387281,
#     'sv': '0407',
#     'coordonnees': [47.47304, -0.48608954],
#     'idligne': 268435460,
#     'numarret': 11134},
#    'geometry': {'type': 'Point', 'coordinates': [-0.48608954, 47.47304]},
#    'record_timestamp': '2018-06-19T10:28:13+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c1face88ffc04e903b88bc015a11c7192cc278ca',
#    'fields': {'etat': 'HL',
#     'type': 'OMNICITY',
#     'ecart': -247,
#     'novh': '423',
#     'dest': 'SPECIAL PISCINE',
#     'idparcours': 272302336,
#     'cap': 180,
#     'nomarret': 'PISCINE MONPLAISIR',
#     'idvh': 268435879,
#     'iddesserte': 272302338,
#     'mnemoligne': '535',
#     'y': 2278947,
#     'nomligne': 'Piscine MONPLAISIR',
#     'mnemoarret': 'P-MONPL',
#     'idarret': 672636,
#     'harret': '2018-06-18T22:00:00+00:00',
#     'x': 386809,
#     'sv': '53513',
#     'coordonnees': [47.475602, -0.49249141],
#     'idligne': 268435515,
#     'numarret': 804722},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49249141, 47.475602]},
#    'record_timestamp': '2018-06-19T10:10:16+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '14c506f09a99d91c098950a3fe823121db098640',
#    'fields': {'etat': 'HLPS',
#     'type': 'OmniArtE6',
#     'ecart': 0,
#     'novh': '681',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268721408,
#     'cap': 95,
#     'nomarret': 'SORTIE BUS CTB',
#     'idvh': 268436137,
#     'iddesserte': 268721409,
#     'mnemoligne': '04',
#     'y': 2281381,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'SDCTB',
#     'idarret': 671973,
#     'harret': '2018-06-19T06:53:55+00:00',
#     'x': 381077,
#     'sv': '0423',
#     'coordonnees': [47.4956, -0.56967987],
#     'idligne': 268435460,
#     'numarret': 17220},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56967987, 47.4956]},
#    'record_timestamp': '2018-06-19T10:21:55+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c654b6be045e5ffa2ce381caefccce8eb35b7d5c',
#    'fields': {'etat': 'TDEP',
#     'type': 'OmniArtE6',
#     'ecart': 0,
#     'novh': '689',
#     'dest': 'ST BARTHELEMY',
#     'idparcours': 268707072,
#     'cap': 90,
#     'nomarret': "L'ATOLL - BEAUCOUZE",
#     'idvh': 268436145,
#     'iddesserte': 268707073,
#     'mnemoligne': '04',
#     'y': 2280279,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'ATOLLBEA',
#     'idarret': 672520,
#     'harret': '2018-06-19T10:39:00+00:00',
#     'x': 376758,
#     'sv': '0402',
#     'coordonnees': [47.484244, -0.62640945],
#     'idligne': 268435460,
#     'numarret': 20041},
#    'geometry': {'type': 'Point', 'coordinates': [-0.62640945, 47.484244]},
#    'record_timestamp': '2018-06-19T10:30:15+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '330bfa9dc100be890f1ad6d996ec766cdfae6765',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '449',
#     'dest': 'MOULIN MARCILLE PAR TRELA',
#     'idparcours': 269266944,
#     'cap': 90,
#     'nomarret': 'ST AUBIN LA SALLE',
#     'idvh': 268435905,
#     'iddesserte': 269266945,
#     'mnemoligne': '12',
#     'y': 2280507,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'BARONNER',
#     'idarret': 671157,
#     'harret': '2018-06-19T10:39:00+00:00',
#     'x': 386016,
#     'sv': '1210',
#     'coordonnees': [47.489367, -0.50375319],
#     'idligne': 268435468,
#     'numarret': 2861},
#    'geometry': {'type': 'Point', 'coordinates': [-0.50375319, 47.489367]},
#    'record_timestamp': '2018-06-19T10:32:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'eccdff00c372435527fda3fdf2c58cdb4f76720b',
#    'fields': {'etat': 'TDEP',
#     'type': 'OmniSTDE6',
#     'ecart': 0,
#     'novh': '814',
#     'dest': 'BOUCHEMAINE CENTRE',
#     'idparcours': 268873728,
#     'cap': 262,
#     'nomarret': 'ZI. EST',
#     'idvh': 268436270,
#     'iddesserte': 268873729,
#     'mnemoligne': '06',
#     'y': 2278873,
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'mnemoarret': 'ZIEST',
#     'idarret': 672083,
#     'harret': '2018-06-19T10:41:00+00:00',
#     'x': 386693,
#     'sv': '0622',
#     'coordonnees': [47.474899, -0.49399403],
#     'idligne': 268435462,
#     'numarret': 24046},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49399403, 47.474899]},
#    'record_timestamp': '2018-06-19T10:35:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c22f1921661fede0c6f6635c9e3bddf9f5d46476',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': -110,
#     'novh': '453',
#     'dest': 'MOULIN MARCILLE PAR TRELA',
#     'idparcours': 269266944,
#     'cap': 210,
#     'nomarret': 'PLACE LORRAINE',
#     'idvh': 268435909,
#     'iddesserte': 269266964,
#     'mnemoligne': '12',
#     'y': 2278670,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'LOHUIT',
#     'idarret': 671677,
#     'harret': '2018-06-19T10:38:50+00:00',
#     'x': 382714,
#     'sv': '1208',
#     'coordonnees': [47.471773, -0.54664839],
#     'idligne': 268435468,
#     'numarret': 5526},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54664839, 47.471773]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a627776c208afbfbfe4fcb5838046358a0b64ab9',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 228,
#     'novh': '454',
#     'dest': 'MAIRIE DES PONTS DE CE',
#     'idparcours': 269004800,
#     'cap': 104,
#     'nomarret': 'RIVET',
#     'idvh': 268435910,
#     'iddesserte': 269004835,
#     'mnemoligne': '08',
#     'y': 2274685,
#     'nomligne': 'PONTS CE <>  AQUAVITA H. RECULEE',
#     'mnemoarret': 'RIVET-E',
#     'idarret': 671927,
#     'harret': '2018-06-19T10:37:27+00:00',
#     'x': 384507,
#     'sv': '0803',
#     'coordonnees': [47.436542, -0.52095611],
#     'idligne': 268435464,
#     'numarret': 5331},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52095611, 47.436542]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '11f4c1b37f06116e5b390b43b8e54697d256c67d',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': -127,
#     'novh': '457',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268796928,
#     'cap': 326,
#     'nomarret': 'AQUA VITA',
#     'idvh': 268435913,
#     'iddesserte': 268796930,
#     'mnemoligne': '05',
#     'y': 2281475,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'AQVI-D5B',
#     'idarret': 672581,
#     'harret': '2018-06-19T10:38:32+00:00',
#     'x': 381189,
#     'sv': '0521',
#     'coordonnees': [47.496482, -0.56824053],
#     'idligne': 268435461,
#     'numarret': 96211},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56824053, 47.496482]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '8761725445b2f9ae6b68bcdf6c2d59173db8f9cf',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 334,
#     'novh': '538',
#     'dest': 'POLE 49 par SCHWEITZER',
#     'idparcours': 269101312,
#     'cap': 71,
#     'nomarret': 'CHALOUERE',
#     'idvh': 268435994,
#     'iddesserte': 269101352,
#     'mnemoligne': '10',
#     'y': 2279583,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'CHALOU-E',
#     'idarret': 671279,
#     'harret': '2018-06-19T10:37:16+00:00',
#     'x': 383264,
#     'sv': '1009',
#     'coordonnees': [47.480161, -0.5398002],
#     'idligne': 268435466,
#     'numarret': 16972},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5398002, 47.480161]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a1b0c279c5f0d4879ca2c32b0ea558e39a40bec6',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': -38,
#     'novh': '601',
#     'dest': 'BELLE BEILLE',
#     'idparcours': 268545536,
#     'cap': 315,
#     'nomarret': 'GARES PAPIN',
#     'idvh': 268436057,
#     'iddesserte': 268545555,
#     'mnemoligne': '01',
#     'y': 2277985,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'GAREPA-E',
#     'idarret': 671475,
#     'harret': '2018-06-19T10:36:48+00:00',
#     'x': 381916,
#     'sv': '0121',
#     'coordonnees': [47.465352, -0.55689299],
#     'idligne': 268435457,
#     'numarret': 715},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55689299, 47.465352]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '09f8443253a4eefd0208aae651dc2f15bdf2f09f',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': -40,
#     'novh': '603',
#     'dest': 'MONPLAISIR',
#     'idparcours': 268513024,
#     'cap': 68,
#     'nomarret': 'NOTRE DAME DU LAC',
#     'idvh': 268436059,
#     'iddesserte': 268513030,
#     'mnemoligne': '01',
#     'y': 2279793,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'NDAMELAC',
#     'idarret': 671792,
#     'harret': '2018-06-19T10:37:34+00:00',
#     'x': 379162,
#     'sv': '0102',
#     'coordonnees': [47.480686, -0.59429214],
#     'idligne': 268435457,
#     'numarret': 23915},
#    'geometry': {'type': 'Point', 'coordinates': [-0.59429214, 47.480686]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '97f6ce6f0689c56277361a552ab05a4d51c5bc50',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 148,
#     'novh': '614',
#     'dest': 'MONPLAISIR',
#     'idparcours': 268513024,
#     'cap': 45,
#     'nomarret': 'FOCH HARAS',
#     'idvh': 268436070,
#     'iddesserte': 268513046,
#     'mnemoligne': '01',
#     'y': 2278160,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'HARAS',
#     'idarret': 671528,
#     'harret': '2018-06-19T10:36:31+00:00',
#     'x': 382288,
#     'sv': '0101',
#     'coordonnees': [47.467048, -0.55204726],
#     'idligne': 268435457,
#     'numarret': 20835},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55204726, 47.467048]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'ca5f9f90466b1fe721348057a739de323c1f62b0',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': -31,
#     'novh': '616',
#     'dest': 'ST BARTHELEMY',
#     'idparcours': 268706560,
#     'cap': 80,
#     'nomarret': 'MAISON DE TECHNOPOLE',
#     'idvh': 268436072,
#     'iddesserte': 268706579,
#     'mnemoligne': '04',
#     'y': 2279558,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'MATEC.',
#     'idarret': 671722,
#     'harret': '2018-06-19T10:36:31+00:00',
#     'x': 378318,
#     'sv': '0425',
#     'coordonnees': [47.47829, -0.60536599],
#     'idligne': 268435460,
#     'numarret': 9274},
#    'geometry': {'type': 'Point', 'coordinates': [-0.60536599, 47.47829]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd256116331bdd077cabb56b796160ec1f9b3e536',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 51,
#     'novh': '622',
#     'dest': 'MONPLAISIR',
#     'idparcours': 268513024,
#     'cap': 13,
#     'nomarret': 'FRATELLINI',
#     'idvh': 268436078,
#     'iddesserte': 268513054,
#     'mnemoligne': '01',
#     'y': 2278379,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'CIEST.-E',
#     'idarret': 671308,
#     'harret': '2018-06-19T10:37:07+00:00',
#     'x': 383829,
#     'sv': '0105',
#     'coordonnees': [47.469525, -0.53172573],
#     'idligne': 268435457,
#     'numarret': 23398},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53172573, 47.469525]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '58d6606ab15a377baf27fad8857c7941efc6b8d8',
#    'fields': {'etat': 'TDEP',
#     'type': 'MAN City',
#     'ecart': 24,
#     'novh': '623',
#     'dest': 'AVRILLE ADEZIERE',
#     'idparcours': 268641536,
#     'cap': 0,
#     'nomarret': 'MURS ERIGNE',
#     'idvh': 268436079,
#     'iddesserte': 268641537,
#     'mnemoligne': '03',
#     'y': 2270221,
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'mnemoarret': 'MURSERIG',
#     'idarret': 671785,
#     'harret': '2018-06-19T10:36:24+00:00',
#     'x': 381715,
#     'sv': '0306',
#     'coordonnees': [47.395496, -0.55576757],
#     'idligne': 268435459,
#     'numarret': 22074},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55576757, 47.395496]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'dffc3b25e4e34ecd2cef8eff3568305edd7045f1',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 143,
#     'novh': '651',
#     'dest': 'BEAUCOUZE  HAUTE ROCHE',
#     'idparcours': 268741632,
#     'cap': 216,
#     'nomarret': 'FOCH MAISON BLEUE',
#     'idvh': 268436107,
#     'iddesserte': 268741658,
#     'mnemoligne': '04',
#     'y': 2278443,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'FO-LOR-R',
#     'idarret': 671447,
#     'harret': '2018-06-19T10:36:42+00:00',
#     'x': 382544,
#     'sv': '0406',
#     'coordonnees': [47.469677, -0.54879155],
#     'idligne': 268435460,
#     'numarret': 170},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54879155, 47.469677]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '397a1a8465f0a320704c8e49423d5602f81800da',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 415,
#     'novh': '654',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611072,
#     'cap': 284,
#     'nomarret': 'QUANTINIERE',
#     'idvh': 268436110,
#     'iddesserte': 268611129,
#     'mnemoligne': '02',
#     'y': 2276268,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'QUANTI-E',
#     'idarret': 672665,
#     'harret': '2018-06-19T10:37:26+00:00',
#     'x': 388450,
#     'sv': '0209',
#     'coordonnees': [47.452049, -0.46946522],
#     'idligne': 268435458,
#     'numarret': 83420},
#    'geometry': {'type': 'Point', 'coordinates': [-0.46946522, 47.452049]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '9d9442de2731053444e1871f103d3f6d8681bd25',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 144,
#     'novh': '670',
#     'dest': "BEAUCOUZE L'ATOLL",
#     'idparcours': 268739072,
#     'cap': 302,
#     'nomarret': 'BALZAC',
#     'idvh': 268436126,
#     'iddesserte': 268739106,
#     'mnemoligne': '04',
#     'y': 2278859,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'BALZAC-E',
#     'idarret': 671437,
#     'harret': '2018-06-19T10:36:36+00:00',
#     'x': 380459,
#     'sv': '0405',
#     'coordonnees': [47.472724, -0.5766357],
#     'idligne': 268435460,
#     'numarret': 1432},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5766357, 47.472724]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '29857e6a1d70228cebf7abe4877f19094f4a5587',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniArtE6',
#     'ecart': 406,
#     'novh': '683',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611584,
#     'cap': 111,
#     'nomarret': 'CHOUTEAU',
#     'idvh': 268436139,
#     'iddesserte': 268611614,
#     'mnemoligne': '02',
#     'y': 2275692,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'CHOUTE-E',
#     'idarret': 671302,
#     'harret': '2018-06-19T10:37:07+00:00',
#     'x': 386367,
#     'sv': '0206',
#     'coordonnees': [47.446199, -0.49679485],
#     'idligne': 268435458,
#     'numarret': 22740},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49679485, 47.446199]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'adfe21ef157d323c7568362828aba5315bfea5c7',
#    'fields': {'etat': 'HL',
#     'type': 'OmniSTDE6',
#     'ecart': 149,
#     'novh': '817',
#     'dest': 'ST AUBIN LA SALLE',
#     'idparcours': 269233408,
#     'cap': 298,
#     'nomarret': 'MAIL',
#     'idvh': 268436273,
#     'iddesserte': 269233430,
#     'mnemoligne': '12',
#     'y': 2278511,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'MAIL-HDV',
#     'idarret': 671700,
#     'harret': '2018-06-19T10:37:28+00:00',
#     'x': 382401,
#     'sv': '1201',
#     'coordonnees': [47.470241, -0.55072038],
#     'idligne': 268435468,
#     'numarret': 7828},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55072038, 47.470241]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'b95e98363405c9aa34a2927c7b4b1694df5d455d',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 152,
#     'novh': '1005',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 175,
#     'nomarret': 'PLACE LA FAYETTE',
#     'idvh': 268436461,
#     'iddesserte': 269451541,
#     'mnemoligne': 'A',
#     'y': 2277760,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1LAFA',
#     'idarret': 671055,
#     'harret': '2018-06-19T10:37:31+00:00',
#     'x': 382035,
#     'sv': 'A13',
#     'coordonnees': [47.463369, -0.55520578],
#     'idligne': 268435471,
#     'numarret': 31950},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55520578, 47.463369]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6649fd4dfef1b561ba530e1bc102b820b6dbe42c',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 35,
#     'novh': '1014',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 149,
#     'nomarret': 'PLACE MOLIERE',
#     'idvh': 268436470,
#     'iddesserte': 269451536,
#     'mnemoligne': 'A',
#     'y': 2278970,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1MOLI',
#     'idarret': 671057,
#     'harret': '2018-06-19T10:36:35+00:00',
#     'x': 382110,
#     'sv': 'A04',
#     'coordonnees': [47.474271, -0.55480206],
#     'idligne': 268435471,
#     'numarret': 2492},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55480206, 47.474271]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'ed7cfc069de9bd032567e715cfa8a3d1f43778f3',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 126,
#     'novh': '1016',
#     'dest': 'AVRILLE ARDENNE',
#     'idparcours': 269419008,
#     'cap': 331,
#     'nomarret': 'TERRA BOTANICA',
#     'idvh': 268436472,
#     'iddesserte': 269419028,
#     'mnemoligne': 'A',
#     'y': 2281247,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2BOTA',
#     'idarret': 671070,
#     'harret': '2018-06-19T10:38:16+00:00',
#     'x': 380916,
#     'sv': 'A11',
#     'coordonnees': [47.494341, -0.57174939],
#     'idligne': 268435471,
#     'numarret': 22213},
#    'geometry': {'type': 'Point', 'coordinates': [-0.57174939, 47.494341]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '90bb882bba892248a073270fbb54cc63551ed5f4',
#    'fields': {'etat': 'LIGN',
#     'type': 'AXER',
#     'ecart': 248,
#     'novh': '7182',
#     'dest': 'SOUCELLES HERMITAGE',
#     'idparcours': 270535168,
#     'cap': 122,
#     'nomarret': 'FOCH HARAS',
#     'idvh': 268442638,
#     'iddesserte': 270535170,
#     'mnemoligne': '32',
#     'y': 2278116,
#     'nomligne': 'SOUCELLES PELLOUAILLES <> GARE',
#     'mnemoarret': 'HARAS',
#     'idarret': 671528,
#     'harret': '2018-06-19T10:37:06+00:00',
#     'x': 382173,
#     'sv': '3207',
#     'coordonnees': [47.466615, -0.55355023],
#     'idligne': 268435488,
#     'numarret': 20835},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55355023, 47.466615]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'ff55276513f30d4f55f0d9c67d7782533000e612',
#    'fields': {'etat': 'LIGN',
#     'type': 'ARES',
#     'ecart': 109,
#     'novh': '8091',
#     'dest': 'ST LEGER LES ESSARTS',
#     'idparcours': 270734848,
#     'cap': 32,
#     'nomarret': "CHATEAU D'ANGERS",
#     'idvh': 268443547,
#     'iddesserte': 270734850,
#     'mnemoligne': '35',
#     'y': 2278338,
#     'nomligne': 'St LEGER St LAMBERT <> GARE',
#     'mnemoarret': 'CHDARR-E',
#     'idarret': 671295,
#     'harret': '2018-06-19T10:36:38+00:00',
#     'x': 381790,
#     'sv': '3519',
#     'coordonnees': [47.468484, -0.55873566],
#     'idligne': 268435491,
#     'numarret': 31053},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55873566, 47.468484]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '93928ecf52fef30c29fbf86c3bb9b795cdb823e8',
#    'fields': {'etat': 'HL',
#     'type': 'RECREO',
#     'ecart': 131,
#     'novh': '8109',
#     'dest': 'LA MEMBROLLE',
#     'idparcours': 270992384,
#     'cap': 39,
#     'nomarret': 'PLACE MONPROFIT',
#     'idvh': 268443565,
#     'iddesserte': 270992387,
#     'mnemoligne': '39',
#     'y': 2278768,
#     'nomligne': 'LA MEMBROLLE <> GARE',
#     'mnemoarret': 'MONPR -E',
#     'idarret': 671755,
#     'harret': '2018-06-19T10:37:30+00:00',
#     'x': 381221,
#     'sv': '3907',
#     'coordonnees': [47.47216, -0.5664891],
#     'idligne': 268435495,
#     'numarret': 15116},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5664891, 47.47216]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '7e637676a9acfb4fd74d683dbc9f5860af6db234',
#    'fields': {'etat': 'LIGN',
#     'type': 'Low Entry',
#     'ecart': 200,
#     'novh': '9401',
#     'dest': 'CHANTOURTEAU',
#     'idparcours': 270369280,
#     'cap': 182,
#     'nomarret': 'CHEVRIERE',
#     'idvh': 268444857,
#     'iddesserte': 270369301,
#     'mnemoligne': '15',
#     'y': 2273673,
#     'nomligne': 'EXPRESS CHANTOURTEAU <> GARES',
#     'mnemoarret': 'CHEVRI-E',
#     'idarret': 671298,
#     'harret': '2018-06-19T10:37:00+00:00',
#     'x': 377773,
#     'sv': '1534',
#     'coordonnees': [47.425209, -0.609665],
#     'idligne': 268435485,
#     'numarret': 7832},
#    'geometry': {'type': 'Point', 'coordinates': [-0.609665, 47.425209]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c69372bacb0214e0bd77b75ba8d31ac3d10aeb9c',
#    'fields': {'etat': 'LIGN',
#     'type': 'Low Entry',
#     'ecart': 28,
#     'novh': '9402',
#     'dest': 'MONTEUIL DOMAINE DU VAL',
#     'idparcours': 270283008,
#     'cap': 325,
#     'nomarret': 'CHEMIN NOIR',
#     'idvh': 268444858,
#     'iddesserte': 270283023,
#     'mnemoligne': '13',
#     'y': 2285201,
#     'nomligne': 'EXPRESS MONTREUIL <> GARES',
#     'mnemoarret': 'CHENOI-E',
#     'idarret': 672751,
#     'harret': '2018-06-19T10:36:28+00:00',
#     'x': 379601,
#     'sv': '1334',
#     'coordonnees': [47.529443, -0.5911442],
#     'idligne': 268435484,
#     'numarret': 903926},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5911442, 47.529443]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd0336bf87cfa1a8ebcbc46581cdcb22d4e9aaff9',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '463',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 269277184,
#     'cap': 264,
#     'nomarret': 'RELEVE DEPOT',
#     'idvh': 268435919,
#     'iddesserte': 269277185,
#     'mnemoligne': '12',
#     'y': 2278880,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'REL-DEPO',
#     'idarret': 672512,
#     'harret': '2018-06-19T10:39:00+00:00',
#     'x': 386704,
#     'sv': '1202',
#     'coordonnees': [47.474966, -0.49385153],
#     'idligne': 268435468,
#     'numarret': 16504},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49385153, 47.474966]},
#    'record_timestamp': '2018-06-19T10:34:55+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'f5d83fb84acf66fbe7a5d9e742b97e7ddfd40cd4',
#    'fields': {'etat': 'TDEP',
#     'type': 'CITADIS',
#     'ecart': 0,
#     'novh': '1017',
#     'dest': 'AVRILLE ARDENNE',
#     'idparcours': 269419520,
#     'cap': 226,
#     'nomarret': 'ANGERS - ROSERAIE',
#     'idvh': 268436473,
#     'iddesserte': 269419521,
#     'mnemoligne': 'A',
#     'y': 2275585,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1ANRO',
#     'idarret': 672088,
#     'harret': '2018-06-19T10:37:30+00:00',
#     'x': 382039,
#     'sv': 'A10',
#     'coordonnees': [47.44382, -0.55409176],
#     'idligne': 268435471,
#     'numarret': 3935},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55409176, 47.44382]},
#    'record_timestamp': '2018-06-19T10:34:37+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '463ca9a4e1dce86959ef7fbe0f8262176858a5ba',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '456',
#     'dest': 'MONTREUIL JUIGNE',
#     'idparcours': 268905216,
#     'cap': 227,
#     'nomarret': 'CHU - MATERNITE',
#     'idvh': 268435912,
#     'iddesserte': 268905217,
#     'mnemoligne': '07',
#     'y': 2279680,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'HOPA8-C',
#     'idarret': 671540,
#     'harret': '2018-06-19T10:46:00+00:00',
#     'x': 382118,
#     'sv': '0723',
#     'coordonnees': [47.480655, -0.55504254],
#     'idligne': 268435463,
#     'numarret': 27358},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55504254, 47.480655]},
#    'record_timestamp': '2018-06-19T10:27:15+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '410c26a654609b0c4d49d5270b56aa4d95ce1d46',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '433',
#     'dest': 'SAINTE GEMMES',
#     'idparcours': 269198848,
#     'cap': 56,
#     'nomarret': "L'HOIRIE",
#     'idvh': 268435889,
#     'iddesserte': 269198849,
#     'mnemoligne': '11',
#     'y': 2278354,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'LHOIRI11',
#     'idarret': 671667,
#     'harret': '2018-06-19T10:39:00+00:00',
#     'x': 377296,
#     'sv': '1103',
#     'coordonnees': [47.467123, -0.61831542],
#     'idligne': 268435467,
#     'numarret': 32088},
#    'geometry': {'type': 'Point', 'coordinates': [-0.61831542, 47.467123]},
#    'record_timestamp': '2018-06-19T10:30:15+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a5f2364fa47f3c3f2feb3aad849ce7129fda01b0',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 37,
#     'novh': '435',
#     'dest': 'POLE 49 par SCHWEITZER',
#     'idparcours': 269107968,
#     'cap': 299,
#     'nomarret': 'RIOTTEAU',
#     'idvh': 268435891,
#     'iddesserte': 269107976,
#     'mnemoligne': '10',
#     'y': 2275372,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'RIOTTEAU',
#     'idarret': 671923,
#     'harret': '2018-06-19T10:36:50+00:00',
#     'x': 386327,
#     'sv': '1004',
#     'coordonnees': [47.44331, -0.49717192],
#     'idligne': 268435466,
#     'numarret': 29013},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49717192, 47.44331]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '820424ed13c77fcca5c018cd39cb0c8715893e08',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': -133,
#     'novh': '461',
#     'dest': 'AQUAVITA VERNEAU',
#     'idparcours': 268971776,
#     'cap': 9,
#     'nomarret': 'GARES BREMONT',
#     'idvh': 268435917,
#     'iddesserte': 268971809,
#     'mnemoligne': '08',
#     'y': 2278064,
#     'nomligne': 'PONTS CE <>  AQUAVITA H. RECULEE',
#     'mnemoarret': 'BREMON-E',
#     'idarret': 671225,
#     'harret': '2018-06-19T10:38:13+00:00',
#     'x': 381731,
#     'sv': '0805',
#     'coordonnees': [47.466001, -0.55938385],
#     'idligne': 268435464,
#     'numarret': 25430},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55938385, 47.466001]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'cd82d6207c107d5d4584b4a56062daefea35048d',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 102,
#     'novh': '523',
#     'dest': 'CHU - HOPITAL',
#     'idparcours': 268939776,
#     'cap': 182,
#     'nomarret': 'CROIX CADEAU',
#     'idvh': 268435979,
#     'iddesserte': 268939800,
#     'mnemoligne': '07',
#     'y': 2284349,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'CCADEA',
#     'idarret': 671258,
#     'harret': '2018-06-19T10:37:02+00:00',
#     'x': 378097,
#     'sv': '0724',
#     'coordonnees': [47.521279, -0.61067962],
#     'idligne': 268435463,
#     'numarret': 5701},
#    'geometry': {'type': 'Point', 'coordinates': [-0.61067962, 47.521279]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '5327f3cc268302a81b5dc181c51c0b928a071e0a',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': -28,
#     'novh': '526',
#     'dest': 'MONTREUIL JUIGNE FENEU',
#     'idparcours': 268904704,
#     'cap': 314,
#     'nomarret': 'AUCHAN',
#     'idvh': 268435982,
#     'iddesserte': 268904723,
#     'mnemoligne': '07',
#     'y': 2283933,
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'mnemoarret': 'INTAVR-E',
#     'idarret': 671561,
#     'harret': '2018-06-19T10:36:34+00:00',
#     'x': 378449,
#     'sv': '0721',
#     'coordonnees': [47.517659, -0.60580212],
#     'idligne': 268435463,
#     'numarret': 6846},
#    'geometry': {'type': 'Point', 'coordinates': [-0.60580212, 47.517659]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'bd67a0bd59245e77a5c03b656518702e5376bc42',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 844,
#     'novh': '533',
#     'dest': 'CIRCULAIRE SENS A',
#     'idparcours': 268774144,
#     'cap': 349,
#     'nomarret': '5A VERNEAU AQUAVITA',
#     'idvh': 268435989,
#     'iddesserte': 268774207,
#     'mnemoligne': '05',
#     'y': 2281008,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'AQUA-A5A',
#     'idarret': 672781,
#     'harret': '2018-06-19T10:36:44+00:00',
#     'x': 381416,
#     'sv': '0526',
#     'coordonnees': [47.492359, -0.56500098],
#     'idligne': 268435461,
#     'numarret': 17213},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56500098, 47.492359]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '0a12e603e02f5e994a88075550171c456e379e8b',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': -113,
#     'novh': '540',
#     'dest': 'CIRCULAIRE SENS B',
#     'idparcours': 268807680,
#     'cap': 190,
#     'nomarret': 'GARES BREMONT',
#     'idvh': 268435996,
#     'iddesserte': 268807696,
#     'mnemoligne': '05',
#     'y': 2278099,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'GBREM-E',
#     'idarret': 671489,
#     'harret': '2018-06-19T10:36:47+00:00',
#     'x': 381738,
#     'sv': '0501',
#     'coordonnees': [47.466318, -0.55930817],
#     'idligne': 268435461,
#     'numarret': 25296},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55930817, 47.466318]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '609d77ff21f896937788b45d7b65f06220ef926a',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 22,
#     'novh': '660',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611584,
#     'cap': 209,
#     'nomarret': 'FOCH MAISON BLEUE',
#     'idvh': 268436116,
#     'iddesserte': 268611597,
#     'mnemoligne': '02',
#     'y': 2278646,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'FO-LOR-R',
#     'idarret': 671447,
#     'harret': '2018-06-19T10:37:21+00:00',
#     'x': 382699,
#     'sv': '0218',
#     'coordonnees': [47.471553, -0.54683557],
#     'idligne': 268435458,
#     'numarret': 170},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54683557, 47.471553]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd3b33e48da329c0170c82621ed03538fa0d4c83d',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': -115,
#     'novh': '809',
#     'dest': 'ST AUBIN LA SALLE',
#     'idparcours': 269232896,
#     'cap': 299,
#     'nomarret': 'DAGUERRE',
#     'idvh': 268436265,
#     'iddesserte': 269232911,
#     'mnemoligne': '12',
#     'y': 2275692,
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'mnemoarret': 'DAGUERRE',
#     'idarret': 671353,
#     'harret': '2018-06-19T10:36:45+00:00',
#     'x': 385750,
#     'sv': '1203',
#     'coordonnees': [47.445999, -0.50497073],
#     'idligne': 268435468,
#     'numarret': 2483},
#    'geometry': {'type': 'Point', 'coordinates': [-0.50497073, 47.445999]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '1f2028b7e74b31c7314f4ab98fa191316dfae8d3',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 157,
#     'novh': '822',
#     'dest': 'ZI BEAUCOUZE PAR LAC DE M',
#     'idparcours': 269162752,
#     'cap': 223,
#     'nomarret': 'GRAND MAINE',
#     'idvh': 268436278,
#     'iddesserte': 269162776,
#     'mnemoligne': '11',
#     'y': 2278372,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'GDMAIN-E',
#     'idarret': 671490,
#     'harret': '2018-06-19T10:39:57+00:00',
#     'x': 381332,
#     'sv': '1104',
#     'coordonnees': [47.468637, -0.56482364],
#     'idligne': 268435467,
#     'numarret': 15461},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56482364, 47.468637]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '48bce3dfd575d9ee4003715c272c32cdccbfb365',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 28,
#     'novh': '1002',
#     'dest': 'AVRILLE ARDENNE',
#     'idparcours': 269419008,
#     'cap': 25,
#     'nomarret': 'CHU - HOPITAL',
#     'idvh': 268436458,
#     'iddesserte': 269419022,
#     'mnemoligne': 'A',
#     'y': 2279778,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2HOPA',
#     'idarret': 671076,
#     'harret': '2018-06-19T10:36:30+00:00',
#     'x': 382213,
#     'sv': 'A09',
#     'coordonnees': [47.481567, -0.55383073],
#     'idligne': 268435471,
#     'numarret': 13445},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55383073, 47.481567]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '561a880c6d029bc6de267ab847dda10902ec5bb7',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 29,
#     'novh': '1010',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 141,
#     'nomarret': 'SAINT GILLES',
#     'idvh': 268436466,
#     'iddesserte': 269451523,
#     'mnemoligne': 'A',
#     'y': 2282646,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '1STGI',
#     'idarret': 671061,
#     'harret': '2018-06-19T10:36:31+00:00',
#     'x': 379635,
#     'sv': 'A06',
#     'coordonnees': [47.506489, -0.58942981],
#     'idligne': 268435471,
#     'numarret': 23494},
#    'geometry': {'type': 'Point', 'coordinates': [-0.58942981, 47.506489]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '048c92e752ecfd8c6dd175f4dfd31b93abc2c311',
#    'fields': {'etat': 'LIGN',
#     'type': 'ARWAY',
#     'ecart': 359,
#     'novh': '7592',
#     'dest': 'PLESSIS MACE',
#     'idparcours': 270664960,
#     'cap': 309,
#     'nomarret': 'POMONE',
#     'idvh': 268443048,
#     'iddesserte': 270664965,
#     'mnemoligne': '34',
#     'y': 2279670,
#     'nomligne': 'PLESSIS MACE MEIGNANNE <> GARE',
#     'mnemoarret': 'POMONE-E',
#     'idarret': 671867,
#     'harret': '2018-06-19T10:36:58+00:00',
#     'x': 380856,
#     'sv': '3405',
#     'coordonnees': [47.480146, -0.5717707],
#     'idligne': 268435490,
#     'numarret': 15036},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5717707, 47.480146]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'dfab9c212ceb15b8309a46eb3a65bb5153576201',
#    'fields': {'etat': 'LIGN',
#     'type': 'CROSSWAY',
#     'ecart': -36,
#     'novh': '9134',
#     'dest': 'SOUCELLES',
#     'idparcours': 270535936,
#     'cap': 10,
#     'nomarret': 'TOURAINE',
#     'idvh': 268444590,
#     'iddesserte': 270535952,
#     'mnemoligne': '32',
#     'y': 2284673,
#     'nomligne': 'SOUCELLES PELLOUAILLES <> GARE',
#     'mnemoarret': 'TOURAI-E',
#     'idarret': 672386,
#     'harret': '2018-06-19T10:37:11+00:00',
#     'x': 391424,
#     'sv': '3205',
#     'coordonnees': [47.528552, -0.43398014],
#     'idligne': 268435488,
#     'numarret': 25515},
#    'geometry': {'type': 'Point', 'coordinates': [-0.43398014, 47.528552]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd5b4b40f7c787ec86cd8f76e52d0a706e159b4bc',
#    'fields': {'etat': 'TARR',
#     'type': 'CITADIS',
#     'ecart': 0,
#     'novh': '1004',
#     'dest': 'ANGERS ROSERAIE',
#     'idparcours': 269451520,
#     'cap': 84,
#     'nomarret': 'ANGERS - ROSERAIE',
#     'idvh': 268436460,
#     'iddesserte': 269451546,
#     'mnemoligne': 'A',
#     'y': 2275600,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2ANRO',
#     'idarret': 671066,
#     'harret': '2018-06-19T10:35:54+00:00',
#     'x': 382048,
#     'sv': 'A02',
#     'coordonnees': [47.443958, -0.55397982],
#     'idligne': 268435471,
#     'numarret': 32091},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55397982, 47.443958]},
#    'record_timestamp': '2018-06-19T10:36:16+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a1247a963a151e63fd05ad19fde1c5fcd369fd98',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNICITY',
#     'ecart': 0,
#     'novh': '441',
#     'dest': 'EVENTARD par MONPLAISIR',
#     'idparcours': 269029376,
#     'cap': 5,
#     'nomarret': 'ESPACE ANJOU',
#     'idvh': 268435897,
#     'iddesserte': 269029377,
#     'mnemoligne': '09',
#     'y': 2278212,
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'mnemoarret': 'ESPACEAN',
#     'idarret': 671423,
#     'harret': '2018-06-19T10:40:00+00:00',
#     'x': 384248,
#     'sv': '0905',
#     'coordonnees': [47.468161, -0.52609049],
#     'idligne': 268435465,
#     'numarret': 18251},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52609049, 47.468161]},
#    'record_timestamp': '2018-06-19T10:31:13+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '2fce171a2943ed93bdc50cb037542940828810f5',
#    'fields': {'etat': 'TDEP',
#     'type': 'MAN City',
#     'ecart': 0,
#     'novh': '610',
#     'dest': 'PAS EN SERVICE',
#     'idparcours': 268742912,
#     'cap': 264,
#     'nomarret': 'RELEVE DEPOT',
#     'idvh': 268436066,
#     'iddesserte': 268742913,
#     'mnemoligne': '04',
#     'y': 2278880,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'REL-DEPO',
#     'idarret': 672512,
#     'harret': '2018-06-19T10:45:00+00:00',
#     'x': 386698,
#     'sv': '0422',
#     'coordonnees': [47.474964, -0.49393108],
#     'idligne': 268435460,
#     'numarret': 16504},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49393108, 47.474964]},
#    'record_timestamp': '2018-06-19T10:29:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '1620d79e322a0e1e7267de6a3246c6d2e8d0a531',
#    'fields': {'etat': 'TDEP',
#     'type': 'MAN City',
#     'ecart': 0,
#     'novh': '619',
#     'dest': 'BELLE BEILLE',
#     'idparcours': 268545536,
#     'cap': 287,
#     'nomarret': 'MONPLAISIR',
#     'idvh': 268436075,
#     'iddesserte': 268545537,
#     'mnemoligne': '01',
#     'y': 2280767,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'MONPLAIS',
#     'idarret': 671754,
#     'harret': '2018-06-19T10:40:00+00:00',
#     'x': 384174,
#     'sv': '0106',
#     'coordonnees': [47.491103, -0.52830684],
#     'idligne': 268435457,
#     'numarret': 4795},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52830684, 47.491103]},
#    'record_timestamp': '2018-06-19T10:33:56+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '36b62334a7ff50c31051c6a0597240632d0ea15e',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNIART',
#     'ecart': 0,
#     'novh': '665',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611072,
#     'cap': 61,
#     'nomarret': 'ST SYLVAIN',
#     'idvh': 268436121,
#     'iddesserte': 268611073,
#     'mnemoligne': '02',
#     'y': 2283022,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'STSYLVAI',
#     'idarret': 672010,
#     'harret': '2018-06-19T10:45:00+00:00',
#     'x': 388599,
#     'sv': '0214',
#     'coordonnees': [47.512809, -0.47068963],
#     'idligne': 268435458,
#     'numarret': 32055},
#    'geometry': {'type': 'Point', 'coordinates': [-0.47068963, 47.512809]},
#    'record_timestamp': '2018-06-19T10:35:35+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'f5a196e2c8dcbffe36742d6840765f591ee91e68',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 205,
#     'novh': '439',
#     'dest': 'SORGES',
#     'idparcours': 269139456,
#     'cap': 270,
#     'nomarret': 'GARES PAPIN',
#     'idvh': 268435895,
#     'iddesserte': 269139478,
#     'mnemoligne': '10',
#     'y': 2277978,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'GAREPA-E',
#     'idarret': 671475,
#     'harret': '2018-06-19T10:37:05+00:00',
#     'x': 381940,
#     'sv': '1010',
#     'coordonnees': [47.465297, -0.55657144],
#     'idligne': 268435466,
#     'numarret': 715},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55657144, 47.465297]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '22e54152c416fda5b3de7baf13381b018d92a6c0',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 234,
#     'novh': '532',
#     'dest': 'CIRCULAIRE SENS A',
#     'idparcours': 268774144,
#     'cap': 182,
#     'nomarret': 'MORELLERIE',
#     'idvh': 268435988,
#     'iddesserte': 268774172,
#     'mnemoligne': '05',
#     'y': 2276415,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'MORELLER',
#     'idarret': 671780,
#     'harret': '2018-06-19T10:36:31+00:00',
#     'x': 382765,
#     'sv': '0524',
#     'coordonnees': [47.45152, -0.54487558],
#     'idligne': 268435461,
#     'numarret': 495},
#    'geometry': {'type': 'Point', 'coordinates': [-0.54487558, 47.45152]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '183566835d3ff296e8ae815ad799eed75504ecbc',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 342,
#     'novh': '543',
#     'dest': 'CIRCULAIRE SENS B',
#     'idparcours': 268807680,
#     'cap': 87,
#     'nomarret': 'ANGERS ROSERAIE',
#     'idvh': 268435999,
#     'iddesserte': 268807711,
#     'mnemoligne': '05',
#     'y': 2275597,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'ANRO-5B',
#     'idarret': 671113,
#     'harret': '2018-06-19T10:36:41+00:00',
#     'x': 382063,
#     'sv': '0523',
#     'coordonnees': [47.443936, -0.5537796],
#     'idligne': 268435461,
#     'numarret': 12151},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5537796, 47.443936]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '25d7cc7cf7b2468813876206d33006beb4ecefa5',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 115,
#     'novh': '602',
#     'dest': 'MONPLAISIR',
#     'idparcours': 268513024,
#     'cap': 25,
#     'nomarret': 'NOZAY',
#     'idvh': 268436058,
#     'iddesserte': 268513062,
#     'mnemoligne': '01',
#     'y': 2280388,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'NOZAY -E',
#     'idarret': 671795,
#     'harret': '2018-06-19T10:36:35+00:00',
#     'x': 383876,
#     'sv': '0123',
#     'coordonnees': [47.487599, -0.53207535],
#     'idligne': 268435457,
#     'numarret': 837},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53207535, 47.487599]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '30a353abe809221867cccbb106a130f8d25528ed',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 103,
#     'novh': '605',
#     'dest': 'MURS ERIGNE',
#     'idparcours': 268674560,
#     'cap': 195,
#     'nomarret': 'CHATEAU ERIGNE',
#     'idvh': 268436061,
#     'iddesserte': 268674609,
#     'mnemoligne': '03',
#     'y': 2271348,
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'mnemoarret': 'CHAERI-E',
#     'idarret': 671277,
#     'harret': '2018-06-19T10:37:28+00:00',
#     'x': 384011,
#     'sv': '0322',
#     'coordonnees': [47.406383, -0.52591617],
#     'idligne': 268435459,
#     'numarret': 8276},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52591617, 47.406383]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'ef9ed2ba47ef35f349a711625a77488a3c741382',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 44,
#     'novh': '609',
#     'dest': 'BANCHAIS',
#     'idparcours': 268579072,
#     'cap': 199,
#     'nomarret': 'HALTE FERROVIAIRE',
#     'idvh': 268436065,
#     'iddesserte': 268579077,
#     'mnemoligne': '02',
#     'y': 2276369,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'PEPINIER',
#     'idarret': 672664,
#     'harret': '2018-06-19T10:36:46+00:00',
#     'x': 388430,
#     'sv': '0211',
#     'coordonnees': [47.452951, -0.4697781],
#     'idligne': 268435458,
#     'numarret': 10185},
#    'geometry': {'type': 'Point', 'coordinates': [-0.4697781, 47.452951]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '894cde35a5be2a3613d9cbfdd813c7f2ecba2a69',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 22,
#     'novh': '656',
#     'dest': 'ST SYLVAIN',
#     'idparcours': 268578560,
#     'cap': 55,
#     'nomarret': 'LES CARREAUX',
#     'idvh': 268436112,
#     'iddesserte': 268578611,
#     'mnemoligne': '02',
#     'y': 2282253,
# ...
#     'numarret': 11114},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55270094, 47.484971]},
#    'record_timestamp': '2018-06-19T10:35:53+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '056dfb2f15e4ef1d3945b94183f2519279d3b11d',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': 17,
#     'novh': '436',
#     'dest': 'SCHWEITZER',
#     'idparcours': 269096704,
#     'cap': 301,
#     'nomarret': 'FREMUR',
#     'idvh': 268435892,
#     'iddesserte': 269096734,
#     'mnemoligne': '10',
#     'y': 2277213,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'FREMUR',
#     'idarret': 671458,
#     'harret': '2018-06-19T10:36:37+00:00',
#     'x': 381840,
#     'sv': '1008',
#     'coordonnees': [47.458388, -0.55752335],
#     'idligne': 268435466,
#     'numarret': 18974},
#    'geometry': {'type': 'Point', 'coordinates': [-0.55752335, 47.458388]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '2c7d2ad67790f429eaf5ad4ca04ddd350f0335bb',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNICITY',
#     'ecart': -17,
#     'novh': '452',
#     'dest': 'HAUTE DE RECULEE',
#     'idparcours': 268972288,
#     'cap': 71,
#     'nomarret': 'MARIE CURIE',
#     'idvh': 268435908,
#     'iddesserte': 268972297,
#     'mnemoligne': '08',
#     'y': 2274252,
#     'nomligne': 'PONTS CE <>  AQUAVITA H. RECULEE',
#     'mnemoarret': 'MACURIE',
#     'idarret': 671695,
#     'harret': '2018-06-19T10:36:53+00:00',
#     'x': 384672,
#     'sv': '0821',
#     'coordonnees': [47.432703, -0.51856157],
#     'idligne': 268435464,
#     'numarret': 12294},
#    'geometry': {'type': 'Point', 'coordinates': [-0.51856157, 47.432703]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'd110e1c9e41eb28cc65d5fb9906627c0ca61e895',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': -37,
#     'novh': '530',
#     'dest': 'CIRCULAIRE SENS A',
#     'idparcours': 268774144,
#     'cap': 178,
#     'nomarret': 'CAMELIA',
#     'idvh': 268435986,
#     'iddesserte': 268774161,
#     'mnemoligne': '05',
#     'y': 2278593,
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'mnemoarret': 'CAMELI-E',
#     'idarret': 671234,
#     'harret': '2018-06-19T10:37:36+00:00',
#     'x': 384785,
#     'sv': '0502',
#     'coordonnees': [47.471761, -0.51915544],
#     'idligne': 268435461,
#     'numarret': 10436},
#    'geometry': {'type': 'Point', 'coordinates': [-0.51915544, 47.471761]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'abb9c3fdc7e92b38615dfa2359b4ff247c92c750',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': -126,
#     'novh': '536',
#     'dest': 'ZI TRELAZE PAR ST LEZIN',
#     'idparcours': 269140992,
#     'cap': 251,
#     'nomarret': 'PLACE NEY',
#     'idvh': 268435992,
#     'iddesserte': 269140999,
#     'mnemoligne': '10',
#     'y': 2279589,
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'mnemoarret': 'PLACENEY',
#     'idarret': 671851,
#     'harret': '2018-06-19T10:37:34+00:00',
#     'x': 383282,
#     'sv': '1006',
#     'coordonnees': [47.480221, -0.53956445],
#     'idligne': 268435466,
#     'numarret': 18833},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53956445, 47.480221]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'e5812a9ccb0bd902d9a22e36d4fe05cd190e17cd',
#    'fields': {'etat': 'LIGN',
#     'type': 'GX 327',
#     'ecart': 11,
#     'novh': '541',
#     'dest': "CLINIQUE DE L'ANJOU",
#     'idparcours': 269198336,
#     'cap': 103,
#     'nomarret': 'POISSONNERIE',
#     'idvh': 268435997,
#     'iddesserte': 269198351,
#     'mnemoligne': '11',
#     'y': 2277978,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'POISSONN',
#     'idarret': 671863,
#     'harret': '2018-06-19T10:39:13+00:00',
#     'x': 380528,
#     'sv': '1122',
#     'coordonnees': [47.464828, -0.57528796],
#     'idligne': 268435467,
#     'numarret': 29689},
#    'geometry': {'type': 'Point', 'coordinates': [-0.57528796, 47.464828]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '970584f6ee3dc808db238005d8da0cac59de5961',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': -42,
#     'novh': '611',
#     'dest': 'MONPLAISIR',
#     'idparcours': 268513024,
#     'cap': 82,
#     'nomarret': 'SAINT JACQUES',
#     'idvh': 268436067,
#     'iddesserte': 268513035,
#     'mnemoligne': '01',
#     'y': 2278942,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'SAJACQUE',
#     'idarret': 671959,
#     'harret': '2018-06-19T10:36:23+00:00',
#     'x': 380870,
#     'sv': '0126',
#     'coordonnees': [47.473607, -0.57122773],
#     'idligne': 268435457,
#     'numarret': 17939},
#    'geometry': {'type': 'Point', 'coordinates': [-0.57122773, 47.473607]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'c19095510a59102cdeb093f2b3798b1ca4c5e4a0',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': -21,
#     'novh': '653',
#     'dest': 'MURS ERIGNE',
#     'idparcours': 268674048,
#     'cap': 134,
#     'nomarret': 'DESCAZEAUX',
#     'idvh': 268436109,
#     'iddesserte': 268674068,
#     'mnemoligne': '03',
#     'y': 2279288,
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'mnemoarret': 'DSCAZEAU',
#     'idarret': 671393,
#     'harret': '2018-06-19T10:36:38+00:00',
#     'x': 381170,
#     'sv': '0328',
#     'coordonnees': [47.476817, -0.56742009],
#     'idligne': 268435459,
#     'numarret': 24278},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56742009, 47.476817]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '3dcde40073a7428c513a255b9f510d94917b4c08',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 437,
#     'novh': '669',
#     'dest': 'BANCHAIS',
#     'idparcours': 268579072,
#     'cap': 303,
#     'nomarret': 'BOURGONNIER',
#     'idvh': 268436125,
#     'iddesserte': 268579101,
#     'mnemoligne': '02',
#     'y': 2277593,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'BOUGONNI',
#     'idarret': 671216,
#     'harret': '2018-06-19T10:36:29+00:00',
#     'x': 382995,
#     'sv': '0201',
#     'coordonnees': [47.462185, -0.5423998],
#     'idligne': 268435458,
#     'numarret': 27073},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5423998, 47.462185]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'bdf823031297320af34641d34d5b600511bb478e',
#    'fields': {'etat': 'LIGN',
#     'type': 'OMNIART',
#     'ecart': 52,
#     'novh': '673',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268611072,
#     'cap': 234,
#     'nomarret': 'SEPT SONNETTES',
#     'idvh': 268436129,
#     'iddesserte': 268611088,
#     'mnemoligne': '02',
#     'y': 2280206,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'SEPSONET',
#     'idarret': 671979,
#     'harret': '2018-06-19T10:36:51+00:00',
#     'x': 385238,
#     'sv': '0208',
#     'coordonnees': [47.486408, -0.51392593],
#     'idligne': 268435458,
#     'numarret': 12415},
#    'geometry': {'type': 'Point', 'coordinates': [-0.51392593, 47.486408]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '5927b0379c66aab1b64ccc75e4dcb8e69a9fe431',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniArtE6',
#     'ecart': 42,
#     'novh': '678',
#     'dest': "BEAUCOUZE L'ATOLL",
#     'idparcours': 268739072,
#     'cap': 15,
#     'nomarret': 'CROIX DE CHEMINEE',
#     'idvh': 268436134,
#     'iddesserte': 268739087,
#     'mnemoligne': '04',
#     'y': 2277979,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'CCHEMINE',
#     'idarret': 671261,
#     'harret': '2018-06-19T10:37:24+00:00',
#     'x': 386312,
#     'sv': '0408',
#     'coordonnees': [47.466739, -0.49861756],
#     'idligne': 268435460,
#     'numarret': 30005},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49861756, 47.466739]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '3ad238cd9a5428b65f240fab9f26c0ecd34e4c3b',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniArtE6',
#     'ecart': -29,
#     'novh': '686',
#     'dest': 'BELLE BEILLE',
#     'idparcours': 268545536,
#     'cap': 284,
#     'nomarret': 'TRINITE',
#     'idvh': 268436142,
#     'iddesserte': 268545562,
#     'mnemoligne': '01',
#     'y': 2279081,
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'mnemoarret': 'TRINIT-E',
#     'idarret': 672021,
#     'harret': '2018-06-19T10:38:15+00:00',
#     'x': 381588,
#     'sv': '0128',
#     'coordonnees': [47.475095, -0.56177686],
#     'idligne': 268435457,
#     'numarret': 29503},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56177686, 47.475095]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6898f9644086f005a620ca7f8541875967116336',
#    'fields': {'etat': 'LIGN',
#     'type': 'OmniSTDE6',
#     'ecart': 220,
#     'novh': '816',
#     'dest': 'ESPACE ANJOU',
#     'idparcours': 269062656,
#     'cap': 207,
#     'nomarret': 'MENDES FRANCE',
#     'idvh': 268436272,
#     'iddesserte': 269062673,
#     'mnemoligne': '09',
#     'y': 2278725,
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'mnemoarret': 'MENDESFR',
#     'idarret': 671733,
#     'harret': '2018-06-19T10:36:28+00:00',
#     'x': 382743,
#     'sv': '0904',
#     'coordonnees': [47.472277, -0.5462907],
#     'idligne': 268435465,
#     'numarret': 10353},
#    'geometry': {'type': 'Point', 'coordinates': [-0.5462907, 47.472277]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '480c257c4a57c1a8d6db8aec5735b24d657699a8',
#    'fields': {'etat': 'LIGN',
#     'type': 'CITADIS',
#     'ecart': 30,
#     'novh': '1009',
#     'dest': 'AVRILLE ARDENNE',
#     'idparcours': 269419008,
#     'cap': 39,
#     'nomarret': 'BAMAKO',
#     'idvh': 268436465,
#     'iddesserte': 269419012,
#     'mnemoligne': 'A',
#     'y': 2276244,
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'mnemoarret': '2BAMA',
#     'idarret': 671067,
#     'harret': '2018-06-19T10:38:00+00:00',
#     'x': 381484,
#     'sv': 'A03',
#     'coordonnees': [47.44956, -0.56176775],
#     'idligne': 268435471,
#     'numarret': 30251},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56176775, 47.44956]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'b21d7ab4944f91aede2829c758e9c5792c4696a7',
#    'fields': {'etat': 'LIGN',
#     'type': 'CROSSWAY',
#     'ecart': -105,
#     'novh': '3310',
#     'dest': 'ST MARTIN FOUILLOUX',
#     'idparcours': 270801408,
#     'cap': 236,
#     'nomarret': 'ELYSEE',
#     'idvh': 268438766,
#     'iddesserte': 270801412,
#     'mnemoligne': '36',
#     'y': 2278985,
#     'nomligne': 'St MARTIN St JEAN <> GARE',
#     'mnemoarret': 'P-ELYS-E',
#     'idarret': 672787,
#     'harret': '2018-06-19T10:39:55+00:00',
#     'x': 381127,
#     'sv': '3603',
#     'coordonnees': [47.474079, -0.56784164],
#     'idligne': 268435492,
#     'numarret': 189856},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56784164, 47.474079]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '2ae12eea9dc4e9a499e9b8ec2fe7c3b976a250d4',
#    'fields': {'etat': 'LIGN',
#     'type': 'VOLVO',
#     'ecart': -22,
#     'novh': '7640',
#     'dest': 'PLESSIS MACE',
#     'idparcours': 270931712,
#     'cap': 253,
#     'nomarret': 'LA BARRE',
#     'idvh': 268443096,
#     'iddesserte': 270931718,
#     'mnemoligne': '38',
#     'y': 2278852,
#     'nomligne': 'St CLEMENT St LAMBERT <> GARE',
#     'mnemoarret': 'P-LBAR-E',
#     'idarret': 672784,
#     'harret': '2018-06-19T10:36:37+00:00',
#     'x': 378738,
#     'sv': '3801',
#     'coordonnees': [47.472085, -0.59944757],
#     'idligne': 268435494,
#     'numarret': 475176},
#    'geometry': {'type': 'Point', 'coordinates': [-0.59944757, 47.472085]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6cf93ba3e794564ba943fac28ce978fb094d0f52',
#    'fields': {'etat': 'HL',
#     'type': 'INTOURO',
#     'ecart': 338,
#     'novh': '8113',
#     'dest': 'CROIX DE BEAUVAIS',
#     'idparcours': 270602240,
#     'cap': 320,
#     'nomarret': 'CANTENAY LEGRAS',
#     'idvh': 268443569,
#     'iddesserte': 270602247,
#     'mnemoligne': '33',
#     'y': 2282438,
#     'nomligne': 'FENEU CANTENAY <> GARE',
#     'mnemoarret': 'LEGRAS-E',
#     'idarret': 672237,
#     'harret': '2018-06-19T10:40:50+00:00',
#     'x': 381146,
#     'sv': '3309',
#     'coordonnees': [47.505123, -0.56928338],
#     'idligne': 268435489,
#     'numarret': 11618},
#    'geometry': {'type': 'Point', 'coordinates': [-0.56928338, 47.505123]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '7d7827dcf26958219f92aa1861b3822210a53006',
#    'fields': {'etat': 'LIGN',
#     'type': 'CROSSWAY',
#     'ecart': 220,
#     'novh': '8849',
#     'dest': 'PLESSIS  SARRIGNE',
#     'idparcours': 270402048,
#     'cap': 56,
#     'nomarret': 'CHATENAY',
#     'idvh': 268444305,
#     'iddesserte': 270402055,
#     'mnemoligne': '30',
#     'y': 2279726,
#     'nomligne': 'SARRIGNE PLESSIS <> GARE',
#     'mnemoarret': 'CHATEN-E',
#     'idarret': 671290,
#     'harret': '2018-06-19T10:36:55+00:00',
#     'x': 384566,
#     'sv': '3001',
#     'coordonnees': [47.481874, -0.52260555],
#     'idligne': 268435486,
#     'numarret': 2767},
#    'geometry': {'type': 'Point', 'coordinates': [-0.52260555, 47.481874]},
#    'record_timestamp': '2018-06-19T10:36:33+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': 'a777f1ace4019b5f775a24a70db74c8a946649ce',
#    'fields': {'etat': 'LIGN',
#     'type': 'MAN City',
#     'ecart': 323,
#     'novh': '618',
#     'dest': 'ST BARTHELEMY',
#     'idparcours': 268707072,
#     'cap': 91,
#     'nomarret': 'STADE ST BARTHELEMY',
#     'idvh': 268436074,
#     'iddesserte': 268707123,
#     'mnemoligne': '04',
#     'y': 2277354,
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'mnemoarret': 'STADE-E',
#     'idarret': 671990,
#     'harret': '2018-06-19T10:36:22+00:00',
#     'x': 386745,
#     'sv': '0410',
#     'coordonnees': [47.461262, -0.4925792],
#     'idligne': 268435460,
#     'numarret': 12422},
#    'geometry': {'type': 'Point', 'coordinates': [-0.4925792, 47.461262]},
#    'record_timestamp': '2018-06-19T10:36:16+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '37ba40bfbe41e79b0b5dd11a93bc0df89426ed0e',
#    'fields': {'etat': 'TDEP',
#     'type': 'OMNIART',
#     'ecart': 0,
#     'novh': '663',
#     'dest': 'TRELAZE QUANTINIERE',
#     'idparcours': 268612096,
#     'cap': 230,
#     'nomarret': 'PARC DES EXPOSITIONS',
#     'idvh': 268436119,
#     'iddesserte': 268612097,
#     'mnemoligne': '02',
#     'y': 2281370,
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'mnemoarret': 'PARCEXPO',
#     'idarret': 671809,
#     'harret': '2018-06-19T10:45:01+00:00',
#     'x': 386758,
#     'sv': '0202',
#     'coordonnees': [47.497366, -0.49432542],
#     'idligne': 268435458,
#     'numarret': 12773},
#    'geometry': {'type': 'Point', 'coordinates': [-0.49432542, 47.497366]},
#    'record_timestamp': '2018-06-19T10:36:16+00:00'},
#   {'datasetid': 'bus-tram-position-tr',
#    'recordid': '6bc00b133c0eed3ca8506f4da939cd3aa85f0040',
#    'fields': {'etat': 'TDEP',
#     'type': 'OmniSTDE6',
#     'ecart': 0,
#     'novh': '820',
#     'dest': "LAC DE MAINE - L'HOIRIE",
#     'idparcours': 269166848,
#     'cap': 247,
#     'nomarret': "CLINIQUE DE L'ANJOU",
#     'idvh': 268436276,
#     'iddesserte': 269166849,
#     'mnemoligne': '11',
#     'y': 2275595,
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'mnemoarret': 'CLINANJO',
#     'idarret': 671327,
#     'harret': '2018-06-19T10:47:00+00:00',
#     'x': 383163,
#     'sv': '1102',
#     'coordonnees': [47.444281, -0.53920337],
#     'idligne': 268435467,
#     'numarret': 21645},
#    'geometry': {'type': 'Point', 'coordinates': [-0.53920337, 47.444281]},
#    'record_timestamp': '2018-06-19T10:27:15+00:00'}]}

# %% [markdown]
# # Remplissage de DataFrame

# %% [markdown]
# On peut construire une `DataFrame` directement à partir d'un "dictionnaires de colonnes".

# %%
dd = g.json()['records']

# %%
dd[0]
# Out:
# {'datasetid': 'bus-tram-position-tr',
#  'recordid': 'd2707eca39de09f79bcef7be9101e0af08c1a754',
#  'fields': {'etat': 'HLPS',
#   'type': 'OmniSTDE6',
#   'ecart': 0,
#   'novh': '803',
#   'dest': 'PAS EN SERVICE',
#   'idparcours': 268720384,
#   'cap': 185,
#   'nomarret': 'SORTIE DEPOT ST BART',
#   'idvh': 268436259,
#   'iddesserte': 268720385,
#   'mnemoligne': '04',
#   'y': 2279028,
#   'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#   'mnemoarret': 'DEPOT SD',
#   'idarret': 671375,
#   'harret': '2018-06-19T07:09:46+00:00',
#   'x': 386788,
#   'sv': '0412',
#   'coordonnees': [47.476323, -0.49280852],
#   'idligne': 268435460,
#   'numarret': 6562},
#  'geometry': {'type': 'Point', 'coordinates': [-0.49280852, 47.476323]},
#  'record_timestamp': '2018-06-19T07:16:13+00:00'}

# %%
#Arret
id_arret = [elem['fields']['idarret'] for elem in dd]
nom_arret = [elem['fields']['nomarret'] for elem in dd]
mne_arret = [elem['fields']['mnemoarret'] for elem in dd]

arret = pd.DataFrame({
    'id_arret': id_arret,
    'nom_arret': nom_arret,
    'mne_arret': mne_arret
})

#arret.info()

arret
# Out:
#      id_arret             nom_arret mne_arret
# 0      671375  SORTIE DEPOT ST BART  DEPOT SD
# 1      671973        SORTIE BUS CTB     SDCTB
# 2      671375  SORTIE DEPOT ST BART  DEPOT SD
# 3      671963      ST BARTH COLLEGE  SBARTHEL
# 4      672636    PISCINE MONPLAISIR   P-MONPL
# 5      671973        SORTIE BUS CTB     SDCTB
# 6      672520   L'ATOLL - BEAUCOUZE  ATOLLBEA
# 7      671157     ST AUBIN LA SALLE  BARONNER
# 8      672083               ZI. EST     ZIEST
# 9      671677        PLACE LORRAINE    LOHUIT
# 10     671927                 RIVET   RIVET-E
# 11     672581             AQUA VITA  AQVI-D5B
# 12     671279             CHALOUERE  CHALOU-E
# 13     671475           GARES PAPIN  GAREPA-E
# 14     671792     NOTRE DAME DU LAC  NDAMELAC
# 15     671528            FOCH HARAS     HARAS
# 16     671722  MAISON DE TECHNOPOLE    MATEC.
# 17     671308            FRATELLINI  CIEST.-E
# 18     671785           MURS ERIGNE  MURSERIG
# 19     671447     FOCH MAISON BLEUE  FO-LOR-R
# 20     672665           QUANTINIERE  QUANTI-E
# 21     671437                BALZAC  BALZAC-E
# 22     671302              CHOUTEAU  CHOUTE-E
# 23     671700                  MAIL  MAIL-HDV
# 24     671055      PLACE LA FAYETTE     1LAFA
# 25     671057         PLACE MOLIERE     1MOLI
# 26     671070        TERRA BOTANICA     2BOTA
# 27     671528            FOCH HARAS     HARAS
# 28     671295      CHATEAU D'ANGERS  CHDARR-E
# 29     671755       PLACE MONPROFIT  MONPR -E
# ..        ...                   ...       ...
# 95     671465        FRONT DE MAINE  FRONDM-E
# 96     671447     FOCH MAISON BLEUE  FO-LOR-R
# 97     671074     FOCHMAISONBLEUEv2     2FMBL
# 98     671039     AVRILLE - ARDENNE     1AARD
# 99     671051  HAUTS DE SAINT AUBIN     1HSAU
# 100    671627             LA POINTE  LAPOIN-E
# 101    672193            GRIMORELLE  GRIMOR-E
# 102    672127           BEAU SOLEIL  BSOLEI-E
# 103    672346         LA RENARDIERE   RENAR-E
# 104    671548      HAUTE DE RECULEE  HRECULEE
# 105    671458                FREMUR    FREMUR
# 106    671695           MARIE CURIE   MACURIE
# 107    671234               CAMELIA  CAMELI-E
# 108    671851             PLACE NEY  PLACENEY
# 109    671863          POISSONNERIE  POISSONN
# 110    671959         SAINT JACQUES  SAJACQUE
# 111    671393            DESCAZEAUX  DSCAZEAU
# 112    671216           BOURGONNIER  BOUGONNI
# 113    671979        SEPT SONNETTES  SEPSONET
# 114    671261     CROIX DE CHEMINEE  CCHEMINE
# 115    672021               TRINITE  TRINIT-E
# 116    671733         MENDES FRANCE  MENDESFR
# 117    671067                BAMAKO     2BAMA
# 118    672787                ELYSEE  P-ELYS-E
# 119    672784              LA BARRE  P-LBAR-E
# 120    672237       CANTENAY LEGRAS  LEGRAS-E
# 121    671290              CHATENAY  CHATEN-E
# 122    671990   STADE ST BARTHELEMY   STADE-E
# 123    671809  PARC DES EXPOSITIONS  PARCEXPO
# 124    671327   CLINIQUE DE L'ANJOU  CLINANJO
#
# [125 rows x 3 columns]

# %%
#Bus
id_vh = [elem['fields']['idvh'] for elem in dd]
type_vh = [elem['fields']['type'] for elem in dd]
etat_vh = [elem['fields']['etat'] for elem in dd]

bus = pd.DataFrame({
    'id_vh': id_vh,
    'type_vh': type_vh,
    'etat_vh': etat_vh
})

#bus.info()

bus
# Out:
#          id_vh                  type_vh etat_vh
# 0    268436259                OmniSTDE6    HLPS
# 1    268436120                  OMNIART    HLPS
# 2    268435899                 OMNICITY    HLPS
# 3    268436158  AGORA123456789ABCDEFART    TDEP
# 4    268435879                 OMNICITY      HL
# 5    268436137                OmniArtE6    HLPS
# 6    268436145                OmniArtE6    TDEP
# 7    268435905                 OMNICITY    TDEP
# 8    268436270                OmniSTDE6    TDEP
# 9    268435909                 OMNICITY    LIGN
# 10   268435910                 OMNICITY    LIGN
# 11   268435913                 OMNICITY    LIGN
# 12   268435994                   GX 327    LIGN
# 13   268436057                 MAN City    LIGN
# 14   268436059                 MAN City    LIGN
# 15   268436070                 MAN City    LIGN
# 16   268436072                 MAN City    LIGN
# 17   268436078                 MAN City    LIGN
# 18   268436079                 MAN City    TDEP
# 19   268436107                  OMNIART    LIGN
# 20   268436110                  OMNIART    LIGN
# 21   268436126                  OMNIART    LIGN
# 22   268436139                OmniArtE6    LIGN
# 23   268436273                OmniSTDE6      HL
# 24   268436461                  CITADIS    LIGN
# 25   268436470                  CITADIS    LIGN
# 26   268436472                  CITADIS    LIGN
# 27   268442638                     AXER    LIGN
# 28   268443547                     ARES    LIGN
# 29   268443565                   RECREO      HL
# ..         ...                      ...     ...
# 95   268436275                OmniSTDE6    LIGN
# 96   268436277                OmniSDTE6    LIGN
# 97   268436457                  CITADIS    LIGN
# 98   268436459                  CITADIS    LIGN
# 99   268436468                  CITADIS    LIGN
# 100  268438708                   OTOKAR    LIGN
# 101  268438716                    ARWAY    TARR
# 102  268438755                 CROSSWAY    HLPR
# 103  268443784                 CROSSWAY      HL
# 104  268435911                 OMNICITY    TDEP
# 105  268435892                 OMNICITY    LIGN
# 106  268435908                 OMNICITY    LIGN
# 107  268435986                   GX 327    LIGN
# 108  268435992                   GX 327    LIGN
# 109  268435997                   GX 327    LIGN
# 110  268436067                 MAN City    LIGN
# 111  268436109                  OMNIART    LIGN
# 112  268436125                  OMNIART    LIGN
# 113  268436129                  OMNIART    LIGN
# 114  268436134                OmniArtE6    LIGN
# 115  268436142                OmniArtE6    LIGN
# 116  268436272                OmniSTDE6    LIGN
# 117  268436465                  CITADIS    LIGN
# 118  268438766                 CROSSWAY    LIGN
# 119  268443096                    VOLVO    LIGN
# 120  268443569                  INTOURO      HL
# 121  268444305                 CROSSWAY    LIGN
# 122  268436074                 MAN City    LIGN
# 123  268436119                  OMNIART    TDEP
# 124  268436276                OmniSTDE6    TDEP
#
# [125 rows x 3 columns]

# %%
#Ligne
id_ligne = [elem['fields']['idligne'] for elem in dd]
nom_ligne = [elem['fields']['nomligne'] for elem in dd]
mne_ligne = [elem['fields']['mnemoligne'] for elem in dd]

ligne = pd.DataFrame({
    'id_ligne': id_arret,
    'nom_ligne': nom_ligne,
    'mne_ligne': mne_ligne
})

#ligne.info()

ligne
# Out:
#      id_ligne                         nom_ligne mne_ligne
# 0      671375        BEAUCOUZE <> ST BARTHELEMY        04
# 1      671973        BELLE BEILLE <> MONPLAISIR        01
# 2      671375           BOUCHEMAINE <> Z I  EST        06
# 3      671963        BEAUCOUZE <> ST BARTHELEMY        04
# 4      672636                Piscine MONPLAISIR       535
# 5      671973        BEAUCOUZE <> ST BARTHELEMY        04
# 6      672520        BEAUCOUZE <> ST BARTHELEMY        04
# 7      671157   M-MARCILLE <> ST AUBIN LA SALLE        12
# 8      672083           BOUCHEMAINE <> Z I  EST        06
# 9      671677   M-MARCILLE <> ST AUBIN LA SALLE        12
# 10     671927  PONTS CE <>  AQUAVITA H. RECULEE        08
# 11     672581    CIRCULAIRE VERNEAU GARE EUROPE        05
# 12     671279     ST LEZIN SORGES <> SCHWEITZER        10
# 13     671475        BELLE BEILLE <> MONPLAISIR        01
# 14     671792        BELLE BEILLE <> MONPLAISIR        01
# 15     671528        BELLE BEILLE <> MONPLAISIR        01
# 16     671722        BEAUCOUZE <> ST BARTHELEMY        04
# 17     671308        BELLE BEILLE <> MONPLAISIR        01
# 18     671785   MURS ERIGNE <> ADEZIERE SALETTE        03
# 19     671447        BEAUCOUZE <> ST BARTHELEMY        04
# 20     672665     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 21     671437        BEAUCOUZE <> ST BARTHELEMY        04
# 22     671302     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 23     671700   M-MARCILLE <> ST AUBIN LA SALLE        12
# 24     671055               ARDENNE <> ROSERAIE         A
# 25     671057               ARDENNE <> ROSERAIE         A
# 26     671070               ARDENNE <> ROSERAIE         A
# 27     671528    SOUCELLES PELLOUAILLES <> GARE        32
# 28     671295       St LEGER St LAMBERT <> GARE        35
# 29     671755              LA MEMBROLLE <> GARE        39
# ..        ...                               ...       ...
# 95     671465           BOUCHEMAINE <> Z I  EST        06
# 96     671447           BOUCHEMAINE <> Z I  EST        06
# 97     671074               ARDENNE <> ROSERAIE         A
# 98     671039               ARDENNE <> ROSERAIE         A
# 99     671051               ARDENNE <> ROSERAIE         A
# 100    671627               SAVENNIERES <> GARE        37
# 101    672193      ECOUFLANT GRIMORELLE <> GARE        42
# 102    672127         St MARTIN St JEAN <> GARE        36
# 103    672346       St LEGER St LAMBERT <> GARE        35
# 104    671548  PONTS CE <>  AQUAVITA H. RECULEE        08
# 105    671458     ST LEZIN SORGES <> SCHWEITZER        10
# 106    671695  PONTS CE <>  AQUAVITA H. RECULEE        08
# 107    671234    CIRCULAIRE VERNEAU GARE EUROPE        05
# 108    671851     ST LEZIN SORGES <> SCHWEITZER        10
# 109    671863  LAC MAINE <> STE GEMMES CL ANJOU        11
# 110    671959        BELLE BEILLE <> MONPLAISIR        01
# 111    671393   MURS ERIGNE <> ADEZIERE SALETTE        03
# 112    671216     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 113    671979     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 114    671261        BEAUCOUZE <> ST BARTHELEMY        04
# 115    672021        BELLE BEILLE <> MONPLAISIR        01
# 116    671733          ESPACE ANJOU <> EVENTARD        09
# 117    671067               ARDENNE <> ROSERAIE         A
# 118    672787         St MARTIN St JEAN <> GARE        36
# 119    672784     St CLEMENT St LAMBERT <> GARE        38
# 120    672237            FENEU CANTENAY <> GARE        33
# 121    671290          SARRIGNE PLESSIS <> GARE        30
# 122    671990        BEAUCOUZE <> ST BARTHELEMY        04
# 123    671809     ST SYLVAIN BANCHAIS <>TRELAZE        02
# 124    671327  LAC MAINE <> STE GEMMES CL ANJOU        11
#
# [125 rows x 3 columns]

# %%
#Trajet
id_bus = [elem['fields']['idvh'] for elem in dd]
id_ligne = [elem['fields']['idligne'] for elem in dd]
latitude = [elem['fields']['coordonnees'][0] for elem in dd]
longitude = [elem['fields']['coordonnees'][1] for elem in dd]

trajet = pd.DataFrame({
    'id_bus': id_bus,
    'id_ligne': id_ligne,
    'latitude': latitude,
    'longitude': longitude
})

#trajet.info()

trajet
# Out:
#         id_bus   id_ligne   latitude  longitude
# 0    268436259  268435460  47.476323  -0.492809
# 1    268436120  268435457  47.495681  -0.569286
# 2    268435899  268435462  47.475119  -0.492731
# 3    268436158  268435460  47.473040  -0.486090
# 4    268435879  268435515  47.475602  -0.492491
# 5    268436137  268435460  47.495600  -0.569680
# 6    268436145  268435460  47.484244  -0.626409
# 7    268435905  268435468  47.489367  -0.503753
# 8    268436270  268435462  47.474899  -0.493994
# 9    268435909  268435468  47.471773  -0.546648
# 10   268435910  268435464  47.436542  -0.520956
# 11   268435913  268435461  47.496482  -0.568241
# 12   268435994  268435466  47.480161  -0.539800
# 13   268436057  268435457  47.465352  -0.556893
# 14   268436059  268435457  47.480686  -0.594292
# 15   268436070  268435457  47.467048  -0.552047
# 16   268436072  268435460  47.478290  -0.605366
# 17   268436078  268435457  47.469525  -0.531726
# 18   268436079  268435459  47.395496  -0.555768
# 19   268436107  268435460  47.469677  -0.548792
# 20   268436110  268435458  47.452049  -0.469465
# 21   268436126  268435460  47.472724  -0.576636
# 22   268436139  268435458  47.446199  -0.496795
# 23   268436273  268435468  47.470241  -0.550720
# 24   268436461  268435471  47.463369  -0.555206
# 25   268436470  268435471  47.474271  -0.554802
# 26   268436472  268435471  47.494341  -0.571749
# 27   268442638  268435488  47.466615  -0.553550
# 28   268443547  268435491  47.468484  -0.558736
# 29   268443565  268435495  47.472160  -0.566489
# ..         ...        ...        ...        ...
# 95   268436275  268435462  47.471446  -0.565906
# 96   268436277  268435462  47.471691  -0.546724
# 97   268436457  268435471  47.468925  -0.549707
# 98   268436459  268435471  47.511314  -0.595833
# 99   268436468  268435471  47.492170  -0.560329
# 100  268438708  268435493  47.409826  -0.620205
# 101  268438716  268435498  47.526484  -0.505283
# 102  268438755  268435492  47.444239  -0.687119
# 103  268443784  268435491  47.487761  -0.666006
# 104  268435911  268435464  47.484971  -0.552701
# 105  268435892  268435466  47.458388  -0.557523
# 106  268435908  268435464  47.432703  -0.518562
# 107  268435986  268435461  47.471761  -0.519155
# 108  268435992  268435466  47.480221  -0.539564
# 109  268435997  268435467  47.464828  -0.575288
# 110  268436067  268435457  47.473607  -0.571228
# 111  268436109  268435459  47.476817  -0.567420
# 112  268436125  268435458  47.462185  -0.542400
# 113  268436129  268435458  47.486408  -0.513926
# 114  268436134  268435460  47.466739  -0.498618
# 115  268436142  268435457  47.475095  -0.561777
# 116  268436272  268435465  47.472277  -0.546291
# 117  268436465  268435471  47.449560  -0.561768
# 118  268438766  268435492  47.474079  -0.567842
# 119  268443096  268435494  47.472085  -0.599448
# 120  268443569  268435489  47.505123  -0.569283
# 121  268444305  268435486  47.481874  -0.522606
# 122  268436074  268435460  47.461262  -0.492579
# 123  268436119  268435458  47.497366  -0.494325
# 124  268436276  268435467  47.444281  -0.539203
#
# [125 rows x 4 columns]

# %%
#Etape
id_arret = [elem['fields']['idarret'] for elem in dd]
harret = [elem['fields']['harret'] for elem in dd]
record_timestamp = [elem['record_timestamp'] for elem in dd]
ecart = [elem['fields']['ecart'] for elem in dd]

etape = pd.DataFrame({
    'id_arret': id_arret,
    'heure_theorique': harret,
    'ecart': ecart,
    'record_timestamp': record_timestamp
})

etape['record_timestamp'] = pd.to_datetime(etape['record_timestamp'])

def transfo(row):
    return row['record_timestamp'] + dt.timedelta(seconds=row['ecart'])
etape['heure_estime'] = etape.apply(transfo, axis='columns')

#etape.info()

etape
# Out:
#      id_arret            heure_theorique  ecart    record_timestamp  \
# 0      671375  2018-06-19T07:09:46+00:00      0 2018-06-19 07:16:13
# 1      671973  2018-06-19T07:45:09+00:00      0 2018-06-19 07:57:53
# 2      671375  2018-06-19T07:26:00+00:00      0 2018-06-19 07:31:18
# 3      671963  2018-06-19T10:38:00+00:00      0 2018-06-19 10:28:13
# 4      672636  2018-06-18T22:00:00+00:00   -247 2018-06-19 10:10:16
# 5      671973  2018-06-19T06:53:55+00:00      0 2018-06-19 10:21:55
# 6      672520  2018-06-19T10:39:00+00:00      0 2018-06-19 10:30:15
# 7      671157  2018-06-19T10:39:00+00:00      0 2018-06-19 10:32:35
# 8      672083  2018-06-19T10:41:00+00:00      0 2018-06-19 10:35:35
# 9      671677  2018-06-19T10:38:50+00:00   -110 2018-06-19 10:36:33
# 10     671927  2018-06-19T10:37:27+00:00    228 2018-06-19 10:36:33
# 11     672581  2018-06-19T10:38:32+00:00   -127 2018-06-19 10:36:33
# 12     671279  2018-06-19T10:37:16+00:00    334 2018-06-19 10:36:33
# 13     671475  2018-06-19T10:36:48+00:00    -38 2018-06-19 10:36:33
# 14     671792  2018-06-19T10:37:34+00:00    -40 2018-06-19 10:36:33
# 15     671528  2018-06-19T10:36:31+00:00    148 2018-06-19 10:36:33
# 16     671722  2018-06-19T10:36:31+00:00    -31 2018-06-19 10:36:33
# 17     671308  2018-06-19T10:37:07+00:00     51 2018-06-19 10:36:33
# 18     671785  2018-06-19T10:36:24+00:00     24 2018-06-19 10:36:33
# 19     671447  2018-06-19T10:36:42+00:00    143 2018-06-19 10:36:33
# 20     672665  2018-06-19T10:37:26+00:00    415 2018-06-19 10:36:33
# 21     671437  2018-06-19T10:36:36+00:00    144 2018-06-19 10:36:33
# 22     671302  2018-06-19T10:37:07+00:00    406 2018-06-19 10:36:33
# 23     671700  2018-06-19T10:37:28+00:00    149 2018-06-19 10:36:33
# 24     671055  2018-06-19T10:37:31+00:00    152 2018-06-19 10:36:33
# 25     671057  2018-06-19T10:36:35+00:00     35 2018-06-19 10:36:33
# 26     671070  2018-06-19T10:38:16+00:00    126 2018-06-19 10:36:33
# 27     671528  2018-06-19T10:37:06+00:00    248 2018-06-19 10:36:33
# 28     671295  2018-06-19T10:36:38+00:00    109 2018-06-19 10:36:33
# 29     671755  2018-06-19T10:37:30+00:00    131 2018-06-19 10:36:33
# ..        ...                        ...    ...                 ...
# 95     671465  2018-06-19T10:37:19+00:00    220 2018-06-19 10:36:33
# 96     671447  2018-06-19T10:38:38+00:00    -22 2018-06-19 10:36:33
# 97     671074  2018-06-19T10:36:40+00:00      7 2018-06-19 10:36:33
# 98     671039  2018-06-19T10:36:37+00:00    237 2018-06-19 10:36:33
# 99     671051  2018-06-19T10:36:29+00:00    128 2018-06-19 10:36:33
# 100    671627  2018-06-19T10:37:06+00:00   -141 2018-06-19 10:36:33
# 101    672193  2018-06-19T10:35:42+00:00     50 2018-06-19 10:36:33
# 102    672127  2018-06-18T22:00:00+00:00      0 2018-06-19 10:36:33
# 103    672346  2018-06-19T10:38:12+00:00    -47 2018-06-19 10:36:33
# 104    671548  2018-06-19T10:42:00+00:00      0 2018-06-19 10:35:53
# 105    671458  2018-06-19T10:36:37+00:00     17 2018-06-19 10:36:33
# 106    671695  2018-06-19T10:36:53+00:00    -17 2018-06-19 10:36:33
# 107    671234  2018-06-19T10:37:36+00:00    -37 2018-06-19 10:36:33
# 108    671851  2018-06-19T10:37:34+00:00   -126 2018-06-19 10:36:33
# 109    671863  2018-06-19T10:39:13+00:00     11 2018-06-19 10:36:33
# 110    671959  2018-06-19T10:36:23+00:00    -42 2018-06-19 10:36:33
# 111    671393  2018-06-19T10:36:38+00:00    -21 2018-06-19 10:36:33
# 112    671216  2018-06-19T10:36:29+00:00    437 2018-06-19 10:36:33
# 113    671979  2018-06-19T10:36:51+00:00     52 2018-06-19 10:36:33
# 114    671261  2018-06-19T10:37:24+00:00     42 2018-06-19 10:36:33
# 115    672021  2018-06-19T10:38:15+00:00    -29 2018-06-19 10:36:33
# 116    671733  2018-06-19T10:36:28+00:00    220 2018-06-19 10:36:33
# 117    671067  2018-06-19T10:38:00+00:00     30 2018-06-19 10:36:33
# 118    672787  2018-06-19T10:39:55+00:00   -105 2018-06-19 10:36:33
# 119    672784  2018-06-19T10:36:37+00:00    -22 2018-06-19 10:36:33
# 120    672237  2018-06-19T10:40:50+00:00    338 2018-06-19 10:36:33
# 121    671290  2018-06-19T10:36:55+00:00    220 2018-06-19 10:36:33
# 122    671990  2018-06-19T10:36:22+00:00    323 2018-06-19 10:36:16
# 123    671809  2018-06-19T10:45:01+00:00      0 2018-06-19 10:36:16
# 124    671327  2018-06-19T10:47:00+00:00      0 2018-06-19 10:27:15
#
#            heure_estime
# 0   2018-06-19 07:16:13
# 1   2018-06-19 07:57:53
# 2   2018-06-19 07:31:18
# 3   2018-06-19 10:28:13
# 4   2018-06-19 10:06:09
# 5   2018-06-19 10:21:55
# 6   2018-06-19 10:30:15
# 7   2018-06-19 10:32:35
# 8   2018-06-19 10:35:35
# 9   2018-06-19 10:34:43
# 10  2018-06-19 10:40:21
# 11  2018-06-19 10:34:26
# 12  2018-06-19 10:42:07
# 13  2018-06-19 10:35:55
# 14  2018-06-19 10:35:53
# 15  2018-06-19 10:39:01
# 16  2018-06-19 10:36:02
# 17  2018-06-19 10:37:24
# 18  2018-06-19 10:36:57
# 19  2018-06-19 10:38:56
# 20  2018-06-19 10:43:28
# 21  2018-06-19 10:38:57
# 22  2018-06-19 10:43:19
# 23  2018-06-19 10:39:02
# 24  2018-06-19 10:39:05
# 25  2018-06-19 10:37:08
# 26  2018-06-19 10:38:39
# 27  2018-06-19 10:40:41
# 28  2018-06-19 10:38:22
# 29  2018-06-19 10:38:44
# ..                  ...
# 95  2018-06-19 10:40:13
# 96  2018-06-19 10:36:11
# 97  2018-06-19 10:36:40
# 98  2018-06-19 10:40:30
# 99  2018-06-19 10:38:41
# 100 2018-06-19 10:34:12
# 101 2018-06-19 10:37:23
# 102 2018-06-19 10:36:33
# 103 2018-06-19 10:35:46
# 104 2018-06-19 10:35:53
# 105 2018-06-19 10:36:50
# 106 2018-06-19 10:36:16
# 107 2018-06-19 10:35:56
# 108 2018-06-19 10:34:27
# 109 2018-06-19 10:36:44
# 110 2018-06-19 10:35:51
# 111 2018-06-19 10:36:12
# 112 2018-06-19 10:43:50
# 113 2018-06-19 10:37:25
# 114 2018-06-19 10:37:15
# 115 2018-06-19 10:36:04
# 116 2018-06-19 10:40:13
# 117 2018-06-19 10:37:03
# 118 2018-06-19 10:34:48
# 119 2018-06-19 10:36:11
# 120 2018-06-19 10:42:11
# 121 2018-06-19 10:40:13
# 122 2018-06-19 10:41:39
# 123 2018-06-19 10:36:16
# 124 2018-06-19 10:27:15
#
# [125 rows x 5 columns]

# %%
#Ouverture de la connection vers la bdd
engine = create_engine("sqlite:///data.sqlite")
connection = engine.connect()

# %%
#Table arret
arret.to_sql('arret', connection, if_exists='replace', index=False)

# %%
#Table bus
bus.to_sql('bus', connection, if_exists='replace', index=False)

# %%
#Table ligne
ligne.to_sql('ligne', connection, if_exists='replace', index=False)

# %%
#Table trajet
trajet.to_sql('trajet', connection, if_exists='replace', index=False)

# %%
#Table etape
etape.to_sql('etape', connection, if_exists='replace', index=False)

# %%
#Fermeture connection
connection.close()
