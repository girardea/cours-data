# %% [markdown]
# # Import des modules nécessaires

# %%
    # Pour manipuler efficacement des tables de données dans Python
    import pandas as pd

    # Pour faire des requêtes GET et POST
    import requests
    
    # Pour gérer les date
    import datetime as dt
    
    # sql
    from sqlalchemy import create_engine

# %%
print(pd.__version__)
# Out:
# 0.22.0

# %%
print(requests.__version__)
# Out:
# 2.18.4

# %% [markdown]
# # Requêtage d'une API REST

# %% [markdown]
# Pour lancer une requête GET, c'est ultra-simple : on utilise `requests.get(url)`.
#
# Si vous voulez glisser des paramètres avec la requête, utilisez l'argument optionnel `params`, qui accepte un simple dictionnaire.

# %%
r = requests.get("https://data.angers.fr/api/records/1.0/search/",
                 params={
                     'dataset': 'horaires-theoriques-et-arrets-du-reseau-irigo-gtfs',
                     'rows': 10
                 })

# %%
g = requests.get("https://data.angers.fr/api/records/1.0/search/",
                 params={
                     'dataset': 'bus-tram-position-tr',
                     'rows': 200
                 })

# %% [markdown]
# Regardons la nature de ce qui nous est renvoyé.

# %%
type(g)
# Out:
# requests.models.Response

# %% [markdown]
# C'est un objet de la classe `Response`. Si vous voulez connaitre toutes les méthodes attachées, faites `help(r)`

# %%
help(g)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, state)
#  |
#  |  close(self)
#  |      Releases the connection back to the pool. Once this method has been
#  |      called the underlying ``raw`` object must not be accessed again.
#  |
#  |      *Note: Should not normally need to be called explicitly.*
#  |
#  |  iter_content(self, chunk_size=1, decode_unicode=False)
#  |      Iterates over the response data.  When stream=True is set on the
#  |      request, this avoids reading the content at once into memory for
#  |      large responses.  The chunk size is the number of bytes it should
#  |      read into memory.  This is not necessarily the length of each item
#  |      returned as decoding can take place.
#  |
#  |      chunk_size must be of type int or None. A value of None will
#  |      function differently depending on the value of `stream`.
#  |      stream=True will read data as it arrives in whatever size the
#  |      chunks are received. If stream=False, data is returned as
#  |      a single chunk.
#  |
#  |      If decode_unicode is True, content will be decoded using the best
#  |      available encoding based on the response.
#  |
#  |  iter_lines(self, chunk_size=512, decode_unicode=None, delimiter=None)
#  |      Iterates over the response data, one line at a time.  When
#  |      stream=True is set on the request, this avoids reading the
#  |      content at once into memory for large responses.
#  |
#  |      .. note:: This method is not reentrant safe.
#  |
#  |  json(self, **kwargs)
#  |      Returns the json-encoded content of a response, if any.
#  |
#  |      :param \*\*kwargs: Optional arguments that ``json.loads`` takes.
#  |      :raises ValueError: If the response body does not contain valid json.
#  |
#  |  raise_for_status(self)
#  |      Raises stored :class:`HTTPError`, if one occurred.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  apparent_encoding
#  |      The apparent encoding, provided by the chardet library.
#  |
#  |  content
#  |      Content of the response, in bytes.
#  |
#  |  is_permanent_redirect
#  |      True if this Response one of the permanent versions of redirect.
#  |
#  |  is_redirect
#  |      True if this Response is a well-formed HTTP redirect that could have
#  |      been processed automatically (by :meth:`Session.resolve_redirects`).
#  |
#  |  links
#  |      Returns the parsed header links of the response, if any.
#  |
#  |  next
#  |      Returns a PreparedRequest for the next request in a redirect chain, if there is one.
#  |
#  |  ok
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  text
#  |      Content of the response, in unicode.
#  |
#  |      If Response.encoding is None, encoding will be guessed using
#  |      ``chardet``.
#  |
#  |      The encoding of the response content is determined based solely on HTTP
#  |      headers, following RFC 2616 to the letter. If you can take advantage of
#  |      non-HTTP knowledge to make a better guess at the encoding, you should
#  |      set ``r.encoding`` appropriately before accessing this property.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __attrs__ = ['_content', 'status_code', 'headers', 'url', 'history', '...

# %% [markdown]
# Pour tester que tout a bien fonctionnné, on va vérifié le statut.

# %%
g.raise_for_status()

# %% [markdown]
# Si ça dit rien c'est que c'est bon :) Dans le doute, regardons le statut...

# %%
g.status_code
# Out:
# 200

# %% [markdown]
# Statut 200 = succès !!

# %%
g.json()
# Out:
# {'nhits': 106,
#  'parameters': {'dataset': ['bus-tram-position-tr'],
#   'format': 'json',
#   'rows': 200,
#   'timezone': 'UTC'},
#  'records': [{'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 155,
#     'coordonnees': [47.504063, -0.58675933],
#     'dest': 'CHU - HOPITAL',
#     'ecart': 126,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:33+00:00',
#     'idarret': 672852,
#     'iddesserte': 268939803,
#     'idligne': 268435463,
#     'idparcours': 268939776,
#     'idvh': 268435884,
#     'mnemoarret': 'ACAS-7C',
#     'mnemoligne': '07',
#     'nomarret': 'ACACIAS',
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'novh': '428',
#     'numarret': 9581,
#     'sv': '0725',
#     'type': 'OMNICITY',
#     'x': 379826,
#     'y': 2282369},
#    'geometry': {'coordinates': [-0.58675933, 47.504063], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '1fd516059c0bf544c7241ec3ee006cfe9b15987e'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 330,
#     'coordonnees': [47.478688, -0.56497295],
#     'dest': 'HAUTE DE RECULEE',
#     'ecart': 27,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:02+00:00',
#     'idarret': 672949,
#     'iddesserte': 268972327,
#     'idligne': 268435464,
#     'idparcours': 268972288,
#     'idvh': 268435899,
#     'mnemoarret': 'BICHO.-E',
#     'mnemoligne': '08',
#     'nomarret': 'BICHON',
#     'nomligne': 'PONTS CE <>  AQUAVITA H. RECULEE',
#     'novh': '443',
#     'numarret': 991,
#     'sv': '0821',
#     'type': 'OMNICITY',
#     'x': 381362,
#     'y': 2279489},
#    'geometry': {'coordinates': [-0.56497295, 47.478688], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'e9e06aaa63b6f1909e235bab88e3c0c22401af53'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 304,
#     'coordonnees': [47.451116, -0.53399899],
#     'dest': 'AQUAVITA VERNEAU',
#     'ecart': -103,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:06+00:00',
#     'idarret': 673827,
#     'iddesserte': 268969741,
#     'idligne': 268435464,
#     'idparcours': 268969728,
#     'idvh': 268435910,
#     'mnemoarret': 'VIVIERS',
#     'mnemoligne': '08',
#     'nomarret': 'VIVIERS',
#     'nomligne': 'PONTS CE <>  AQUAVITA H. RECULEE',
#     'novh': '454',
#     'numarret': 29924,
#     'sv': '0803',
#     'type': 'OMNICITY',
#     'x': 383583,
#     'y': 2276340},
#    'geometry': {'coordinates': [-0.53399899, 47.451116], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'a627776c208afbfbfe4fcb5838046358a0b64ab9'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 66,
#     'coordonnees': [47.487846, -0.57233738],
#     'dest': 'CIRCULAIRE SENS A',
#     'ecart': -15,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:16+00:00',
#     'idarret': 673591,
#     'iddesserte': 268774204,
#     'idligne': 268435461,
#     'idparcours': 268774144,
#     'idvh': 268435913,
#     'mnemoarret': 'PETIPA-E',
#     'mnemoligne': '05',
#     'nomarret': 'PETITES PANNES',
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'novh': '457',
#     'numarret': 21835,
#     'sv': '0528',
#     'type': 'OMNICITY',
#     'x': 380845,
#     'y': 2280527},
#    'geometry': {'coordinates': [-0.57233738, 47.487846], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '11f4c1b37f06116e5b390b43b8e54697d256c67d'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 212,
#     'coordonnees': [47.451319, -0.57166998],
#     'dest': 'CIRCULAIRE SENS B',
#     'ecart': 43,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:42+00:00',
#     'idarret': 673245,
#     'iddesserte': 268807703,
#     'idligne': 268435461,
#     'idparcours': 268807680,
#     'idvh': 268435987,
#     'mnemoarret': 'GAUBOUR5',
#     'mnemoligne': '05',
#     'nomarret': 'GAUBOURGS',
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'novh': '531',
#     'numarret': 29955,
#     'sv': '0501',
#     'type': 'GX 327',
#     'x': 380745,
#     'y': 2276467},
#    'geometry': {'coordinates': [-0.57166998, 47.451319], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '9f2b9f6c3301d14871638a9d10a3070be4f10283'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 347,
#     'coordonnees': [47.491421, -0.56510918],
#     'dest': 'CIRCULAIRE SENS B',
#     'ecart': -151,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:07+00:00',
#     'idarret': 674341,
#     'iddesserte': 268807742,
#     'idligne': 268435461,
#     'idparcours': 268807680,
#     'idvh': 268435994,
#     'mnemoarret': 'VERNEA-E',
#     'mnemoligne': '05',
#     'nomarret': 'AURIOL',
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'novh': '538',
#     'numarret': 24578,
#     'sv': '0503',
#     'type': 'GX 327',
#     'x': 381404,
#     'y': 2280904},
#    'geometry': {'coordinates': [-0.56510918, 47.491421], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '8761725445b2f9ae6b68bcdf6c2d59173db8f9cf'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 283,
#     'coordonnees': [47.470633, -0.51820553],
#     'dest': 'BEAUCOUZE  HAUTE ROCHE',
#     'ecart': 2,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:10+00:00',
#     'idarret': 672880,
#     'iddesserte': 268741651,
#     'idligne': 268435460,
#     'idparcours': 268741632,
#     'idvh': 268436057,
#     'mnemoarret': 'ARCEAU',
#     'mnemoligne': '04',
#     'nomarret': 'ARCEAU',
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'novh': '601',
#     'numarret': 15889,
#     'sv': '0425',
#     'type': 'MAN City',
#     'x': 384852,
#     'y': 2278465},
#    'geometry': {'coordinates': [-0.51820553, 47.470633], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'a1b0c279c5f0d4879ca2c32b0ea558e39a40bec6'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 261,
#     'coordonnees': [47.474476, -0.5652878],
#     'dest': 'BELLE BEILLE',
#     'ecart': 235,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:13+00:00',
#     'idarret': 673514,
#     'iddesserte': 268545563,
#     'idligne': 268435457,
#     'idparcours': 268545536,
#     'idvh': 268436070,
#     'mnemoarret': 'MONPRO-E',
#     'mnemoligne': '01',
#     'nomarret': 'MONPROFIT',
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'novh': '614',
#     'numarret': 29694,
#     'sv': '0106',
#     'type': 'MAN City',
#     'x': 381321,
#     'y': 2279022},
#    'geometry': {'coordinates': [-0.5652878, 47.474476], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '97f6ce6f0689c56277361a552ab05a4d51c5bc50'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 135,
#     'coordonnees': [47.456899, -0.53197492],
#     'dest': 'TRELAZE QUANTINIERE',
#     'ecart': 251,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:51+00:00',
#     'idarret': 673498,
#     'iddesserte': 268611107,
#     'idligne': 268435458,
#     'idparcours': 268611072,
#     'idvh': 268436107,
#     'mnemoarret': 'MILLOT-E',
#     'mnemoligne': '02',
#     'nomarret': 'SAUMUROISE',
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'novh': '651',
#     'numarret': 2926,
#     'sv': '0216',
#     'type': 'OMNIART',
#     'x': 383759,
#     'y': 2276977},
#    'geometry': {'coordinates': [-0.53197492, 47.456899], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'dffc3b25e4e34ecd2cef8eff3568305edd7045f1'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 23,
#     'coordonnees': [47.468693, -0.49269522],
#     'dest': 'ST BARTHELEMY',
#     'ecart': 15,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:05+00:00',
#     'idarret': 673027,
#     'iddesserte': 268706621,
#     'idligne': 268435460,
#     'idparcours': 268706560,
#     'idvh': 268436110,
#     'mnemoarret': 'CEZAN-E',
#     'mnemoligne': '04',
#     'nomarret': 'CEZANNE',
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'novh': '654',
#     'numarret': 16647,
#     'sv': '0409',
#     'type': 'OMNIART',
#     'x': 386766,
#     'y': 2278180},
#    'geometry': {'coordinates': [-0.49269522, 47.468693], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '397a1a8465f0a320704c8e49423d5602f81800da'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 302,
#     'coordonnees': [47.464558, -0.54834168],
#     'dest': 'BANCHAIS',
#     'ecart': 323,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:26:32+00:00',
#     'idarret': 673574,
#     'iddesserte': 268579104,
#     'idligne': 268435458,
#     'idparcours': 268579072,
#     'idvh': 268436120,
#     'mnemoarret': 'PATNOIRE',
#     'mnemoligne': '02',
#     'nomarret': 'PATINOIRE',
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'novh': '664',
#     'numarret': 31383,
#     'sv': '0206',
#     'type': 'OMNIART',
#     'x': 382557,
#     'y': 2277873},
#    'geometry': {'coordinates': [-0.54834168, 47.464558], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'a0a5b38fdf8b9abdd0ac05e7bf1854b76737021b'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 216,
#     'coordonnees': [47.469677, -0.54879155],
#     'dest': 'TRELAZE QUANTINIERE',
#     'ecart': -4,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:56+00:00',
#     'idarret': 673205,
#     'iddesserte': 268611597,
#     'idligne': 268435458,
#     'idparcours': 268611584,
#     'idvh': 268436126,
#     'mnemoarret': 'FO-LOR-R',
#     'mnemoligne': '02',
#     'nomarret': 'FOCH MAISON BLEUE',
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'novh': '670',
#     'numarret': 170,
#     'sv': '0201',
#     'type': 'OMNIART',
#     'x': 382544,
#     'y': 2278443},
#    'geometry': {'coordinates': [-0.54879155, 47.469677], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '9d9442de2731053444e1871f103d3f6d8681bd25'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 188,
#     'coordonnees': [47.475512, -0.59954358],
#     'dest': 'ST BARTHELEMY',
#     'ecart': 35,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:15+00:00',
#     'idarret': 673242,
#     'iddesserte': 268707092,
#     'idligne': 268435460,
#     'idparcours': 268707072,
#     'idvh': 268436145,
#     'mnemoarret': 'GAUBERT',
#     'mnemoligne': '04',
#     'nomarret': 'GAUBERT',
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'novh': '689',
#     'numarret': 18121,
#     'sv': '0408',
#     'type': 'OmniArtE6',
#     'x': 378745,
#     'y': 2279233},
#    'geometry': {'coordinates': [-0.59954358, 47.475512], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'c654b6be045e5ffa2ce381caefccce8eb35b7d5c'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 225,
#     'coordonnees': [47.469037, -0.54955333],
#     'dest': 'ANGERS ROSERAIE',
#     'ecart': -6,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:10+00:00',
#     'idarret': 672806,
#     'iddesserte': 269452562,
#     'idligne': 268435471,
#     'idparcours': 269452544,
#     'idvh': 268436461,
#     'mnemoarret': '1FMBL',
#     'mnemoligne': 'A',
#     'nomarret': 'FOCHMAISONBLEUEv1',
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'novh': '1005',
#     'numarret': 11327,
#     'sv': 'A06',
#     'type': 'CITADIS',
#     'x': 382484,
#     'y': 2278374},
#    'geometry': {'coordinates': [-0.54955333, 47.469037], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'b95e98363405c9aa34a2927c7b4b1694df5d455d'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 33,
#     'coordonnees': [47.433763, -0.50072346],
#     'dest': 'ST AUBIN LA SALLE',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:32:00+00:00',
#     'idarret': 673542,
#     'iddesserte': 269233409,
#     'idligne': 268435468,
#     'idparcours': 269233408,
#     'idvh': 268435909,
#     'mnemoarret': 'MOULINMA',
#     'mnemoligne': '12',
#     'nomarret': 'MOULIN MARCILLE',
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'novh': '453',
#     'numarret': 32614,
#     'sv': '1208',
#     'type': 'OMNICITY',
#     'x': 386021,
#     'y': 2274321},
#    'geometry': {'coordinates': [-0.50072346, 47.433763], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:16+00:00',
#    'recordid': 'c22f1921661fede0c6f6635c9e3bddf9f5d46476'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 202,
#     'coordonnees': [47.422079, -0.61061938],
#     'dest': 'BOUCHEMAINE CENTRE',
#     'ecart': 526,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:25+00:00',
#     'idarret': 672971,
#     'iddesserte': 268873778,
#     'idligne': 268435462,
#     'idparcours': 268873728,
#     'idvh': 268436270,
#     'mnemoarret': 'BOUCHE-E',
#     'mnemoligne': '06',
#     'nomarret': 'BOUCHEMAINE',
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'novh': '814',
#     'numarret': 10804,
#     'sv': '0622',
#     'type': 'OmniSTDE6',
#     'x': 377688,
#     'y': 2273328},
#    'geometry': {'coordinates': [-0.61061938, 47.422079], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:33+00:00',
#    'recordid': 'eccdff00c372435527fda3fdf2c58cdb4f76720b'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 5,
#     'coordonnees': [47.46824, -0.52616112],
#     'dest': 'EVENTARD par MONPLAISIR',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:26:00+00:00',
#     'idarret': 673181,
#     'iddesserte': 269029377,
#     'idligne': 268435465,
#     'idparcours': 269029376,
#     'idvh': 268435965,
#     'mnemoarret': 'ESPACEAN',
#     'mnemoligne': '09',
#     'nomarret': 'ESPACE ANJOU',
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'novh': '509',
#     'numarret': 18251,
#     'sv': '0904',
#     'type': 'GX317',
#     'x': 384243,
#     'y': 2278221},
#    'geometry': {'coordinates': [-0.52616112, 47.46824], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:22:55+00:00',
#    'recordid': '48c46de920ba9eae1ae8aa285973e6a47b96b15a'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 61,
#     'coordonnees': [47.512809, -0.47068963],
#     'dest': 'TRELAZE QUANTINIERE',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:32:00+00:00',
#     'idarret': 673768,
#     'iddesserte': 268611073,
#     'idligne': 268435458,
#     'idparcours': 268611072,
#     'idvh': 268436059,
#     'mnemoarret': 'STSYLVAI',
#     'mnemoligne': '02',
#     'nomarret': 'ST SYLVAIN',
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'novh': '603',
#     'numarret': 32055,
#     'sv': '0209',
#     'type': 'MAN City',
#     'x': 388599,
#     'y': 2283022},
#    'geometry': {'coordinates': [-0.47068963, 47.512809], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:23:18+00:00',
#    'recordid': '09f8443253a4eefd0208aae651dc2f15bdf2f09f'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 346,
#     'coordonnees': [47.458785, -0.53287278],
#     'dest': 'SPECIAL PISCINE',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:30:00+00:00',
#     'idarret': 674393,
#     'iddesserte': 272280065,
#     'idligne': 268435514,
#     'idparcours': 272280064,
#     'idvh': 268435879,
#     'mnemoarret': 'P-JBOUIN',
#     'mnemoligne': '534',
#     'nomarret': 'PISCINE JEAN BOUIN',
#     'nomligne': 'Piscine JEAN-BOUIN',
#     'novh': '423',
#     'numarret': 643487,
#     'sv': '53413',
#     'type': 'OMNICITY',
#     'x': 383699,
#     'y': 2277189},
#    'geometry': {'coordinates': [-0.53287278, 47.458785], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:12:15+00:00',
#    'recordid': 'c1face88ffc04e903b88bc015a11c7192cc278ca'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 287,
#     'coordonnees': [47.491111, -0.52833384],
#     'dest': 'BELLE BEILLE',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:25:00+00:00',
#     'idarret': 673512,
#     'iddesserte': 268545537,
#     'idligne': 268435457,
#     'idparcours': 268545536,
#     'idvh': 268436072,
#     'mnemoarret': 'MONPLAIS',
#     'mnemoligne': '01',
#     'nomarret': 'MONPLAISIR',
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'novh': '616',
#     'numarret': 4795,
#     'sv': '0126',
#     'type': 'MAN City',
#     'x': 384172,
#     'y': 2280768},
#    'geometry': {'coordinates': [-0.52833384, 47.491111], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:20:18+00:00',
#    'recordid': 'ca5f9f90466b1fe721348057a739de323c1f62b0'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 270,
#     'coordonnees': [47.512522, -0.58681221],
#     'dest': 'MURS ERIGNE',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:29:00+00:00',
#     'idarret': 673718,
#     'iddesserte': 268674049,
#     'idligne': 268435459,
#     'idparcours': 268674048,
#     'idvh': 268436079,
#     'mnemoarret': 'SALETTE',
#     'mnemoligne': '03',
#     'nomarret': 'AVRILLE SALETTE',
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'novh': '623',
#     'numarret': 16933,
#     'sv': '0306',
#     'type': 'MAN City',
#     'x': 379857,
#     'y': 2283309},
#    'geometry': {'coordinates': [-0.58681221, 47.512522], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:19:14+00:00',
#    'recordid': '58d6606ab15a377baf27fad8857c7941efc6b8d8'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 5,
#     'coordonnees': [47.475202, -0.49264276],
#     'dest': 'PAS EN SERVICE',
#     'ecart': 0,
#     'etat': 'HLPS',
#     'harret': '2018-06-20T07:26:01+00:00',
#     'idarret': 673133,
#     'iddesserte': 268875521,
#     'idligne': 268435462,
#     'idparcours': 268875520,
#     'idvh': 268435982,
#     'mnemoarret': 'DEPOT SD',
#     'mnemoligne': '06',
#     'nomarret': 'SORTIE DEPOT ST BART',
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'novh': '526',
#     'numarret': 6562,
#     'sv': '0621',
#     'type': 'GX 327',
#     'x': 386796,
#     'y': 2278903},
#    'geometry': {'coordinates': [-0.49264276, 47.475202], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T07:31:53+00:00',
#    'recordid': '5327f3cc268302a81b5dc181c51c0b928a071e0a'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 118,
#     'coordonnees': [47.444001, -0.56376079],
#     'dest': 'SPECIAL PISCINE',
#     'ecart': 0,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:30:00+00:00',
#     'idarret': 674395,
#     'iddesserte': 272207361,
#     'idligne': 268435513,
#     'idparcours': 272207360,
#     'idvh': 268435880,
#     'mnemoarret': 'P-ROSER',
#     'mnemoligne': '533',
#     'nomarret': 'PISCINE ROSERAIE',
#     'nomligne': 'Piscine ROSERAIE',
#     'novh': '424',
#     'numarret': 720289,
#     'sv': '53314',
#     'type': 'OMNICITY',
#     'x': 381311,
#     'y': 2275632},
#    'geometry': {'coordinates': [-0.56376079, 47.444001], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:14:58+00:00',
#    'recordid': '9e27c22a0f3035afdda1694da39f58334337f32f'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 175,
#     'coordonnees': [47.453281, -0.55331789],
#     'dest': 'SAINTE GEMMES',
#     'ecart': 144,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:36+00:00',
#     'idarret': 672932,
#     'iddesserte': 269198874,
#     'idligne': 268435467,
#     'idparcours': 269198848,
#     'idvh': 268435889,
#     'mnemoarret': 'BEDIER-E',
#     'mnemoligne': '11',
#     'nomarret': 'BEDIER',
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'novh': '433',
#     'numarret': 14067,
#     'sv': '1103',
#     'type': 'OMNICITY',
#     'x': 382136,
#     'y': 2276634},
#    'geometry': {'coordinates': [-0.55331789, 47.453281], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '410c26a654609b0c4d49d5270b56aa4d95ce1d46'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 259,
#     'coordonnees': [47.420651, -0.57742385],
#     'dest': 'SAINTE GEMMES',
#     'ecart': 546,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:01+00:00',
#     'idarret': 673393,
#     'iddesserte': 269198889,
#     'idligne': 268435467,
#     'idparcours': 269198848,
#     'idvh': 268435912,
#     'mnemoarret': 'LECHEN-E',
#     'mnemoligne': '11',
#     'nomarret': 'LE CHENE',
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'novh': '456',
#     'numarret': 9672,
#     'sv': '1122',
#     'type': 'OMNICITY',
#     'x': 380185,
#     'y': 2273076},
#    'geometry': {'coordinates': [-0.57742385, 47.420651], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '463ca9a4e1dce86959ef7fbe0f8262176858a5ba'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 187,
#     'coordonnees': [47.487522, -0.56334307],
#     'dest': 'MAIRIE DES PONTS DE CE',
#     'ecart': 5,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:05+00:00',
#     'idarret': 672959,
#     'iddesserte': 269004805,
#     'idligne': 268435464,
#     'idparcours': 269004800,
#     'idvh': 268435917,
#     'mnemoarret': 'BLERIOT',
#     'mnemoligne': '08',
#     'nomarret': 'BLERIOT',
#     'nomligne': 'PONTS CE <>  AQUAVITA H. RECULEE',
#     'novh': '461',
#     'numarret': 22166,
#     'sv': '0805',
#     'type': 'OMNICITY',
#     'x': 381521,
#     'y': 2280466},
#    'geometry': {'coordinates': [-0.56334307, 47.487522], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '820424ed13c77fcca5c018cd39cb0c8715893e08'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 348,
#     'coordonnees': [47.47478, -0.51976866],
#     'dest': 'ST AUBIN LA SALLE',
#     'ecart': 138,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:56+00:00',
#     'idarret': 672954,
#     'iddesserte': 269233440,
#     'idligne': 268435468,
#     'idparcours': 269233408,
#     'idvh': 268435919,
#     'mnemoarret': 'BIRGTE-E',
#     'mnemoligne': '12',
#     'nomarret': 'BIRGE',
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'novh': '463',
#     'numarret': 13020,
#     'sv': '1202',
#     'type': 'OMNICITY',
#     'x': 384751,
#     'y': 2278930},
#    'geometry': {'coordinates': [-0.51976866, 47.47478], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'd0336bf87cfa1a8ebcbc46581cdcb22d4e9aaff9'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 307,
#     'coordonnees': [47.446704, -0.5701045],
#     'dest': 'CIRCULAIRE SENS A',
#     'ecart': 150,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:54+00:00',
#     'idarret': 673519,
#     'iddesserte': 268774184,
#     'idligne': 268435461,
#     'idparcours': 268774144,
#     'idvh': 268435995,
#     'mnemoarret': 'MONTCA-E',
#     'mnemoligne': '05',
#     'nomarret': 'MONTCASSIN',
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'novh': '539',
#     'numarret': 18547,
#     'sv': '0524',
#     'type': 'GX 327',
#     'x': 380844,
#     'y': 2275950},
#    'geometry': {'coordinates': [-0.5701045, 47.446704], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '78853a2af8a78a2aa42b5257bdfa5136efca6aba'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 195,
#     'coordonnees': [47.465584, -0.51962065],
#     'dest': 'CIRCULAIRE SENS A',
#     'ecart': 319,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:36+00:00',
#     'idarret': 673821,
#     'iddesserte': 268774163,
#     'idligne': 268435461,
#     'idparcours': 268774144,
#     'idvh': 268435996,
#     'mnemoarret': 'VILLECHI',
#     'mnemoligne': '05',
#     'nomarret': 'VILLECHIEN',
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'novh': '540',
#     'numarret': 12145,
#     'sv': '0502',
#     'type': 'GX 327',
#     'x': 384725,
#     'y': 2277908},
#    'geometry': {'coordinates': [-0.51962065, 47.465584], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '0a12e603e02f5e994a88075550171c456e379e8b'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 126,
#     'coordonnees': [47.44676, -0.49925281],
#     'dest': 'TRELAZE QUANTINIERE',
#     'ecart': 626,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:17+00:00',
#     'idarret': 673060,
#     'iddesserte': 268611614,
#     'idligne': 268435458,
#     'idparcours': 268611584,
#     'idvh': 268436116,
#     'mnemoarret': 'CHOUTE-E',
#     'mnemoligne': '02',
#     'nomarret': 'CHOUTEAU',
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'novh': '660',
#     'numarret': 22740,
#     'sv': '0204',
#     'type': 'OMNIART',
#     'x': 386184,
#     'y': 2275761},
#    'geometry': {'coordinates': [-0.49925281, 47.44676], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '609d77ff21f896937788b45d7b65f06220ef926a'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 89,
#     'coordonnees': [47.471175, -0.52977031],
#     'dest': 'ST BARTHELEMY',
#     'ecart': 58,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:58+00:00',
#     'idarret': 673069,
#     'iddesserte': 268707113,
#     'idligne': 268435460,
#     'idparcours': 268707072,
#     'idvh': 268436133,
#     'mnemoarret': 'CIMETI-E',
#     'mnemoligne': '04',
#     'nomarret': "CIMETIERE DE L'EST",
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'novh': '677',
#     'numarret': 7431,
#     'sv': '0405',
#     'type': 'OMNIART',
#     'x': 383983,
#     'y': 2278557},
#    'geometry': {'coordinates': [-0.52977031, 47.471175], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '5cfae27a36b7e741a3ec4c343b7e3b3cbedea9d4'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 220,
#     'coordonnees': [47.452264, -0.55622194],
#     'dest': 'ANGERS ROSERAIE',
#     'ecart': 114,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:53+00:00',
#     'idarret': 672799,
#     'iddesserte': 269451543,
#     'idligne': 268435471,
#     'idparcours': 269451520,
#     'idvh': 268436466,
#     'mnemoarret': '1BAMA',
#     'mnemoligne': 'A',
#     'nomarret': 'BAMAKO',
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'novh': '1010',
#     'numarret': 24604,
#     'sv': 'A05',
#     'type': 'CITADIS',
#     'x': 381913,
#     'y': 2276529},
#    'geometry': {'coordinates': [-0.55622194, 47.452264], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '561a880c6d029bc6de267ab847dda10902ec5bb7'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 334,
#     'coordonnees': [47.498144, -0.58197158],
#     'dest': 'AVRILLE ARDENNE',
#     'ecart': 239,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:19+00:00',
#     'idarret': 672829,
#     'iddesserte': 269419030,
#     'idligne': 268435471,
#     'idparcours': 269419008,
#     'idvh': 268436469,
#     'mnemoarret': '2BROY',
#     'mnemoligne': 'A',
#     'nomarret': 'BOIS DU ROY',
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'novh': '1013',
#     'numarret': 31784,
#     'sv': 'A01',
#     'type': 'CITADIS',
#     'x': 380162,
#     'y': 2281698},
#    'geometry': {'coordinates': [-0.58197158, 47.498144], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '41cb4aaa75f8b10b0fbace742d407a6b97c1fd03'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 146,
#     'coordonnees': [47.4996, -0.58312727],
#     'dest': 'ANGERS ROSERAIE',
#     'ecart': 102,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:51+00:00',
#     'idarret': 672803,
#     'iddesserte': 269451525,
#     'idligne': 268435471,
#     'idparcours': 269451520,
#     'idvh': 268436473,
#     'mnemoarret': '1BROY',
#     'mnemoligne': 'A',
#     'nomarret': 'BOIS DU ROY',
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'novh': '1017',
#     'numarret': 32629,
#     'sv': 'A11',
#     'type': 'CITADIS',
#     'x': 380081,
#     'y': 2281863},
#    'geometry': {'coordinates': [-0.58312727, 47.4996], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'f5d83fb84acf66fbe7a5d9e742b97e7ddfd40cd4'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 347,
#     'coordonnees': [47.465126, -0.559469],
#     'dest': 'FENEU',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:25:00+00:00',
#     'idarret': 674195,
#     'iddesserte': 270600705,
#     'idligne': 268435489,
#     'idparcours': 270600704,
#     'idvh': 268442535,
#     'mnemoarret': 'GARESEMA',
#     'mnemoligne': '33',
#     'nomarret': 'GARES SEMARD SUB',
#     'nomligne': 'FENEU CANTENAY <> GARE',
#     'novh': '7079',
#     'numarret': 21525,
#     'sv': '3303',
#     'type': 'ARES',
#     'x': 381721,
#     'y': 2277967},
#    'geometry': {'coordinates': [-0.559469, 47.465126], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:20:18+00:00',
#    'recordid': '3d926e4869e3d2204e1a432b6926c8cc6d472c8a'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 16,
#     'coordonnees': [47.541122, -0.60943969],
#     'dest': 'MONTREUIL JUIGNE',
#     'ecart': 0,
#     'etat': 'TARR',
#     'harret': '2018-06-20T09:12:44+00:00',
#     'idarret': 672944,
#     'iddesserte': 268905259,
#     'idligne': 268435463,
#     'idparcours': 268905216,
#     'idvh': 268435893,
#     'mnemoarret': 'BENE-E',
#     'mnemoligne': '07',
#     'nomarret': 'BENE',
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'novh': '437',
#     'numarret': 27645,
#     'sv': '0721',
#     'type': 'OMNICITY',
#     'x': 378273,
#     'y': 2286550},
#    'geometry': {'coordinates': [-0.60943969, 47.541122], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:17:35+00:00',
#    'recordid': 'a6a2342aee1908680a1e3f0f9c6c10861fa59067'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 176,
#     'coordonnees': [47.478738, -0.52823901],
#     'dest': 'BELLE BEILLE',
#     'ecart': 223,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:17+00:00',
#     'idarret': 673777,
#     'iddesserte': 268545544,
#     'idligne': 268435457,
#     'idparcours': 268545536,
#     'idvh': 268436130,
#     'mnemoarret': 'THULEAU',
#     'mnemoligne': '01',
#     'nomarret': 'THULEAU',
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'novh': '674',
#     'numarret': 17278,
#     'sv': '0124',
#     'type': 'OMNIART',
#     'x': 384129,
#     'y': 2279393},
#    'geometry': {'coordinates': [-0.52823901, 47.478738], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '728b74266eadaea4a517423fdc4c9b600cf5e353'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 340,
#     'coordonnees': [47.460976, -0.54651519],
#     'dest': 'AVRILLE ADEZIERE',
#     'ecart': 458,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:07+00:00',
#     'idarret': 673654,
#     'iddesserte': 268641565,
#     'idligne': 268435459,
#     'idparcours': 268641536,
#     'idvh': 268436157,
#     'mnemoarret': 'RABELAI',
#     'mnemoligne': '03',
#     'nomarret': 'RABELAIS',
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'novh': '701',
#     'numarret': 819,
#     'sv': '0301',
#     'type': 'AGORA123456789ABCDEFART',
#     'x': 382680,
#     'y': 2277470},
#    'geometry': {'coordinates': [-0.54651519, 47.460976], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'c733fa262074908e8a48a5db2ed96f0bd883293c'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 284,
#     'coordonnees': [47.459409, -0.52113428],
#     'dest': 'ST AUBIN LA SALLE',
#     'ecart': -15,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:57+00:00',
#     'idarret': 673764,
#     'iddesserte': 269233421,
#     'idligne': 268435468,
#     'idparcours': 269233408,
#     'idvh': 268435888,
#     'mnemoarret': 'STLEONCB',
#     'mnemoligne': '12',
#     'nomarret': 'ST LEONARD',
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'novh': '432',
#     'numarret': 11495,
#     'sv': '1204',
#     'type': 'OMNICITY',
#     'x': 384586,
#     'y': 2277226},
#    'geometry': {'coordinates': [-0.52113428, 47.459409], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '8c5c08abc25ceba7789df1bbd064a405391fa2df'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 26,
#     'coordonnees': [47.485268, -0.53349007],
#     'dest': 'SCHWEITZER',
#     'ecart': 36,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:19+00:00',
#     'idarret': 673830,
#     'iddesserte': 269097770,
#     'idligne': 268435466,
#     'idparcours': 269097728,
#     'idvh': 268435897,
#     'mnemoarret': 'VOLTAI-E',
#     'mnemoligne': '10',
#     'nomarret': 'VOLTAIRE',
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'novh': '441',
#     'numarret': 11140,
#     'sv': '1004',
#     'type': 'OMNICITY',
#     'x': 383760,
#     'y': 2280133},
#    'geometry': {'coordinates': [-0.53349007, 47.485268], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'a1247a963a151e63fd05ad19fde1c5fcd369fd98'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 331,
#     'coordonnees': [47.472368, -0.55457929],
#     'dest': "LAC DE MAINE - L'HOIRIE",
#     'ecart': 328,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:26:06+00:00',
#     'idarret': 673620,
#     'iddesserte': 269164829,
#     'idligne': 268435467,
#     'idparcours': 269164800,
#     'idvh': 268435970,
#     'mnemoarret': 'POISSO-E',
#     'mnemoligne': '11',
#     'nomarret': 'POISSONNERIE',
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'novh': '514',
#     'numarret': 16364,
#     'sv': '1102',
#     'type': 'GX317',
#     'x': 382119,
#     'y': 2278758},
#    'geometry': {'coordinates': [-0.55457929, 47.472368], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '1c44ca5a778932347a25178acb8c887e48a98c69'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 124,
#     'coordonnees': [47.488387, -0.51763047],
#     'dest': 'EVENTARD par MONPLAISIR',
#     'ecart': 106,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:18+00:00',
#     'idarret': 673119,
#     'iddesserte': 269029402,
#     'idligne': 268435465,
#     'idparcours': 269029376,
#     'idvh': 268435974,
#     'mnemoarret': 'DEBUSS-E',
#     'mnemoligne': '09',
#     'nomarret': 'DEBUSSY',
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'novh': '518',
#     'numarret': 612,
#     'sv': '0906',
#     'type': 'GX317',
#     'x': 384967,
#     'y': 2280436},
#    'geometry': {'coordinates': [-0.51763047, 47.488387], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'd467dc7e7a1d17297a1285fd4ce40eb531a1882b'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 157,
#     'coordonnees': [47.453077, -0.54525173],
#     'dest': 'TRELAZE ST LEZIN',
#     'ecart': 603,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:59+00:00',
#     'idarret': 673537,
#     'iddesserte': 269131284,
#     'idligne': 268435466,
#     'idparcours': 269131264,
#     'idvh': 268435991,
#     'mnemoarret': 'MORELL-E',
#     'mnemoligne': '10',
#     'nomarret': 'MORELLERIE',
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'novh': '535',
#     'numarret': 16834,
#     'sv': '1009',
#     'type': 'GX 327',
#     'x': 382743,
#     'y': 2276589},
#    'geometry': {'coordinates': [-0.54525173, 47.453077], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '03d5d2418beebbb265eceab036b99c1e2fcbc82a'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 244,
#     'coordonnees': [47.488949, -0.56929024],
#     'dest': 'CIRCULAIRE SENS B',
#     'ecart': 131,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:58+00:00',
#     'idarret': 673592,
#     'iddesserte': 268807684,
#     'idligne': 268435461,
#     'idparcours': 268807680,
#     'idvh': 268435999,
#     'mnemoarret': 'PETIPANN',
#     'mnemoligne': '05',
#     'nomarret': 'PETITES PANNES',
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'novh': '543',
#     'numarret': 1322,
#     'sv': '0521',
#     'type': 'GX 327',
#     'x': 381079,
#     'y': 2280641},
#    'geometry': {'coordinates': [-0.56929024, 47.488949], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '183566835d3ff296e8ae815ad799eed75504ecbc'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 270,
#     'coordonnees': [47.465294, -0.55671725],
#     'dest': 'BELLE BEILLE',
#     'ecart': 529,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:09+00:00',
#     'idarret': 673233,
#     'iddesserte': 268545555,
#     'idligne': 268435457,
#     'idparcours': 268545536,
#     'idvh': 268436058,
#     'mnemoarret': 'GAREPA-E',
#     'mnemoligne': '01',
#     'nomarret': 'GARES PAPIN',
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'novh': '602',
#     'numarret': 715,
#     'sv': '0123',
#     'type': 'MAN City',
#     'x': 381929,
#     'y': 2277978},
#    'geometry': {'coordinates': [-0.55671725, 47.465294], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '25d7cc7cf7b2468813876206d33006beb4ecefa5'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 17,
#     'coordonnees': [47.48232, -0.5267986],
#     'dest': 'MONPLAISIR',
#     'ecart': 446,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:47+00:00',
#     'idarret': 673802,
#     'iddesserte': 268513059,
#     'idligne': 268435457,
#     'idparcours': 268513024,
#     'idvh': 268436065,
#     'mnemoarret': 'VAUGAR-E',
#     'mnemoligne': '01',
#     'nomarret': 'VAUGAREAU',
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'novh': '609',
#     'numarret': 1236,
#     'sv': '0102',
#     'type': 'MAN City',
#     'x': 384252,
#     'y': 2279787},
#    'geometry': {'coordinates': [-0.5267986, 47.48232], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'ef9ed2ba47ef35f349a711625a77488a3c741382'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 136,
#     'coordonnees': [47.478528, -0.56954475],
#     'dest': 'MURS ERIGNE',
#     'ecart': -123,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:36+00:00',
#     'idarret': 673151,
#     'iddesserte': 268674582,
#     'idligne': 268435459,
#     'idparcours': 268674560,
#     'idvh': 268436066,
#     'mnemoarret': 'DSCAZEAU',
#     'mnemoligne': '03',
#     'nomarret': 'DESCAZEAUX',
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'novh': '610',
#     'numarret': 24278,
#     'sv': '0321',
#     'type': 'MAN City',
#     'x': 381017,
#     'y': 2279484},
#    'geometry': {'coordinates': [-0.56954475, 47.478528], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '2fce171a2943ed93bdc50cb037542940828810f5'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 225,
#     'coordonnees': [47.468166, -0.55092645],
#     'dest': 'BELLE BEILLE',
#     'ecart': -21,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:54+00:00',
#     'idarret': 673749,
#     'iddesserte': 268545553,
#     'idligne': 268435457,
#     'idparcours': 268545536,
#     'idvh': 268436075,
#     'mnemoarret': 'STAUBI-E',
#     'mnemoligne': '01',
#     'nomarret': 'FOCH ST AUBIN',
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'novh': '619',
#     'numarret': 31700,
#     'sv': '0105',
#     'type': 'MAN City',
#     'x': 382377,
#     'y': 2278281},
#    'geometry': {'coordinates': [-0.55092645, 47.468166], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '1620d79e322a0e1e7267de6a3246c6d2e8d0a531'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 7,
#     'coordonnees': [47.472299, -0.59989743],
#     'dest': 'BEAUCOUZE  HAUTE ROCHE',
#     'ecart': 41,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:26:20+00:00',
#     'idarret': 673094,
#     'iddesserte': 268741672,
#     'idligne': 268435460,
#     'idparcours': 268741632,
#     'idvh': 268436131,
#     'mnemoarret': 'CNFPT',
#     'mnemoligne': '04',
#     'nomarret': 'C N F P T',
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'novh': '675',
#     'numarret': 22225,
#     'sv': '0403',
#     'type': 'OMNIART',
#     'x': 378705,
#     'y': 2278877},
#    'geometry': {'coordinates': [-0.59989743, 47.472299], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '31b621d7a932256f3844f32c315f3a643ef826dd'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 302,
#     'coordonnees': [47.469736, -0.56155159],
#     'dest': 'BOUCHEMAINE CENTRE',
#     'ecart': 418,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:27:17+00:00',
#     'idarret': 673223,
#     'iddesserte': 268873749,
#     'idligne': 268435462,
#     'idparcours': 268873728,
#     'idvh': 268436257,
#     'mnemoarret': 'FRONDM-E',
#     'mnemoligne': '06',
#     'nomarret': 'FRONT DE MAINE',
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'novh': '801',
#     'numarret': 13856,
#     'sv': '0606',
#     'type': 'OmniSTDE6',
#     'x': 381583,
#     'y': 2278485},
#    'geometry': {'coordinates': [-0.56155159, 47.469736], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'f48d83ae1fff87a101699f34fc3c268b8c3a139d'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 140,
#     'coordonnees': [47.466144, -0.5435562],
#     'dest': 'MOULIN MARCILLE PAR TRELA',
#     'ecart': 215,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:16+00:00',
#     'idarret': 673757,
#     'iddesserte': 269266966,
#     'idligne': 268435468,
#     'idparcours': 269266944,
#     'idvh': 268436271,
#     'mnemoarret': 'STJOS-E',
#     'mnemoligne': '12',
#     'nomarret': 'ST JOSEPH',
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'novh': '815',
#     'numarret': 14109,
#     'sv': '1210',
#     'type': 'OmniSTDE6',
#     'x': 382924,
#     'y': 2278036},
#    'geometry': {'coordinates': [-0.5435562, 47.466144], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'b96414f9cbe6797203811e2b9a4578f44c15f1d7'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 38,
#     'coordonnees': [47.470267, -0.54749607],
#     'dest': 'EVENTARD par MONPLAISIR',
#     'ecart': 29,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:27:02+00:00',
#     'idarret': 673490,
#     'iddesserte': 269029390,
#     'idligne': 268435465,
#     'idparcours': 269029376,
#     'idvh': 268436279,
#     'mnemoarret': 'MENDES-E',
#     'mnemoligne': '09',
#     'nomarret': 'MENDES FRANCE',
#     'nomligne': 'ESPACE ANJOU <> EVENTARD',
#     'novh': '823',
#     'numarret': 25308,
#     'sv': '0905',
#     'type': 'OmniSTDE6',
#     'x': 382644,
#     'y': 2278505},
#    'geometry': {'coordinates': [-0.54749607, 47.470267], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '6f5b7c2626ab8d00785f9b5b0750ae9b211b3048'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 329,
#     'coordonnees': [47.471119, -0.5516043],
#     'dest': 'AVRILLE ARDENNE',
#     'ecart': 140,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:59+00:00',
#     'idarret': 672843,
#     'iddesserte': 269419018,
#     'idligne': 268435471,
#     'idparcours': 269419008,
#     'idvh': 268436467,
#     'mnemoarret': '2RALL',
#     'mnemoligne': 'A',
#     'nomarret': 'RALLIEMENT',
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'novh': '1011',
#     'numarret': 22040,
#     'sv': 'A02',
#     'type': 'CITADIS',
#     'x': 382338,
#     'y': 2278611},
#    'geometry': {'coordinates': [-0.5516043, 47.471119], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '3cf229c9127002e1431e6cb4206074ab8aa6123b'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 5,
#     'coordonnees': [47.425362, -0.52352671],
#     'dest': 'HAUTE DE RECULEE',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:30:00+00:00',
#     'idarret': 673471,
#     'iddesserte': 268972289,
#     'idligne': 268435464,
#     'idparcours': 268972288,
#     'idvh': 268436258,
#     'mnemoarret': 'MAPTSCE',
#     'mnemoligne': '08',
#     'nomarret': 'MAIRIE PONTS DE CE',
#     'nomligne': 'PONTS CE <>  AQUAVITA H. RECULEE',
#     'novh': '802',
#     'numarret': 9963,
#     'sv': '0801',
#     'type': 'OmniSTDE6',
#     'x': 384268,
#     'y': 2273450},
#    'geometry': {'coordinates': [-0.52352671, 47.425362], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:33+00:00',
#    'recordid': '2b95f4212d5984812194c435ddf6d73e1896d6d1'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 148,
#     'coordonnees': [47.431874, -0.48519605],
#     'dest': 'SCHWEITZER',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:25:00+00:00',
#     'idarret': 673746,
#     'iddesserte': 269098241,
#     'idligne': 268435466,
#     'idparcours': 269098240,
#     'idvh': 268435966,
#     'mnemoarret': 'SORGES',
#     'mnemoligne': '10',
#     'nomarret': 'SORGES',
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'novh': '510',
#     'numarret': 27536,
#     'sv': '1006',
#     'type': 'GX317',
#     'x': 387184,
#     'y': 2274069},
#    'geometry': {'coordinates': [-0.48519605, 47.431874], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:16:54+00:00',
#    'recordid': '4661eb66fcf653e8bbfdd26d05364c5a7a3dedc1'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 227,
#     'coordonnees': [47.480655, -0.55504254],
#     'dest': 'MONTREUIL JUIGNE',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:29:00+00:00',
#     'idarret': 673298,
#     'iddesserte': 268905217,
#     'idligne': 268435463,
#     'idparcours': 268905216,
#     'idvh': 268435887,
#     'mnemoarret': 'HOPA8-C',
#     'mnemoligne': '07',
#     'nomarret': 'CHU - MATERNITE',
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'novh': '431',
#     'numarret': 27358,
#     'sv': '0724',
#     'type': 'OMNICITY',
#     'x': 382118,
#     'y': 2279680},
#    'geometry': {'coordinates': [-0.55504254, 47.480655], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:11:58+00:00',
#    'recordid': '434c91865230b6258c6af4026633df601646656a'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 0,
#     'coordonnees': [47.395415, -0.55576319],
#     'dest': 'AVRILLE ADEZIERE',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:27:00+00:00',
#     'idarret': 673543,
#     'iddesserte': 268641537,
#     'idligne': 268435459,
#     'idparcours': 268641536,
#     'idvh': 268436111,
#     'mnemoarret': 'MURSERIG',
#     'mnemoligne': '03',
#     'nomarret': 'MURS ERIGNE',
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'novh': '655',
#     'numarret': 22074,
#     'sv': '0303',
#     'type': 'OMNIART',
#     'x': 381715,
#     'y': 2270212},
#    'geometry': {'coordinates': [-0.55576319, 47.395415], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:18:16+00:00',
#    'recordid': '0d50fa76f49f94a767ab4b9876db53e33f377581'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 112,
#     'coordonnees': [47.472804, -0.48616995],
#     'dest': 'ST BARTHELEMY',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:37:00+00:00',
#     'idarret': 673721,
#     'iddesserte': 268746753,
#     'idligne': 268435460,
#     'idparcours': 268746752,
#     'idvh': 268435877,
#     'mnemoarret': 'SBARTHEL',
#     'mnemoligne': '04',
#     'nomarret': 'ST BARTH COLLEGE',
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'novh': '421',
#     'numarret': 11134,
#     'sv': '0411',
#     'type': 'OMNICITY',
#     'x': 387274,
#     'y': 2278619},
#    'geometry': {'coordinates': [-0.48616995, 47.472804], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:22:37+00:00',
#    'recordid': 'b9df0308777c39fdae5032c00c88bd7f9d66be65'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 286,
#     'coordonnees': [47.478642, -0.6056908],
#     'dest': 'MONPLAISIR',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:27:00+00:00',
#     'idarret': 673481,
#     'iddesserte': 268513025,
#     'idligne': 268435457,
#     'idparcours': 268513024,
#     'idvh': 268436141,
#     'mnemoarret': 'MATECHNO',
#     'mnemoligne': '01',
#     'nomarret': 'MAISON DE TECHNOPOLE',
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'novh': '685',
#     'numarret': 29466,
#     'sv': '0129',
#     'type': 'OmniArtE6',
#     'x': 378295,
#     'y': 2279598},
#    'geometry': {'coordinates': [-0.6056908, 47.478642], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:22:37+00:00',
#    'recordid': '9d0eb484fb4751db5ad61b489bd81e4951569728'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 308,
#     'coordonnees': [47.484534, -0.58307122],
#     'dest': 'AVRILLE ADEZIERE',
#     'ecart': 253,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:14+00:00',
#     'idarret': 673795,
#     'iddesserte': 268641581,
#     'idligne': 268435459,
#     'idparcours': 268641536,
#     'idvh': 268436123,
#     'mnemoarret': 'VALOR-E',
#     'mnemoligne': '03',
#     'nomarret': "VAL D'OR",
#     'nomligne': 'MURS ERIGNE <> ADEZIERE SALETTE',
#     'novh': '667',
#     'numarret': 32097,
#     'sv': '0322',
#     'type': 'OMNIART',
#     'x': 380023,
#     'y': 2280189},
#    'geometry': {'coordinates': [-0.58307122, 47.484534], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'a3e4af6dbc067a96b06e002818db571993f862a0'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 54,
#     'coordonnees': [47.475584, -0.53456123],
#     'dest': 'ST SYLVAIN',
#     'ecart': 105,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:59+00:00',
#     'idarret': 673447,
#     'iddesserte': 268578599,
#     'idligne': 268435458,
#     'idparcours': 268578560,
#     'idvh': 268436124,
#     'mnemoarret': 'LUTIN -E',
#     'mnemoligne': '02',
#     'nomarret': 'LUTIN',
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
# ...
#     'y': 2278600},
#    'geometry': {'coordinates': [-0.61084235, 47.469528], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'f08398155e95e20b46fcba30878938d505f69be8'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 82,
#     'coordonnees': [47.464913, -0.5579177],
#     'dest': 'ZI EST',
#     'ecart': 312,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:53+00:00',
#     'idarret': 673234,
#     'iddesserte': 268840745,
#     'idligne': 268435462,
#     'idparcours': 268840704,
#     'idvh': 268436277,
#     'mnemoarret': 'GAREPAPI',
#     'mnemoligne': '06',
#     'nomarret': 'GARES PAPIN',
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'novh': '821',
#     'numarret': 16316,
#     'sv': '0601',
#     'type': 'OmniSDTE6',
#     'x': 381837,
#     'y': 2277939},
#    'geometry': {'coordinates': [-0.5579177, 47.464913], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '161cd571ad2dc70fadfb2d47376533bad80809ca'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 291,
#     'coordonnees': [47.491459, -0.55313273],
#     'dest': 'AVRILLE ARDENNE',
#     'ecart': 35,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:26:15+00:00',
#     'idarret': 672835,
#     'iddesserte': 269419025,
#     'idligne': 268435471,
#     'idparcours': 269419008,
#     'idvh': 268436457,
#     'mnemoarret': '2HSAU',
#     'mnemoligne': 'A',
#     'nomarret': 'HAUTS DE ST AUBIN',
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'novh': '1001',
#     'numarret': 29280,
#     'sv': 'A03',
#     'type': 'CITADIS',
#     'x': 382306,
#     'y': 2280875},
#    'geometry': {'coordinates': [-0.55313273, 47.491459], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '1f0724e843448d3e4454ec7bf0f4ec5a1570ca5f'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 124,
#     'coordonnees': [47.474883, -0.5479319],
#     'dest': 'ZI TRELAZE PAR ST LEZIN',
#     'ecart': 207,
#     'etat': 'DEVP',
#     'harret': '2018-06-20T09:24:56+00:00',
#     'idarret': 673491,
#     'iddesserte': 269141000,
#     'idligne': 268435466,
#     'idparcours': 269140992,
#     'idvh': 268435892,
#     'mnemoarret': 'MENDESFR',
#     'mnemoligne': '10',
#     'nomarret': 'MENDES FRANCE',
#     'nomligne': 'ST LEZIN SORGES <> SCHWEITZER',
#     'novh': '436',
#     'numarret': 10353,
#     'sv': '1008',
#     'type': 'OMNICITY',
#     'x': 382630,
#     'y': 2279019},
#    'geometry': {'coordinates': [-0.5479319, 47.474883], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '056dfb2f15e4ef1d3945b94183f2519279d3b11d'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 104,
#     'coordonnees': [47.490847, -0.56177124],
#     'dest': 'CIRCULAIRE SENS A',
#     'ecart': 253,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:59+00:00',
#     'idarret': 674376,
#     'iddesserte': 268774147,
#     'idligne': 268435461,
#     'idparcours': 268774144,
#     'idvh': 268435981,
#     'mnemoarret': 'FRATE-E',
#     'mnemoligne': '05',
#     'nomarret': 'FRATERNITE',
#     'nomligne': 'CIRCULAIRE VERNEAU GARE EUROPE',
#     'novh': '525',
#     'numarret': 71441,
#     'sv': '0526',
#     'type': 'GX 327',
#     'x': 381653,
#     'y': 2280831},
#    'geometry': {'coordinates': [-0.56177124, 47.490847], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '2de14308c4daf6f641514d9dfdeb1987908cb063'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 310,
#     'coordonnees': [47.463042, -0.61526184],
#     'dest': "LAC DE MAINE - L'HOIRIE",
#     'ecart': 416,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:47+00:00',
#     'idarret': 672874,
#     'iddesserte': 269164841,
#     'idligne': 268435467,
#     'idparcours': 269164800,
#     'idvh': 268435997,
#     'mnemoarret': 'AQUITA-E',
#     'mnemoligne': '11',
#     'nomarret': "ALIENOR D'AQUITAINE",
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'novh': '541',
#     'numarret': 14482,
#     'sv': '1121',
#     'type': 'GX 327',
#     'x': 377509,
#     'y': 2277892},
#    'geometry': {'coordinates': [-0.61526184, 47.463042], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'e5812a9ccb0bd902d9a22e36d4fe05cd190e17cd'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 190,
#     'coordonnees': [47.4664, -0.55928606],
#     'dest': 'ST BARTHELEMY',
#     'ecart': 216,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:15+00:00',
#     'idarret': 673247,
#     'iddesserte': 268706593,
#     'idligne': 268435460,
#     'idparcours': 268706560,
#     'idvh': 268436069,
#     'mnemoarret': 'GBREM-E',
#     'mnemoligne': '04',
#     'nomarret': 'GARES BREMONT',
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'novh': '613',
#     'numarret': 25296,
#     'sv': '0406',
#     'type': 'MAN City',
#     'x': 381740,
#     'y': 2278108},
#    'geometry': {'coordinates': [-0.55928606, 47.4664], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'fca68a46e97fe6b917c4be714f2f90824a694bd4'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 234,
#     'coordonnees': [47.486, -0.51480697],
#     'dest': 'TRELAZE QUANTINIERE',
#     'ecart': 40,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:19+00:00',
#     'idarret': 673745,
#     'iddesserte': 268611089,
#     'idligne': 268435458,
#     'idparcours': 268611072,
#     'idvh': 268436119,
#     'mnemoarret': 'SOLELEVA',
#     'mnemoligne': '02',
#     'nomarret': 'SOLEIL LEVANT',
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'novh': '663',
#     'numarret': 25379,
#     'sv': '0207',
#     'type': 'OMNIART',
#     'x': 385170,
#     'y': 2280163},
#    'geometry': {'coordinates': [-0.51480697, 47.486], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '37ba40bfbe41e79b0b5dd11a93bc0df89426ed0e'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 112,
#     'coordonnees': [47.472646, -0.48600228],
#     'dest': "BEAUCOUZE L'ATOLL",
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:25:00+00:00',
#     'idarret': 673721,
#     'iddesserte': 268739073,
#     'idligne': 268435460,
#     'idparcours': 268739072,
#     'idvh': 268436125,
#     'mnemoarret': 'SBARTHEL',
#     'mnemoligne': '04',
#     'nomarret': 'ST BARTH COLLEGE',
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'novh': '669',
#     'numarret': 11134,
#     'sv': '0402',
#     'type': 'OMNIART',
#     'x': 387286,
#     'y': 2278601},
#    'geometry': {'coordinates': [-0.48600228, 47.472646], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '3dcde40073a7428c513a255b9f510d94917b4c08'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 105,
#     'coordonnees': [47.474474, -0.52009745],
#     'dest': 'ZI EST',
#     'ecart': 509,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:48+00:00',
#     'idarret': 673328,
#     'iddesserte': 268840239,
#     'idligne': 268435462,
#     'idparcours': 268840192,
#     'idvh': 268436268,
#     'mnemoarret': 'ISORET-E',
#     'mnemoligne': '06',
#     'nomarret': 'ISORET',
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'novh': '812',
#     'numarret': 23628,
#     'sv': '0604',
#     'type': 'OmniSTDE6',
#     'x': 384725,
#     'y': 2278897},
#    'geometry': {'coordinates': [-0.52009745, 47.474474], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '83056f92cee02dac088d72a7a7abe3523929d5f0'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 261,
#     'coordonnees': [47.485896, -0.51245114],
#     'dest': 'TRELAZE QUANTINIERE',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:35:00+00:00',
#     'idarret': 672912,
#     'iddesserte': 268611585,
#     'idligne': 268435458,
#     'idparcours': 268611584,
#     'idvh': 268436129,
#     'mnemoarret': 'BANCSTMA',
#     'mnemoligne': '02',
#     'nomarret': 'BANCHAIS',
#     'nomligne': 'ST SYLVAIN BANCHAIS <>TRELAZE',
#     'novh': '673',
#     'numarret': 20610,
#     'sv': '0211',
#     'type': 'OMNIART',
#     'x': 385347,
#     'y': 2280145},
#    'geometry': {'coordinates': [-0.51245114, 47.485896], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:16+00:00',
#    'recordid': 'bdf823031297320af34641d34d5b600511bb478e'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 67,
#     'coordonnees': [47.528043, -0.59525328],
#     'dest': 'MONTREUIL JUIGNE',
#     'ecart': -27,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:57+00:00',
#     'idarret': 672902,
#     'iddesserte': 268905242,
#     'idligne': 268435463,
#     'idparcours': 268905216,
#     'idvh': 268435885,
#     'mnemoarret': 'AVENEU-E',
#     'mnemoligne': '07',
#     'nomarret': 'AVENUE DE L EUROPE',
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'novh': '429',
#     'numarret': 3623,
#     'sv': '0723',
#     'type': 'OMNICITY',
#     'x': 379286,
#     'y': 2285057},
#    'geometry': {'coordinates': [-0.59525328, 47.528043], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '90fa36f09cc7d440510ec33099b584ee2dfc41d7'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 216,
#     'coordonnees': [47.484685, -0.5126519],
#     'dest': 'VERNUSSON PAR TRELAZE',
#     'ecart': 40,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:26+00:00',
#     'idarret': 673047,
#     'iddesserte': 269266438,
#     'idligne': 268435468,
#     'idparcours': 269266432,
#     'idvh': 268435906,
#     'mnemoarret': 'CHATELAI',
#     'mnemoligne': '12',
#     'nomarret': 'CHATELAIN',
#     'nomligne': 'M-MARCILLE <> ST AUBIN LA SALLE',
#     'novh': '450',
#     'numarret': 23220,
#     'sv': '1203',
#     'type': 'OMNICITY',
#     'x': 385327,
#     'y': 2280011},
#    'geometry': {'coordinates': [-0.5126519, 47.484685], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '1bc03cef14e3cdfd4ecd101f81d25c7dbef6d1c4'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 103,
#     'coordonnees': [47.53002, -0.62089213],
#     'dest': 'CHU - HOPITAL',
#     'ecart': 0,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:55+00:00',
#     'idarret': 674512,
#     'iddesserte': 268939785,
#     'idligne': 268435463,
#     'idparcours': 268939776,
#     'idvh': 268435986,
#     'mnemoarret': 'CHPEGUY',
#     'mnemoligne': '07',
#     'nomarret': 'CHARLES PEGUY',
#     'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#     'novh': '530',
#     'numarret': 855516,
#     'sv': '0728',
#     'type': 'GX 327',
#     'x': 377365,
#     'y': 2285349},
#    'geometry': {'coordinates': [-0.62089213, 47.53002], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'd110e1c9e41eb28cc65d5fb9906627c0ca61e895'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 287,
#     'coordonnees': [47.480415, -0.60286772],
#     'dest': 'BELLE BEILLE',
#     'ecart': 24,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:54+00:00',
#     'idarret': 673312,
#     'iddesserte': 268545573,
#     'idligne': 268435457,
#     'idparcours': 268545536,
#     'idvh': 268436067,
#     'mnemoarret': 'I U T -E',
#     'mnemoligne': '01',
#     'nomarret': 'I U T',
#     'nomligne': 'BELLE BEILLE <> MONPLAISIR',
#     'novh': '611',
#     'numarret': 31087,
#     'sv': '0122',
#     'type': 'MAN City',
#     'x': 378515,
#     'y': 2279787},
#    'geometry': {'coordinates': [-0.60286772, 47.480415], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '970584f6ee3dc808db238005d8da0cac59de5961'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 8,
#     'coordonnees': [47.480959, -0.63200251],
#     'dest': "BEAUCOUZE L'ATOLL",
#     'ecart': 206,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:24:54+00:00',
#     'idarret': 674284,
#     'iddesserte': 268739129,
#     'idligne': 268435460,
#     'idparcours': 268739072,
#     'idvh': 268436074,
#     'mnemoarret': 'ECHATS-E',
#     'mnemoligne': '04',
#     'nomarret': 'ECHATS',
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'novh': '618',
#     'numarret': 30592,
#     'sv': '0410',
#     'type': 'MAN City',
#     'x': 376323,
#     'y': 2279930},
#    'geometry': {'coordinates': [-0.63200251, 47.480959], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'a777f1ace4019b5f775a24a70db74c8a946649ce'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 314,
#     'coordonnees': [47.472036, -0.62967306],
#     'dest': 'ST BARTHELEMY',
#     'ecart': 38,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:01+00:00',
#     'idarret': 673603,
#     'iddesserte': 268706563,
#     'idligne': 268435460,
#     'idparcours': 268706560,
#     'idvh': 268436142,
#     'mnemoarret': 'PINSONS',
#     'mnemoligne': '04',
#     'nomarret': 'PINSONS',
#     'nomligne': 'BEAUCOUZE <> ST BARTHELEMY',
#     'novh': '686',
#     'numarret': 23478,
#     'sv': '0422',
#     'type': 'OmniArtE6',
#     'x': 376461,
#     'y': 2278932},
#    'geometry': {'coordinates': [-0.62967306, 47.472036], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '3ad238cd9a5428b65f240fab9f26c0ecd34e4c3b'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 33,
#     'coordonnees': [47.466005, -0.59465237],
#     'dest': "CLINIQUE DE L'ANJOU",
#     'ecart': 121,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:20+00:00',
#     'idarret': 673249,
#     'iddesserte': 269198350,
#     'idligne': 268435467,
#     'idparcours': 269198336,
#     'idvh': 268436272,
#     'mnemoarret': 'GDMAINE',
#     'mnemoligne': '11',
#     'nomarret': 'GRAND MAINE',
#     'nomligne': 'LAC MAINE <> STE GEMMES CL ANJOU',
#     'novh': '816',
#     'numarret': 14612,
#     'sv': '1104',
#     'type': 'OmniSTDE6',
#     'x': 379074,
#     'y': 2278163},
#    'geometry': {'coordinates': [-0.59465237, 47.466005], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '6898f9644086f005a620ca7f8541875967116336'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 292,
#     'coordonnees': [47.472125, -0.54082642],
#     'dest': 'BOUCHEMAINE CHANTOURTEAU',
#     'ecart': 36,
#     'etat': 'LIGN',
#     'harret': '2018-06-20T09:25:14+00:00',
#     'idarret': 674352,
#     'iddesserte': 268874253,
#     'idligne': 268435462,
#     'idparcours': 268874240,
#     'idvh': 268436276,
#     'mnemoarret': 'CLEMOINE',
#     'mnemoligne': '06',
#     'nomarret': 'C. LEMOINE',
#     'nomligne': 'BOUCHEMAINE <> Z I  EST',
#     'novh': '820',
#     'numarret': 54191,
#     'sv': '0603',
#     'type': 'OmniSTDE6',
#     'x': 383154,
#     'y': 2278693},
#    'geometry': {'coordinates': [-0.54082642, 47.472125], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': '6bc00b133c0eed3ca8506f4da939cd3aa85f0040'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 157,
#     'coordonnees': [47.604481, -0.70224244],
#     'dest': 'GARES  SNCF',
#     'ecart': 0,
#     'etat': 'HLPS',
#     'harret': '2018-06-20T09:29:00+00:00',
#     'idarret': 673881,
#     'iddesserte': 271024897,
#     'idligne': 268435495,
#     'idparcours': 271024896,
#     'idvh': 268443566,
#     'mnemoarret': 'BOUVET',
#     'mnemoligne': '39',
#     'nomarret': 'BOUVET',
#     'nomligne': 'LA MEMBROLLE <> GARE',
#     'novh': '8110',
#     'numarret': 3637,
#     'sv': '3914',
#     'type': 'INTOURO',
#     'x': 371564,
#     'y': 2293855},
#    'geometry': {'coordinates': [-0.70224244, 47.604481], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:56+00:00',
#    'recordid': 'a1053514a1380f39223659bcbe98957127d66914'},
#   {'datasetid': 'bus-tram-position-tr',
#    'fields': {'cap': 44,
#     'coordonnees': [47.443829, -0.55410549],
#     'dest': 'AVRILLE ARDENNE',
#     'ecart': 0,
#     'etat': 'TDEP',
#     'harret': '2018-06-20T09:27:00+00:00',
#     'idarret': 672824,
#     'iddesserte': 269419009,
#     'idligne': 268435471,
#     'idparcours': 269419008,
#     'idvh': 268436465,
#     'mnemoarret': '2ANRO',
#     'mnemoligne': 'A',
#     'nomarret': 'ANGERS - ROSERAIE',
#     'nomligne': 'ARDENNE <> ROSERAIE',
#     'novh': '1009',
#     'numarret': 32091,
#     'sv': 'A04',
#     'type': 'CITADIS',
#     'x': 382038,
#     'y': 2275586},
#    'geometry': {'coordinates': [-0.55410549, 47.443829], 'type': 'Point'},
#    'record_timestamp': '2018-06-20T09:24:33+00:00',
#    'recordid': '480c257c4a57c1a8d6db8aec5735b24d657699a8'}]}

# %% [markdown]
# # Remplissage de DataFrame

# %% [markdown]
# On peut construire une `DataFrame` directement à partir d'un "dictionnaires de colonnes".

# %%
dd = g.json()['records']

# %%
dd[0]
# Out:
# {'datasetid': 'bus-tram-position-tr',
#  'fields': {'cap': 155,
#   'coordonnees': [47.504063, -0.58675933],
#   'dest': 'CHU - HOPITAL',
#   'ecart': 126,
#   'etat': 'LIGN',
#   'harret': '2018-06-20T09:25:33+00:00',
#   'idarret': 672852,
#   'iddesserte': 268939803,
#   'idligne': 268435463,
#   'idparcours': 268939776,
#   'idvh': 268435884,
#   'mnemoarret': 'ACAS-7C',
#   'mnemoligne': '07',
#   'nomarret': 'ACACIAS',
#   'nomligne': 'HOPITAL <> MONTREUIL JUIGNE',
#   'novh': '428',
#   'numarret': 9581,
#   'sv': '0725',
#   'type': 'OMNICITY',
#   'x': 379826,
#   'y': 2282369},
#  'geometry': {'coordinates': [-0.58675933, 47.504063], 'type': 'Point'},
#  'record_timestamp': '2018-06-20T09:24:56+00:00',
#  'recordid': '1fd516059c0bf544c7241ec3ee006cfe9b15987e'}

# %%
#Arret
id_arret = [elem['fields']['idarret'] for elem in dd]
nom_arret = [elem['fields']['nomarret'] for elem in dd]
mne_arret = [elem['fields']['mnemoarret'] for elem in dd]

arret = pd.DataFrame({
    'id_arret': id_arret,
    'nom_arret': nom_arret,
    'mne_arret': mne_arret
})

#arret.info()

arret
# Out:
#      id_arret mne_arret             nom_arret
# 0      672852   ACAS-7C               ACACIAS
# 1      672949  BICHO.-E                BICHON
# 2      673827   VIVIERS               VIVIERS
# 3      673591  PETIPA-E        PETITES PANNES
# 4      673245  GAUBOUR5             GAUBOURGS
# 5      674341  VERNEA-E                AURIOL
# 6      672880    ARCEAU                ARCEAU
# 7      673514  MONPRO-E             MONPROFIT
# 8      673498  MILLOT-E            SAUMUROISE
# 9      673027   CEZAN-E               CEZANNE
# 10     673574  PATNOIRE             PATINOIRE
# 11     673205  FO-LOR-R     FOCH MAISON BLEUE
# 12     673242   GAUBERT               GAUBERT
# 13     672806     1FMBL     FOCHMAISONBLEUEv1
# 14     673542  MOULINMA       MOULIN MARCILLE
# 15     672971  BOUCHE-E           BOUCHEMAINE
# 16     673181  ESPACEAN          ESPACE ANJOU
# 17     673768  STSYLVAI            ST SYLVAIN
# 18     674393  P-JBOUIN    PISCINE JEAN BOUIN
# 19     673512  MONPLAIS            MONPLAISIR
# 20     673718   SALETTE       AVRILLE SALETTE
# 21     673133  DEPOT SD  SORTIE DEPOT ST BART
# 22     674395   P-ROSER      PISCINE ROSERAIE
# 23     672932  BEDIER-E                BEDIER
# 24     673393  LECHEN-E              LE CHENE
# 25     672959   BLERIOT               BLERIOT
# 26     672954  BIRGTE-E                 BIRGE
# 27     673519  MONTCA-E            MONTCASSIN
# 28     673821  VILLECHI            VILLECHIEN
# 29     673060  CHOUTE-E              CHOUTEAU
# ..        ...       ...                   ...
# 76     672928  BEAUREPA           BEAUREPAIRE
# 77     673457  MAETUDIA             I S T I A
# 78     673414  LEOLAGRA          LEO LAGRANGE
# 79     673416  LESGARES             LES GARES
# 80     674260  TRELA AR               TRELAZE
# 81     673171  EGLTRELA     EGLISE DE TRELAZE
# 82     673233  GAREPA-E           GARES PAPIN
# 83     673177     ESA-E                   ESA
# 84     673594   PETPORT            PETIT PORT
# 85     673337  JEAN M-E           JEAN MONNET
# 86     673234  GAREPAPI           GARES PAPIN
# 87     672835     2HSAU     HAUTS DE ST AUBIN
# 88     673491  MENDESFR         MENDES FRANCE
# 89     674376   FRATE-E            FRATERNITE
# 90     672874  AQUITA-E   ALIENOR D'AQUITAINE
# 91     673247   GBREM-E         GARES BREMONT
# 92     673745  SOLELEVA         SOLEIL LEVANT
# 93     673721  SBARTHEL      ST BARTH COLLEGE
# 94     673328  ISORET-E                ISORET
# 95     672912  BANCSTMA              BANCHAIS
# 96     672902  AVENEU-E    AVENUE DE L EUROPE
# 97     673047  CHATELAI             CHATELAIN
# 98     674512   CHPEGUY         CHARLES PEGUY
# 99     673312  I U T -E                 I U T
# 100    674284  ECHATS-E                ECHATS
# 101    673603   PINSONS               PINSONS
# 102    673249   GDMAINE           GRAND MAINE
# 103    674352  CLEMOINE            C. LEMOINE
# 104    673881    BOUVET                BOUVET
# 105    672824     2ANRO     ANGERS - ROSERAIE
#
# [106 rows x 3 columns]

# %%
#Bus
id_vh = [elem['fields']['idvh'] for elem in dd]
type_vh = [elem['fields']['type'] for elem in dd]
etat_vh = [elem['fields']['etat'] for elem in dd]

bus = pd.DataFrame({
    'id_vh': id_vh,
    'type_vh': type_vh,
    'etat_vh': etat_vh
})

#bus.info()

bus
# Out:
#     etat_vh      id_vh                  type_vh
# 0      LIGN  268435884                 OMNICITY
# 1      LIGN  268435899                 OMNICITY
# 2      LIGN  268435910                 OMNICITY
# 3      LIGN  268435913                 OMNICITY
# 4      LIGN  268435987                   GX 327
# 5      LIGN  268435994                   GX 327
# 6      LIGN  268436057                 MAN City
# 7      LIGN  268436070                 MAN City
# 8      LIGN  268436107                  OMNIART
# 9      LIGN  268436110                  OMNIART
# 10     LIGN  268436120                  OMNIART
# 11     LIGN  268436126                  OMNIART
# 12     LIGN  268436145                OmniArtE6
# 13     LIGN  268436461                  CITADIS
# 14     TDEP  268435909                 OMNICITY
# 15     LIGN  268436270                OmniSTDE6
# 16     TDEP  268435965                    GX317
# 17     TDEP  268436059                 MAN City
# 18     TDEP  268435879                 OMNICITY
# 19     TDEP  268436072                 MAN City
# 20     TDEP  268436079                 MAN City
# 21     HLPS  268435982                   GX 327
# 22     LIGN  268435880                 OMNICITY
# 23     LIGN  268435889                 OMNICITY
# 24     LIGN  268435912                 OMNICITY
# 25     LIGN  268435917                 OMNICITY
# 26     LIGN  268435919                 OMNICITY
# 27     LIGN  268435995                   GX 327
# 28     LIGN  268435996                   GX 327
# 29     LIGN  268436116                  OMNIART
# ..      ...        ...                      ...
# 76     LIGN  268436060                 MAN City
# 77     LIGN  268436063                 MAN City
# 78     LIGN  268436071                 MAN City
# 79     LIGN  268436077                 MAN City
# 80     TDEP  268436108                  OMNIART
# 81     LIGN  268436115                  OMNIART
# 82     LIGN  268436118                  OMNIART
# 83     LIGN  268436162  AGORA123456789ABCDEFART
# 84     LIGN  268436269                OmniSTDE6
# 85     DEVP  268436275                OmniSTDE6
# 86     LIGN  268436277                OmniSDTE6
# 87     LIGN  268436457                  CITADIS
# 88     DEVP  268435892                 OMNICITY
# 89     LIGN  268435981                   GX 327
# 90     LIGN  268435997                   GX 327
# 91     LIGN  268436069                 MAN City
# 92     LIGN  268436119                  OMNIART
# 93     TDEP  268436125                  OMNIART
# 94     LIGN  268436268                OmniSTDE6
# 95     TDEP  268436129                  OMNIART
# 96     LIGN  268435885                 OMNICITY
# 97     LIGN  268435906                 OMNICITY
# 98     LIGN  268435986                   GX 327
# 99     LIGN  268436067                 MAN City
# 100    LIGN  268436074                 MAN City
# 101    LIGN  268436142                OmniArtE6
# 102    LIGN  268436272                OmniSTDE6
# 103    LIGN  268436276                OmniSTDE6
# 104    HLPS  268443566                  INTOURO
# 105    TDEP  268436465                  CITADIS
#
# [106 rows x 3 columns]

# %%
#Ligne
id_ligne = [elem['fields']['idligne'] for elem in dd]
nom_ligne = [elem['fields']['nomligne'] for elem in dd]
mne_ligne = [elem['fields']['mnemoligne'] for elem in dd]

ligne = pd.DataFrame({
    'id_ligne': id_arret,
    'nom_ligne': nom_ligne,
    'mne_ligne': mne_ligne
})

#ligne.info()

ligne
# Out:
#      id_ligne mne_ligne                         nom_ligne
# 0      672852        07       HOPITAL <> MONTREUIL JUIGNE
# 1      672949        08  PONTS CE <>  AQUAVITA H. RECULEE
# 2      673827        08  PONTS CE <>  AQUAVITA H. RECULEE
# 3      673591        05    CIRCULAIRE VERNEAU GARE EUROPE
# 4      673245        05    CIRCULAIRE VERNEAU GARE EUROPE
# 5      674341        05    CIRCULAIRE VERNEAU GARE EUROPE
# 6      672880        04        BEAUCOUZE <> ST BARTHELEMY
# 7      673514        01        BELLE BEILLE <> MONPLAISIR
# 8      673498        02     ST SYLVAIN BANCHAIS <>TRELAZE
# 9      673027        04        BEAUCOUZE <> ST BARTHELEMY
# 10     673574        02     ST SYLVAIN BANCHAIS <>TRELAZE
# 11     673205        02     ST SYLVAIN BANCHAIS <>TRELAZE
# 12     673242        04        BEAUCOUZE <> ST BARTHELEMY
# 13     672806         A               ARDENNE <> ROSERAIE
# 14     673542        12   M-MARCILLE <> ST AUBIN LA SALLE
# 15     672971        06           BOUCHEMAINE <> Z I  EST
# 16     673181        09          ESPACE ANJOU <> EVENTARD
# 17     673768        02     ST SYLVAIN BANCHAIS <>TRELAZE
# 18     674393       534                Piscine JEAN-BOUIN
# 19     673512        01        BELLE BEILLE <> MONPLAISIR
# 20     673718        03   MURS ERIGNE <> ADEZIERE SALETTE
# 21     673133        06           BOUCHEMAINE <> Z I  EST
# 22     674395       533                  Piscine ROSERAIE
# 23     672932        11  LAC MAINE <> STE GEMMES CL ANJOU
# 24     673393        11  LAC MAINE <> STE GEMMES CL ANJOU
# 25     672959        08  PONTS CE <>  AQUAVITA H. RECULEE
# 26     672954        12   M-MARCILLE <> ST AUBIN LA SALLE
# 27     673519        05    CIRCULAIRE VERNEAU GARE EUROPE
# 28     673821        05    CIRCULAIRE VERNEAU GARE EUROPE
# 29     673060        02     ST SYLVAIN BANCHAIS <>TRELAZE
# ..        ...       ...                               ...
# 76     672928        01        BELLE BEILLE <> MONPLAISIR
# 77     673457        01        BELLE BEILLE <> MONPLAISIR
# 78     673414        02     ST SYLVAIN BANCHAIS <>TRELAZE
# 79     673416        01        BELLE BEILLE <> MONPLAISIR
# 80     674260        02     ST SYLVAIN BANCHAIS <>TRELAZE
# 81     673171        02     ST SYLVAIN BANCHAIS <>TRELAZE
# 82     673233        04        BEAUCOUZE <> ST BARTHELEMY
# 83     673177        03   MURS ERIGNE <> ADEZIERE SALETTE
# 84     673594        06           BOUCHEMAINE <> Z I  EST
# 85     673337        06           BOUCHEMAINE <> Z I  EST
# 86     673234        06           BOUCHEMAINE <> Z I  EST
# 87     672835         A               ARDENNE <> ROSERAIE
# 88     673491        10     ST LEZIN SORGES <> SCHWEITZER
# 89     674376        05    CIRCULAIRE VERNEAU GARE EUROPE
# 90     672874        11  LAC MAINE <> STE GEMMES CL ANJOU
# 91     673247        04        BEAUCOUZE <> ST BARTHELEMY
# 92     673745        02     ST SYLVAIN BANCHAIS <>TRELAZE
# 93     673721        04        BEAUCOUZE <> ST BARTHELEMY
# 94     673328        06           BOUCHEMAINE <> Z I  EST
# 95     672912        02     ST SYLVAIN BANCHAIS <>TRELAZE
# 96     672902        07       HOPITAL <> MONTREUIL JUIGNE
# 97     673047        12   M-MARCILLE <> ST AUBIN LA SALLE
# 98     674512        07       HOPITAL <> MONTREUIL JUIGNE
# 99     673312        01        BELLE BEILLE <> MONPLAISIR
# 100    674284        04        BEAUCOUZE <> ST BARTHELEMY
# 101    673603        04        BEAUCOUZE <> ST BARTHELEMY
# 102    673249        11  LAC MAINE <> STE GEMMES CL ANJOU
# 103    674352        06           BOUCHEMAINE <> Z I  EST
# 104    673881        39              LA MEMBROLLE <> GARE
# 105    672824         A               ARDENNE <> ROSERAIE
#
# [106 rows x 3 columns]

# %%
#Trajet
id_bus = [elem['fields']['idvh'] for elem in dd]
id_ligne = [elem['fields']['idligne'] for elem in dd]
latitude = [elem['fields']['coordonnees'][0] for elem in dd]
longitude = [elem['fields']['coordonnees'][1] for elem in dd]

trajet = pd.DataFrame({
    'id_bus': id_bus,
    'id_ligne': id_ligne,
    'latitude': latitude,
    'longitude': longitude
})

#trajet.info()

trajet
# Out:
#         id_bus   id_ligne   latitude  longitude
# 0    268435884  268435463  47.504063  -0.586759
# 1    268435899  268435464  47.478688  -0.564973
# 2    268435910  268435464  47.451116  -0.533999
# 3    268435913  268435461  47.487846  -0.572337
# 4    268435987  268435461  47.451319  -0.571670
# 5    268435994  268435461  47.491421  -0.565109
# 6    268436057  268435460  47.470633  -0.518206
# 7    268436070  268435457  47.474476  -0.565288
# 8    268436107  268435458  47.456899  -0.531975
# 9    268436110  268435460  47.468693  -0.492695
# 10   268436120  268435458  47.464558  -0.548342
# 11   268436126  268435458  47.469677  -0.548792
# 12   268436145  268435460  47.475512  -0.599544
# 13   268436461  268435471  47.469037  -0.549553
# 14   268435909  268435468  47.433763  -0.500723
# 15   268436270  268435462  47.422079  -0.610619
# 16   268435965  268435465  47.468240  -0.526161
# 17   268436059  268435458  47.512809  -0.470690
# 18   268435879  268435514  47.458785  -0.532873
# 19   268436072  268435457  47.491111  -0.528334
# 20   268436079  268435459  47.512522  -0.586812
# 21   268435982  268435462  47.475202  -0.492643
# 22   268435880  268435513  47.444001  -0.563761
# 23   268435889  268435467  47.453281  -0.553318
# 24   268435912  268435467  47.420651  -0.577424
# 25   268435917  268435464  47.487522  -0.563343
# 26   268435919  268435468  47.474780  -0.519769
# 27   268435995  268435461  47.446704  -0.570105
# 28   268435996  268435461  47.465584  -0.519621
# 29   268436116  268435458  47.446760  -0.499253
# ..         ...        ...        ...        ...
# 76   268436060  268435457  47.475279  -0.562729
# 77   268436063  268435457  47.480508  -0.594920
# 78   268436071  268435458  47.447868  -0.508388
# 79   268436077  268435457  47.465022  -0.556782
# 80   268436108  268435458  47.459953  -0.475708
# 81   268436115  268435458  47.445720  -0.462471
# 82   268436118  268435460  47.467226  -0.552163
# 83   268436162  268435459  47.459042  -0.545362
# 84   268436269  268435462  47.425759  -0.609629
# 85   268436275  268435462  47.469528  -0.610842
# 86   268436277  268435462  47.464913  -0.557918
# 87   268436457  268435471  47.491459  -0.553133
# 88   268435892  268435466  47.474883  -0.547932
# 89   268435981  268435461  47.490847  -0.561771
# 90   268435997  268435467  47.463042  -0.615262
# 91   268436069  268435460  47.466400  -0.559286
# 92   268436119  268435458  47.486000  -0.514807
# 93   268436125  268435460  47.472646  -0.486002
# 94   268436268  268435462  47.474474  -0.520097
# 95   268436129  268435458  47.485896  -0.512451
# 96   268435885  268435463  47.528043  -0.595253
# 97   268435906  268435468  47.484685  -0.512652
# 98   268435986  268435463  47.530020  -0.620892
# 99   268436067  268435457  47.480415  -0.602868
# 100  268436074  268435460  47.480959  -0.632003
# 101  268436142  268435460  47.472036  -0.629673
# 102  268436272  268435467  47.466005  -0.594652
# 103  268436276  268435462  47.472125  -0.540826
# 104  268443566  268435495  47.604481  -0.702242
# 105  268436465  268435471  47.443829  -0.554105
#
# [106 rows x 4 columns]

# %%
#Etape
id_arret = [elem['fields']['idarret'] for elem in dd]
harret = [elem['fields']['harret'] for elem in dd]
record_timestamp = [elem['record_timestamp'] for elem in dd]
ecart = [elem['fields']['ecart'] for elem in dd]

etape = pd.DataFrame({
    'id_arret': id_arret,
    'heure_theorique': harret,
    'ecart': ecart,
    'record_timestamp': record_timestamp
})

etape['record_timestamp'] = pd.to_datetime(etape['record_timestamp'])

def transfo(row):
    return row['record_timestamp'] + dt.timedelta(seconds=row['ecart'])
etape['heure_estime'] = etape.apply(transfo, axis='columns')

#etape.info()

etape
# Out:
#      ecart            heure_theorique  id_arret    record_timestamp  \
# 0      126  2018-06-20T09:25:33+00:00    672852 2018-06-20 09:24:56
# 1       27  2018-06-20T09:25:02+00:00    672949 2018-06-20 09:24:56
# 2     -103  2018-06-20T09:25:06+00:00    673827 2018-06-20 09:24:56
# 3      -15  2018-06-20T09:25:16+00:00    673591 2018-06-20 09:24:56
# 4       43  2018-06-20T09:25:42+00:00    673245 2018-06-20 09:24:56
# 5     -151  2018-06-20T09:25:07+00:00    674341 2018-06-20 09:24:56
# 6        2  2018-06-20T09:25:10+00:00    672880 2018-06-20 09:24:56
# 7      235  2018-06-20T09:25:13+00:00    673514 2018-06-20 09:24:56
# 8      251  2018-06-20T09:24:51+00:00    673498 2018-06-20 09:24:56
# 9       15  2018-06-20T09:25:05+00:00    673027 2018-06-20 09:24:56
# 10     323  2018-06-20T09:26:32+00:00    673574 2018-06-20 09:24:56
# 11      -4  2018-06-20T09:24:56+00:00    673205 2018-06-20 09:24:56
# 12      35  2018-06-20T09:25:15+00:00    673242 2018-06-20 09:24:56
# 13      -6  2018-06-20T09:25:10+00:00    672806 2018-06-20 09:24:56
# 14       0  2018-06-20T09:32:00+00:00    673542 2018-06-20 09:24:16
# 15     526  2018-06-20T09:24:25+00:00    672971 2018-06-20 09:24:33
# 16       0  2018-06-20T09:26:00+00:00    673181 2018-06-20 09:22:55
# 17       0  2018-06-20T09:32:00+00:00    673768 2018-06-20 09:23:18
# 18       0  2018-06-20T09:30:00+00:00    674393 2018-06-20 09:12:15
# 19       0  2018-06-20T09:25:00+00:00    673512 2018-06-20 09:20:18
# 20       0  2018-06-20T09:29:00+00:00    673718 2018-06-20 09:19:14
# 21       0  2018-06-20T07:26:01+00:00    673133 2018-06-20 07:31:53
# 22       0  2018-06-20T09:30:00+00:00    674395 2018-06-20 09:14:58
# 23     144  2018-06-20T09:25:36+00:00    672932 2018-06-20 09:24:56
# 24     546  2018-06-20T09:25:01+00:00    673393 2018-06-20 09:24:56
# 25       5  2018-06-20T09:25:05+00:00    672959 2018-06-20 09:24:56
# 26     138  2018-06-20T09:24:56+00:00    672954 2018-06-20 09:24:56
# 27     150  2018-06-20T09:25:54+00:00    673519 2018-06-20 09:24:56
# 28     319  2018-06-20T09:25:36+00:00    673821 2018-06-20 09:24:56
# 29     626  2018-06-20T09:25:17+00:00    673060 2018-06-20 09:24:56
# ..     ...                        ...       ...                 ...
# 76      47  2018-06-20T09:25:46+00:00    672928 2018-06-20 09:24:56
# 77     256  2018-06-20T09:24:58+00:00    673457 2018-06-20 09:24:56
# 78     141  2018-06-20T09:25:40+00:00    673414 2018-06-20 09:24:56
# 79     124  2018-06-20T09:25:35+00:00    673416 2018-06-20 09:24:56
# 80       0  2018-06-20T09:30:00+00:00    674260 2018-06-20 09:24:56
# 81      57  2018-06-20T09:25:12+00:00    673171 2018-06-20 09:24:56
# 82     118  2018-06-20T09:27:17+00:00    673233 2018-06-20 09:24:56
# 83     120  2018-06-20T09:24:52+00:00    673177 2018-06-20 09:24:56
# 84     245  2018-06-20T09:24:54+00:00    673594 2018-06-20 09:24:56
# 85     455  2018-06-20T09:25:59+00:00    673337 2018-06-20 09:24:56
# 86     312  2018-06-20T09:24:53+00:00    673234 2018-06-20 09:24:56
# 87      35  2018-06-20T09:26:15+00:00    672835 2018-06-20 09:24:56
# 88     207  2018-06-20T09:24:56+00:00    673491 2018-06-20 09:24:56
# 89     253  2018-06-20T09:24:59+00:00    674376 2018-06-20 09:24:56
# 90     416  2018-06-20T09:24:47+00:00    672874 2018-06-20 09:24:56
# 91     216  2018-06-20T09:25:15+00:00    673247 2018-06-20 09:24:56
# 92      40  2018-06-20T09:25:19+00:00    673745 2018-06-20 09:24:56
# 93       0  2018-06-20T09:25:00+00:00    673721 2018-06-20 09:24:56
# 94     509  2018-06-20T09:24:48+00:00    673328 2018-06-20 09:24:56
# 95       0  2018-06-20T09:35:00+00:00    672912 2018-06-20 09:24:16
# 96     -27  2018-06-20T09:24:57+00:00    672902 2018-06-20 09:24:56
# 97      40  2018-06-20T09:25:26+00:00    673047 2018-06-20 09:24:56
# 98       0  2018-06-20T09:24:55+00:00    674512 2018-06-20 09:24:56
# 99      24  2018-06-20T09:24:54+00:00    673312 2018-06-20 09:24:56
# 100    206  2018-06-20T09:24:54+00:00    674284 2018-06-20 09:24:56
# 101     38  2018-06-20T09:25:01+00:00    673603 2018-06-20 09:24:56
# 102    121  2018-06-20T09:25:20+00:00    673249 2018-06-20 09:24:56
# 103     36  2018-06-20T09:25:14+00:00    674352 2018-06-20 09:24:56
# 104      0  2018-06-20T09:29:00+00:00    673881 2018-06-20 09:24:56
# 105      0  2018-06-20T09:27:00+00:00    672824 2018-06-20 09:24:33
#
#            heure_estime
# 0   2018-06-20 09:27:02
# 1   2018-06-20 09:25:23
# 2   2018-06-20 09:23:13
# 3   2018-06-20 09:24:41
# 4   2018-06-20 09:25:39
# 5   2018-06-20 09:22:25
# 6   2018-06-20 09:24:58
# 7   2018-06-20 09:28:51
# 8   2018-06-20 09:29:07
# 9   2018-06-20 09:25:11
# 10  2018-06-20 09:30:19
# 11  2018-06-20 09:24:52
# 12  2018-06-20 09:25:31
# 13  2018-06-20 09:24:50
# 14  2018-06-20 09:24:16
# 15  2018-06-20 09:33:19
# 16  2018-06-20 09:22:55
# 17  2018-06-20 09:23:18
# 18  2018-06-20 09:12:15
# 19  2018-06-20 09:20:18
# 20  2018-06-20 09:19:14
# 21  2018-06-20 07:31:53
# 22  2018-06-20 09:14:58
# 23  2018-06-20 09:27:20
# 24  2018-06-20 09:34:02
# 25  2018-06-20 09:25:01
# 26  2018-06-20 09:27:14
# 27  2018-06-20 09:27:26
# 28  2018-06-20 09:30:15
# 29  2018-06-20 09:35:22
# ..                  ...
# 76  2018-06-20 09:25:43
# 77  2018-06-20 09:29:12
# 78  2018-06-20 09:27:17
# 79  2018-06-20 09:27:00
# 80  2018-06-20 09:24:56
# 81  2018-06-20 09:25:53
# 82  2018-06-20 09:26:54
# 83  2018-06-20 09:26:56
# 84  2018-06-20 09:29:01
# 85  2018-06-20 09:32:31
# 86  2018-06-20 09:30:08
# 87  2018-06-20 09:25:31
# 88  2018-06-20 09:28:23
# 89  2018-06-20 09:29:09
# 90  2018-06-20 09:31:52
# 91  2018-06-20 09:28:32
# 92  2018-06-20 09:25:36
# 93  2018-06-20 09:24:56
# 94  2018-06-20 09:33:25
# 95  2018-06-20 09:24:16
# 96  2018-06-20 09:24:29
# 97  2018-06-20 09:25:36
# 98  2018-06-20 09:24:56
# 99  2018-06-20 09:25:20
# 100 2018-06-20 09:28:22
# 101 2018-06-20 09:25:34
# 102 2018-06-20 09:26:57
# 103 2018-06-20 09:25:32
# 104 2018-06-20 09:24:56
# 105 2018-06-20 09:24:33
#
# [106 rows x 5 columns]

# %% [markdown]
# # test

# %%
def test(df):
    try:
        result = True
        for c in df.columns:
            if ('id_ligne' or 'id_arret' or 'id_vh')  in c:
                if not df[c].isnull().all():
                    result = False
            if 'latitude' in c:
                if not (df[c] > 45).all():
                    result = False
            if 'longitude' in c:
                if not(df[c] < 1).all():
                    result = False
        assert result 
    except Exception as e:
        print(e)

# %%
list = [arret, bus, ligne, etape, trajet]

for l in list:
    test(l)

# %%
#Ouverture de la connection vers la bdd
engine = create_engine("sqlite:///data.sqlite")
connection = engine.connect()

# %%
#Table arret
arret.to_sql('arret', connection, if_exists='replace', index=False)

# %%
#Table bus
bus.to_sql('bus', connection, if_exists='replace', index=False)

# %%
#Table ligne
ligne.to_sql('ligne', connection, if_exists='replace', index=False)

# %%
#Table trajet
trajet.to_sql('trajet', connection, if_exists='replace', index=False)

# %%
#Table etape
etape.to_sql('etape', connection, if_exists='replace', index=False)

# %%
#Fermeture connection
connection.close()
