# %%
import pandas as pd

from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

from db import Arret, Vehicule, Ligne, Trajet, Etape
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-1-51b52444af87> in <module>()
#       4 from sqlalchemy.orm import sessionmaker
#       5
# ----> 6 from db import Arret, Vehicule, Ligne, Trajet, Etape
#
# ~/Cours/Bi/tram/irigo-app/db.py in <module>()
#      42     num_ligne = Column(String(32))
#      43
# ---> 44 class Trajet(Base):
#      45     __tablename__ = 'trajet'
#      46     # id_trajet = Column(BigInteger, primary_key=True, autoincrement=True)
#
# ~/.local/lib/python3.5/site-packages/sqlalchemy/ext/declarative/api.py in __init__(cls, classname, bases, dict_)
#      63     def __init__(cls, classname, bases, dict_):
#      64         if '_decl_class_registry' not in cls.__dict__:
# ---> 65             _as_declarative(cls, classname, cls.__dict__)
#      66         type.__init__(cls, classname, bases, dict_)
#      67
#
# ~/.local/lib/python3.5/site-packages/sqlalchemy/ext/declarative/base.py in _as_declarative(cls, classname, dict_)
#      86         return
#      87
# ---> 88     _MapperConfig.setup_mapping(cls, classname, dict_)
#      89
#      90
#
# ~/.local/lib/python3.5/site-packages/sqlalchemy/ext/declarative/base.py in setup_mapping(cls, cls_, classname, dict_)
#     114         else:
#     115             cfg_cls = _MapperConfig
# --> 116         cfg_cls(cls_, classname, dict_)
#     117
#     118     def __init__(self, cls_, classname, dict_):
#
# ~/.local/lib/python3.5/site-packages/sqlalchemy/ext/declarative/base.py in __init__(self, cls_, classname, dict_)
#     146         self._setup_inheritance()
#     147
# --> 148         self._early_mapping()
#     149
#     150     def _early_mapping(self):
#
# ~/.local/lib/python3.5/site-packages/sqlalchemy/ext/declarative/base.py in _early_mapping(self)
#     149
#     150     def _early_mapping(self):
# --> 151         self.map()
#     152
#     153     def _setup_declared_events(self):
#
# ~/.local/lib/python3.5/site-packages/sqlalchemy/ext/declarative/base.py in map(self)
#     574             self.cls,
#     575             self.local_table,
# --> 576             **self.mapper_args
#     577         )
#     578         del self.cls._sa_declared_attr_reg
#
# <string> in mapper(class_, local_table, properties, primary_key, non_primary, inherits, inherit_condition, inherit_foreign_keys, extension, order_by, always_refresh, version_id_col, version_id_generator, polymorphic_on, _polymorphic_map, polymorphic_identity, concrete, with_polymorphic, polymorphic_load, allow_partial_pks, batch, column_prefix, include_properties, exclude_properties, passive_updates, passive_deletes, confirm_deleted_rows, eager_defaults, legacy_is_orphan, _compiled_cache_size)
#
# ~/.local/lib/python3.5/site-packages/sqlalchemy/orm/mapper.py in __init__(self, class_, local_table, properties, primary_key, non_primary, inherits, inherit_condition, inherit_foreign_keys, extension, order_by, always_refresh, version_id_col, version_id_generator, polymorphic_on, _polymorphic_map, polymorphic_identity, concrete, with_polymorphic, polymorphic_load, allow_partial_pks, batch, column_prefix, include_properties, exclude_properties, passive_updates, passive_deletes, confirm_deleted_rows, eager_defaults, legacy_is_orphan, _compiled_cache_size)
#     692             self._configure_properties()
#     693             self._configure_polymorphic_setter()
# --> 694             self._configure_pks()
#     695             Mapper._new_mappers = True
#     696             self._log("constructed")
#
# ~/.local/lib/python3.5/site-packages/sqlalchemy/orm/mapper.py in _configure_pks(self)
#    1325                 "Mapper %s could not assemble any primary "
#    1326                 "key columns for mapped table '%s'" %
# -> 1327                 (self, self.mapped_table.description))
#    1328         elif self.local_table not in self._pks_by_table and \
#    1329                 isinstance(self.local_table, schema.Table):
#
# ArgumentError: Mapper Mapper|Trajet|trajet could not assemble any primary key columns for mapped table 'trajet'

# %%
engine = create_engine('sqlite:///database.db')

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
session.query(Trajet).all()

# %%
with engine.connect() as connection:
    for table in engine.table_names():
        print(table)
        print(pd.read_sql_table(table, connection).head())
# Out:
# arret
#    id_arret mne_arret             nom_arret
# 0    671154  BANCSTMA              BANCHAIS
# 1    671157  BARONNER     ST AUBIN LA SALLE
# 2    671375  DEPOT SD  SORTIE DEPOT ST BART
# 3    671064     2AARD     AVRILLE - ARDENNE
# 4    671723  MATECHNO  MAISON DE TECHNOPOLE
# bus
#   etat_vehicule  id_vehicule type_vehicule
# 0          TDEP    268436139     OmniArtE6
# 1          TDEP    268435909      OMNICITY
# 2          HLPS    268436259     OmniSTDE6
# 3          TDEP    268436472       CITADIS
# 4          TDEP    268436070      MAN City
# etape
#    ecart heure_arret_theorique  id_arret    record_timestamp
# 0      0   2018-06-19 13:49:58    671154 2018-06-19 13:49:58
# 1      0   2018-06-19 13:51:37    671157 2018-06-19 13:51:37
# 2      0   2018-06-19 12:55:13    671375 2018-06-19 12:55:13
# 3      0   2018-06-19 13:52:35    671064 2018-06-19 13:52:35
# 4      0   2018-06-19 13:53:33    671723 2018-06-19 13:53:33
# ligne
#    id_ligne                        nom_ligne num_ligne
# 0    671154    ST SYLVAIN BANCHAIS <>TRELAZE        02
# 1    671157  M-MARCILLE <> ST AUBIN LA SALLE        12
# 2    671375       BEAUCOUZE <> ST BARTHELEMY        04
# 3    671064              ARDENNE <> ROSERAIE         A
# 4    671723       BELLE BEILLE <> MONPLAISIR        01
# trajet
#              destination   id_ligne  id_vehicule   latitude  longitude
# 0    TRELAZE QUANTINIERE  268435458    268436139  47.485885  -0.512530
# 1  VERNUSSON PAR TRELAZE  268435468    268435909  47.489367  -0.503753
# 2         PAS EN SERVICE  268435460    268436259  47.476323  -0.492809
# 3        ANGERS ROSERAIE  268435471    268436472  47.511606  -0.596008
# 4             MONPLAISIR  268435457    268436070  47.478561  -0.605686

# %%
def get_latlon():
    with engine.connect() as connection:
        df = pd.read_sql_table('trajet', connection)
    
    return df[['destination', 'latitude', 'longitude']]

df = get_latlon()
df
# Out:
#                    destination   latitude  longitude
# 0          TRELAZE QUANTINIERE  47.485885  -0.512530
# 1        VERNUSSON PAR TRELAZE  47.489367  -0.503753
# 2               PAS EN SERVICE  47.476323  -0.492809
# 3              ANGERS ROSERAIE  47.511606  -0.596008
# 4                   MONPLAISIR  47.478561  -0.605686
# 5           ST LEGER LA COUDRE  47.464963  -0.559128
# 6                 BELLE BEILLE  47.491103  -0.528307
# 7               PAS EN SERVICE  47.400803  -0.542559
# 8                 ESPACE ANJOU  47.496769  -0.514985
# 9      LAC DE MAINE - L'HOIRIE  47.472852  -0.555017
# 10               CHU - HOPITAL  47.536625  -0.621658
# 11              PAS EN SERVICE  47.475119  -0.492731
# 12           ST AUBIN LA SALLE  47.429680  -0.542488
# 13      MAIRIE DES PONTS DE CE  47.446496  -0.528628
# 14           CIRCULAIRE SENS B  47.462167  -0.562626
# 15                      SORGES  47.441578  -0.492184
# 16                BELLE BEILLE  47.465838  -0.559415
# 17                  MONPLAISIR  47.479647  -0.589800
# 18             AVRILLE SALETTE  47.494789  -0.587220
# 19               ST BARTHELEMY  47.476072  -0.639006
# 20                    BANCHAIS  47.473066  -0.545709
# 21               ST BARTHELEMY  47.473615  -0.584172
# 22              PAS EN SERVICE  47.482564  -0.622399
# 23               ST BARTHELEMY  47.470958  -0.519617
# 24      BEAUCOUZE  HAUTE ROCHE  47.472776  -0.599897
# 25   BOUCHEMAINE PAR HARENCHER  47.447525  -0.615941
# 26           ST AUBIN LA SALLE  47.470432  -0.547731
# 27             ANGERS ROSERAIE  47.443922  -0.554336
# 28             ANGERS ROSERAIE  47.460878  -0.554752
# 29           ST AUBIN LA SALLE  47.433846  -0.500648
# ..                         ...        ...        ...
# 101                     ZI EST  47.471459  -0.534286
# 102   BOUCHEMAINE CHANTOURTEAU  47.471962  -0.541959
# 103                     ZI EST  47.465944  -0.596361
# 104            AVRILLE ARDENNE  47.492229  -0.564104
# 105            ANGERS ROSERAIE  47.496132  -0.580387
# 106            ANGERS ROSERAIE  47.473138  -0.553665
# 107             PAS EN SERVICE  47.494886  -0.569760
# 108               PLESSIS MACE  47.487208  -0.662004
# 109          PLESSIS  SARRIGNE  47.478171  -0.529695
# 110           HAUTE DE RECULEE  47.425281  -0.523522
# 111           MONTREUIL JUIGNE  47.481069  -0.566935
# 112           TRELAZE ST LEZIN  47.457010  -0.553945
# 113          CIRCULAIRE SENS B  47.452415  -0.541832
# 114          CIRCULAIRE SENS A  47.466082  -0.559375
# 115                 SCHWEITZER  47.464670  -0.560068
# 116              SAINTE GEMMES  47.466159  -0.604935
# 117               BELLE BEILLE  47.474311  -0.566513
# 118        TRELAZE QUANTINIERE  47.479512  -0.527126
# 119     BEAUCOUZE  HAUTE ROCHE  47.471148  -0.531946
# 120           AVRILLE ADEZIERE  47.403685  -0.525108
# 121                 ST SYLVAIN  47.445637  -0.463290
# 122        TRELAZE QUANTINIERE  47.443641  -0.477673
# 123        TRELAZE QUANTINIERE  47.453115  -0.469667
# 124          BEAUCOUZE L'ATOLL  47.485121  -0.627308
# 125               BELLE BEILLE  47.491179  -0.529599
# 126          ST AUBIN LA SALLE  47.445134  -0.502457
# 127    EVENTARD par MONPLAISIR  47.468240  -0.526161
# 128              SAINTE GEMMES  47.438231  -0.553324
# 129            AVRILLE ARDENNE  47.476732  -0.551391
# 130         ST LEGER LA COUDRE  47.487763  -0.665926
#
# [131 rows x 3 columns]

# %%
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
def get_mapbox_access_token(folderpath='.', filename="../mapbox.txt"):
    import os
    
    with open(os.path.join(folderpath, filename), 'r') as file:
        s = file.read()
    
    return s

# %%
mapbox_access_token = get_mapbox_access_token()

# %%
df['latitude'][1]
# Out:
# 47.489367

# %%
df['longitude'][1]
# Out:
# -0.50375319

# %%
data = [
    go.Scattermapbox(
        lat=df['latitude'],
        lon=df['longitude'],
        mode='markers',
        marker=dict(
            size=9
        ),
        text=df['destination'],
    )
]

layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=df['latitude'][1],
            lon=df['longitude'][1]
        ),
        pitch=0,
        zoom=10
    ),
)

fig = dict(data=data, layout=layout)
iplot(fig, filename='Multiple Mapbox')
# Out:
# <div id="15c7d9ec-0925-4809-b38b-b41eb06bb719" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("15c7d9ec-0925-4809-b38b-b41eb06bb719", [{"marker": {"size": 9}, "mode": "markers", "text": ["TRELAZE QUANTINIERE", "VERNUSSON PAR TRELAZE", "PAS EN SERVICE", "ANGERS ROSERAIE", "MONPLAISIR", "ST LEGER LA COUDRE", "BELLE BEILLE", "PAS EN SERVICE", "ESPACE ANJOU", "LAC DE MAINE - L'HOIRIE", "CHU - HOPITAL", "PAS EN SERVICE", "ST AUBIN LA SALLE", "MAIRIE DES PONTS DE CE", "CIRCULAIRE SENS B", "SORGES", "BELLE BEILLE", "MONPLAISIR", "AVRILLE SALETTE", "ST BARTHELEMY", "BANCHAIS", "ST BARTHELEMY", "PAS EN SERVICE", "ST BARTHELEMY", "BEAUCOUZE  HAUTE ROCHE", "BOUCHEMAINE PAR HARENCHER", "ST AUBIN LA SALLE", "ANGERS ROSERAIE", "ANGERS ROSERAIE", "ST AUBIN LA SALLE", "PAS EN SERVICE", "MONTREUIL JUIGNE", "LAC DE MAINE - L'HOIRIE", "PAS EN SERVICE", "SPECIAL PISCINE", "MOULIN MARCILLE PAR TRELA", "AQUAVITA VERNEAU", "MOULIN MARCILLE PAR TRELA", "CHU - HOPITAL", "MONTREUIL JUIGNE", "CIRCULAIRE SENS A", "CIRCULAIRE SENS B", "ST SYLVAIN", "LAC DE MAINE - L'HOIRIE", "AVRILLE ARDENNE", "AVRILLE ARDENNE", "ANGERS ROSERAIE", "AVRILLE ARDENNE", "PAS EN SERVICE", "EVENTARD par MONPLAISIR", "HAUTE DE RECULEE", "SCHWEITZER", "CIRCULAIRE SENS A", "BOUCHEMAINE CHANTOURTEAU", "CIRCULAIRE SENS B", "MONPLAISIR", "AVRILLE ADEZIERE", "TRELAZE QUANTINIERE", "BEAUCOUZE L'ATOLL", "PAS EN SERVICE", "MONPLAISIR", "ST SYLVAIN", "TRELAZE QUANTINIERE", "TRELAZE QUANTINIERE", "AVRILLE SALETTE", "EVENTARD par MONPLAISIR